# %% [markdown]
# #Importação das Bibliotecas
# Carrega bibliotecas que são ferramentas de trabalho para:
#
# - Manipular dados (pandas, numpy)
#
# - Fazer gráficos (matplotlib, seaborn)
#
# - Construir modelos de machine learning (sklearn)
#
# Bibliotecas específicas serão importandas ao longo do script

# %%
import os
import shap
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

from collections import Counter
from imblearn.over_sampling import SMOTE
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, ClassifierMixin, clone
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve, CalibratedClassifierCV
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, brier_score_loss, log_loss, balanced_accuracy_score
from sklearn.feature_selection import mutual_info_classif
from sklearn.inspection import permutation_importance
from sklearn.tree import plot_tree
from sklearn.metrics import (
    confusion_matrix, accuracy_score, precision_score, recall_score, f1_score,
    balanced_accuracy_score, matthews_corrcoef, cohen_kappa_score,
    roc_auc_score, roc_curve, precision_recall_curve, average_precision_score,
    log_loss, brier_score_loss, classification_report
)
from sklearn.calibration import calibration_curve
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from catboost import CatBoostClassifier, Pool

# %% [markdown]
# # Coleta de Dados
# Vamos fazer o download da base de dados e armazená-la em um DataFrame.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("adilshamim8/student-depression-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'student-depression-dataset' dataset.
# Path to dataset files: /kaggle/input/student-depression-dataset

# %%
# Lista todos os arquivos e diretórios baixados
dataset_name = os.listdir(path)[0]
print(os.listdir(path))
# Out:
# ['student_depression_dataset.csv']

# %% [markdown]
# ##Criar o DataFrame

# %%
# Criação do dataframe
df_dataset = pd.read_csv(os.path.join(path, dataset_name))

# %% [markdown]
# #Análise Exploratória dos Dados - 1a Parte
# Esta primeira análise exploratória tem por objetivo conhecer os dados brutos e verificar a necessidade de transformações.

# %% [markdown]
# ##Tipo dos Dados

# %%
print(df_dataset.dtypes)
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                          object
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %% [markdown]
# ## Estatística	Descritiva
# A análise descritiva é a primeira etapa da análise de dados, e tem como objetivo resumir, organizar e entender as principais características de um conjunto de dados de forma simples e objetiva, sem tirar conclusões causais ou fazer previsões.
#
# * count:	Número de valores não nulos (não NaN)
# * mean:	Média aritmética dos valores
# * std:	Desvio padrão (medida de dispersão)
# * min:	Valor mínimo
# * 25%:	Primeiro quartil (Q1) – 25% dos dados estão abaixo desse valor
# * 50%:	Mediana (Q2) – metade dos dados estão abaixo desse valor
# * 75%:	Terceiro quartil (Q3) – 75% dos dados estão abaixo desse valor
# * max:	Valor máximo

# %%
pd.options.display.float_format = '{:.2f}'.format
df_whitout_id = df_dataset.drop('id', axis=1)
df_whitout_id.describe()
# Out:
#            Age  Academic Pressure  Work Pressure     CGPA  Study Satisfaction  \
# count 27901.00           27901.00       27901.00 27901.00            27901.00
# mean     25.82               3.14           0.00     7.66                2.94
# std       4.91               1.38           0.04     1.47                1.36
# min      18.00               0.00           0.00     0.00                0.00
# 25%      21.00               2.00           0.00     6.29                2.00
# 50%      25.00               3.00           0.00     7.77                3.00
# 75%      30.00               4.00           0.00     8.92                4.00
# max      59.00               5.00           5.00    10.00                5.00
#
#        Job Satisfaction  Work/Study Hours  Depression
# count          27901.00          27901.00    27901.00
# mean               0.00              7.16        0.59
# std                0.04              3.71        0.49
# min                0.00              0.00        0.00
# 25%                0.00              4.00        0.00
# 50%                0.00              8.00        1.00
# 75%                0.00             10.00        1.00
# max                4.00             12.00        1.00

# %%
dep = df_dataset['Depression'].value_counts().reset_index()
dep.columns = ['Depressao', 'Quantidade']
print(dep)
# Out:
#    Depressao  Quantidade
# 0          1       16336
# 1          0       11565

# %%
df_dataset['Depression'].value_counts().plot(kind='bar')
plt.title('Quantidade de Depressao')
plt.xlabel('Depressao')
plt.ylabel('Ocorrências')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Total Com Depressão x Sem Depressão

# %%
# Total de registros no DataFrame
total_registros = len(df_dataset)

# Soma diagnostico de depressao
total_nao_dep = dep[dep['Depressao'] == 0]['Quantidade'].sum()

# Soma apenas as dep (exclui no depressao(0))
total_dep = dep[dep['Depressao'] != 0]['Quantidade'].sum()

# Calcula a porcentagem
percentual_nao_dep = (total_nao_dep / total_registros) * 100
percentual_dep = (total_dep / total_registros) * 100

# Exibe o resultado
print(f"Total de registros.: {total_registros}")
print(f"Total de sem depressao: {total_nao_dep} ou {percentual_nao_dep:.2f}% do total")
print(f"Total de depressao....: {total_dep} ou {percentual_dep:.2f}% do total")
# Out:
# Total de registros.: 27901
# Total de sem depressao: 11565 ou 41.45% do total
# Total de depressao....: 16336 ou 58.55% do total

# %% [markdown]
# #Engenharia de Dados

# %% [markdown]
# ##Eliminar Valores Nulos
# A eliminação de valores nulos deverá ser feita com cuidados. É necessário avaliar a real necessidade de eliminá-los, pois há alternativas, por exemplo, substituir os valores faltantes pela moda ou pela média.

# %%
df_dataset.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# Não há dados nulos

# %% [markdown]
# ##Eliminar as Linhas Duplicadas
# Já sabemos que não há duplicação, então, este passo não seria necessário, mas fica a título de exemplo

# %% [markdown]
# # Nova seção

# %% [markdown]
# #Cabeçalho com coluna 'Sleep Duration' formatada
#
# Tirar o 'hours' e substituir 'Less than' por '<' e 'More than' por '>'.

# %%
sleep_map = {
    "'Less than 5 hours'": 4,
    "'5-6 hours'": 5.5,
    "'7-8 hours'": 7.5,
    "'More than 8 hours'": 9,
     'Others': 0
}
if 'Sleep Duration' in df_dataset.columns:
    df_dataset['Sleep Duration'] = df_dataset['Sleep Duration'].map(sleep_map)

df_dataset.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male 33.00  Visakhapatnam    Student               5.00
# 1   8  Female 24.00      Bangalore    Student               2.00
# 2  26    Male 31.00       Srinagar    Student               3.00
# 3  30  Female 28.00       Varanasi    Student               3.00
# 4  32  Female 25.00         Jaipur    Student               4.00
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0           0.00  8.97                2.00              0.00            5.50
# 1           0.00  5.90                5.00              0.00            5.50
# 2           0.00  7.03                5.00              0.00            4.00
# 3           0.00  5.59                2.00              0.00            7.50
# 4           0.00  8.13                3.00              0.00            5.50
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# 1       Moderate      BSc                                    No
# 2        Healthy       BA                                    No
# 3       Moderate      BCA                                   Yes
# 4       Moderate   M.Tech                                   Yes
#
#    Work/Study Hours Financial Stress Family History of Mental Illness  \
# 0              3.00              1.0                               No
# 1              3.00              2.0                              Yes
# 2              9.00              1.0                              Yes
# 3              4.00              5.0                              Yes
# 4              1.00              1.0                               No
#
#    Depression
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# #Rodapé com coluna 'Sleep Duration' formatada
#
# Tirar o 'hours' e substituir 'Less than' por '<' e 'More than' por '>'.

# %%
df_dataset.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female 27.00      Surat    Student               5.00
# 27897  140686    Male 27.00   Ludhiana    Student               2.00
# 27898  140689    Male 31.00  Faridabad    Student               3.00
# 27899  140690  Female 18.00   Ludhiana    Student               5.00
# 27900  140699    Male 27.00      Patna    Student               4.00
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896           0.00  5.75                5.00              0.00
# 27897           0.00  9.40                3.00              0.00
# 27898           0.00  6.61                4.00              0.00
# 27899           0.00  6.88                2.00              0.00
# 27900           0.00  9.24                1.00              0.00
#
#        Sleep Duration Dietary Habits      Degree  \
# 27896            5.50      Unhealthy  'Class 12'
# 27897            4.00        Healthy         MSc
# 27898            5.50      Unhealthy          MD
# 27899            4.00        Healthy  'Class 12'
# 27900            4.00        Healthy         BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 27896                                   Yes              7.00
# 27897                                    No              0.00
# 27898                                    No             12.00
# 27899                                   Yes             10.00
# 27900                                   Yes              2.00
#
#       Financial Stress Family History of Mental Illness  Depression
# 27896              1.0                              Yes           0
# 27897              3.0                              Yes           0
# 27898              2.0                               No           0
# 27899              5.0                               No           1
# 27900              3.0                              Yes           1

# %%
# Quantidade total antes
total_antes = len(df_dataset)

# Quantidade de duplicadas
duplicadas = df_dataset.duplicated().sum()

# Remover duplicadas
df_dataset = df_dataset.drop_duplicates()

# Quantidade total depois
total_depois = len(df_dataset)

print(f"Total de linhas antes......................: {total_antes}")
print(f"Linhas duplicadas detectadas...............: {duplicadas}")
print(f"Total de linhas depois do drop_duplicates(): {total_depois}")
# Out:
# Total de linhas antes......................: 27901
# Linhas duplicadas detectadas...............: 0
# Total de linhas depois do drop_duplicates(): 27901

# %%
#Exibe um gráfico da quantidade de falhas por 'Failure Code'
plt.figure(figsize=(12, 6))
df_dataset['Degree'].value_counts().plot(kind='bar')
plt.title('Quantidade por tipo de graduação')
plt.xlabel('Tipo de Falha')
plt.ylabel('Ocorrências')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Análise Exploratória dos Dados - 2a Parte
# Não há necessidade de repetir os comando da 1a Parte, pois não houve mudança dos dados (nenhum valor nulo, por exemplo). Então, vamos aproveitar para fazer mais análises e gráficos

# %% [markdown]
# ##Histogramas das Variáveis Numéricas
#
# * O **histograma** (barras) mostra a **frequência** de registros em faixas específicas de temperatura do ar.
# * A **linha azul** representa a **curva de densidade estimada** — ela suaviza os dados e mostra como os valores estão concentrados.
# * O eixo **X** mostra a temperatura do ar em Kelvin.
# * O eixo **Y** mostra quantas amostras estão em cada faixa de temperatura.
#
# ### *Interpretação:*
#
# Vamos fazer para o primeiro. Convido você a fazer para os demais.
#
# | Observação                                                      | Significado                                                                       |
# | --------------------------------------------------------------- | --------------------------------------------------------------------------------- |
# | A maior parte dos dados está entre **297K e 303K**              | Temperaturas de operação típicas ficam nessa faixa (\~24°C a 30°C)                |
# | A distribuição tem vários **picos** (multimodal)                | Pode haver grupos de máquinas ou momentos distintos de operação                   |
# | Existe uma **simetria moderada**, com leve inclinação à direita | Mostra que há **alguns casos com temperaturas mais altas**, mas sem grande desvio |
#
# ### *Relação com falhas:*
#
# Apesar de ser uma variável bem distribuída e aparentemente "estável", sabemos por análises anteriores (como boxplots e pairplots) que:
#
# * **Falhas como Heat Dissipation Failure** tendem a ocorrer quando a temperatura do ar está **acima de 302K**.
# * Isso pode ser confirmado visualmente nesse gráfico: a “cauda direita” da curva (temperaturas maiores) é menos frequente, mas **potencialmente crítica**.
#
#
# ### *Resultado:*
#
# Este gráfico mostra como a temperatura do ar varia na nossa base. A maioria das medições está concentrada perto dos 300K (cerca de 27°C), o que parece ser uma condição normal. Mas há alguns casos onde a temperatura é mais alta, e foi justamente nessas faixas que algumas falhas apareceram, como problemas de dissipação de calor.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

variaveis = ['Age', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Dietary Habits', 'Sleep Duration']

for var in variaveis:
    plt.figure(figsize=(8, 4))
    sns.histplot(df_dataset[var], kde=True)
    plt.title(f'Distribuição: {var}')
    plt.xlabel(var)
    plt.ylabel("Frequência")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ##Pairplot
#
# Esse gráfico compara **todas as variáveis numéricas duas a duas**, usando dispersão (scatterplots) e densidade (diagonal). Ele é segmentado por **tipo de falha (`Failure Type`)**, usando **cores diferentes para cada classe**.
#
# Esse gráfico mostra se há agrupamentos naturais de pontos (falhas) com base em combinações de variáveis. Isso pode mostrar, por exemplo, que falhas de "Power Failure" acontecem com baixa rotação e alto torque.
#
# ### *Eixos:*
#
# * Linhas = variável no eixo Y
# * Colunas = variável no eixo X
# * Diagonal = distribuição (densidade) de cada variável
#
#
# ### *Distribuições diagonais (autocorrelacionadas)*
#
# * As curvas mostram a **distribuição dos valores por variável**.
# * Por exemplo, a maioria dos valores de `Torque` está entre **35 e 55 Nm**, mas com **alguns pontos acima de 70** → outliers possivelmente relacionados a falhas.
#
# ### *Padrões de falha por cor (fora da diagonal)*
#
# | Variáveis comparadas          | O que se observa?                                                                                       |
# | ----------------------------- | ------------------------------------------------------------------------------------------------------- |
# | **Air Temp × Process Temp**   | Correlação quase perfeita (esperado fisicamente)                                                        |
# | **Torque × Rotational Speed** | Relação inversa clara (quando torque sobe, rotação tende a cair — também esperado)                      |
# | **Torque × Failure Type**     | 🔥 Falhas (especialmente Power Failure e Tool Wear Failure) **concentradas em regiões com torque alto** |
# | **Tool Wear × Torque/Speed**  | Algumas falhas ocorrem com **desgaste elevado e torque alto**                                           |
#
# ### *O que chama atenção?*
#
# * **Power Failure (laranja)** aparece muito mais em regiões com **alta rotação** e **alto torque** → padrão crítico de operação extrema.
# * **Tool Wear Failure (verde)** ocorre em regiões de **torque alto + desgaste alto**.
# * **Heat Dissipation Failure (roxo)** aparece onde a **temperatura do ar é mais alta**.
# * A classe **"No Failure" (azul)** está **muito espalhada**, cobrindo quase todo o gráfico → normal, pois é a classe dominante.
#
# Esse gráfico mostra como as variáveis se comportam em pares e como os diferentes tipos de falha se distribuem nesses espaços. Por exemplo, falhas de desgaste ocorrem quando o torque e o desgaste estão altos. Já falhas de dissipação de calor acontecem quando a temperatura do ar é maior. Esse tipo de visualização nos ajuda a entender que tipo de combinação de condições pode levar a uma falha.

# %%
vars_numericas = [c for c in variaveis if pd.api.types.is_numeric_dtype(df_dataset[c])]

sns.pairplot(df_dataset, hue="Dietary Habits", vars=vars_numericas)

# %% [markdown]
# ##Boxplots
#
# Um boxplot (gráfico de caixa) **resume a distribuição de valores** em cinco partes:
#
# * **Linha central (mediana)**: valor do meio
# * **Caixa**: intervalo entre o 1º quartil (25%) e o 3º quartil (75%)
# * **“Bigodes” (linhas finas)**: mostram a faixa de valores dentro de 1,5x a amplitude interquartil (IQR)
# * **Pontos fora da caixa** (se houver): são considerados **outliers**
#
# ### *O que este gráfico mostra?*
#
# Vamos fazer a análise somente para o primeiro gráfico. Convido você a fazer para os demais.
#
# Ele compara a temperatura do ar entre os diferentes **tipos de falha**:
#
# | Tipo de Falha                | Observação sobre Temperatura                                            |
# | ---------------------------- | ----------------------------------------------------------------------- |
# | **No Failure**               | Mediana \~300K, dispersão normal                                        |
# | **Power Failure**            | Similar a “No Failure”, talvez um pouco mais quente                     |
# | **Tool Wear Failure**        | Também próximo de 300K, sem destaque claro                              |
# | **Overstrain Failure**       | Levemente mais fria que as demais                                       |
# | **Random Failures**          | Varia mais, tem uma mediana levemente mais alta                         |
# | **Heat Dissipation Failure** | 📌 **Temperatura claramente mais alta** (\~302–304K) e mais concentrada |
#
#
# ### Interpretação prática*
#
# * A temperatura do ar **não varia muito entre os tipos de falha** — a maioria fica em torno de **300 K (\~27 °C)**.
# * A exceção é a **Heat Dissipation Failure**, que ocorre com **temperaturas consistentemente mais altas**.
#
#   * Isso faz **sentido físico**, já que o nome indica falha no resfriamento → ar mais quente ao redor do sistema.
#
#
# ### *Resultado*
#
# Este gráfico mostra que, na maioria dos tipos de falha, a temperatura do ar não muda muito. Mas no caso de falha de dissipação de calor, o ar está claramente mais quente. Isso pode indicar que o sistema está retendo calor e não está conseguindo resfriar direito — o que ajuda a entender esse tipo de falha.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ===============================
# BOXPlots - variáveis numéricas
# ===============================
variaveis_numericas = [
    'Age',
    'Academic Pressure',
    'CGPA',
    'Study Satisfaction',
    'Work/Study Hours',
    'Financial Stress'
]

for var in variaveis_numericas:
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df_dataset, x='Depression', y=var)
    plt.title(f'{var} vs. Depression')
    plt.xticks([0, 1], ['Sem Depressão (0)', 'Com Depressão (1)'])
    plt.tight_layout()
    plt.show()

# bins = [0, 4, 6, 8, 10, 12]
# labels = ['< 5', '5-6', '7-8', '> 8', 'Others']

# # Criar faixas de sono
# df_dataset['SleepRange'] = pd.cut(df_dataset['Sleep Duration'], bins=bins, labels=labels, right=False)
# df_dataset['SleepRange'] = pd.Categorical(df_dataset['SleepRange'], categories=labels, ordered=True)

# # Contar quantas pessoas há em cada faixa, separadas por depressão
# count_df = df_dataset.groupby(['SleepRange', 'Depression']).size().reset_index(name='Count')

# # Gráfico de barras (aqui está a correção)
# plt.figure(figsize=(8,5))
# sns.barplot(data=count_df, x='SleepRange', y='Count', hue='Depression', palette='Set2')

# plt.title('Contagem de Pessoas com/sem Depressão por Faixa de Sono')
# plt.xlabel('Faixa de Horas de Sono')
# plt.ylabel('Quantidade de Pessoas')
# plt.legend(title='Depressão')
# plt.tight_layout()
# plt.show()

# ===============================
# COUNTPLOTS - variáveis categóricas
# ===============================
variaveis_categoricas = [
    'Gender',
    'City',
    'Dietary Habits',
    'Degree',
    'Family History of Mental Illness',
    'Have you ever had suicidal thoughts ?'
]

for var in variaveis_categoricas:

  if var == 'City':
    plt.figure(figsize=(20, 10))
  else:
    plt.figure(figsize=(8, 5))
  sns.countplot(data=df_dataset, x=var, hue='Depression')
  plt.title(f'{var} vs. Depression')
  plt.xticks(rotation=45)
  plt.legend(title="Depression", labels=["Sem Depressão (0)", "Com Depressão (1)"])
  plt.tight_layout()
  plt.show()

# %% [markdown]
# ## Matriz de Correlação Selecionada (Mapa de Calor)
#
# A **matriz de correlação de Pearson** mede o **grau de relação linear** entre pares de variáveis.
#
# * Valores próximos de **1** = relação linear positiva forte
# * Valores próximos de **−1** = relação linear negativa forte
# * Valores próximos de **0** = pouca ou nenhuma relação linear
#
#
# ### *Correlações interessantes entre as variáveis*
#
# | Par de variáveis              | Correlação | O que isso diz                                                                                                     |
# | ----------------------------- | ---------- | ------------------------------------------------------------------------------------------------------------------ |
# | **Air temp ↔ Process temp**   | +0.88      | Andam juntas — provavelmente aumentam ao mesmo tempo                                                               |
# | **Torque ↔ Rotational speed** | −0.88      | Relação **fortemente inversa**: quanto mais torque, menor a rotação (ou vice-versa) — isso faz sentido fisicamente |
# | **Outros pares**              | ≈ 0        | Pouca relação direta entre outras variáveis                                                                        |
#
# ### *Como isso se conecta à árvore de decisão?*
#
# * **Mesmo que a correlação seja baixa**, a árvore **ainda pode usar essas variáveis** para fazer boas divisões — pois a árvore **não depende apenas de relações lineares**.
# * Por exemplo:
#
#   * **Torque e Rotational speed** têm correlação negativa forte entre si, mas **podem ser úteis em ramos distintos da árvore**.
#
# ### *Resultado*
#
# Este mapa de calor mostra relações entre as variáveis, não com falhas. Em manutenção preditiva, ele revela co-variações e redundâncias (multicolinearidade) e inspira features derivadas. Depois, modelos não lineares (como árvores) capturam padrões e interações que a correlação linear não mostra — lembre: correlação ≠ causalidade.

# %%
corr_matrix = df_dataset[variaveis].corr(numeric_only=True)

import seaborn as sns, matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação entre Variáveis')
plt.show()

# %% [markdown]
# ##Matriz de Correlação entre as Variáveis e o a Falha
#
# Esse é um **gráfico de barras horizontais** que mostra o **coeficiente de correlação** entre cada variável e o tipo de falha (codificado numericamente).
#
# Mostra a força e direção de uma relação linear entre cada variável e a variável alvo (Failure_Code).
#
# É global e linear: ele verifica se uma variável aumenta ou diminui à medida que o tipo de falha muda (em média).
#
# Valores próximos de zero indicam que a variável isoladamente não tem uma relação linear forte com a falha.
#
# * **Correlação positiva** → conforme o valor da variável aumenta, é mais provável que ocorra um certo tipo de falha (classes maiores).
# * **Correlação negativa** → conforme o valor da variável aumenta, a chance de falha diminui ou muda para outro tipo de falha (classes menores).
# * **Próximo de zero** → pouca ou nenhuma relação linear direta com o tipo de falha.
#
# ### *Interpretação do gráfico*
#
# | Variável                | Correlação com a falha | Interpretação prática                                                                      |
# | ----------------------- | ---------------------- | ------------------------------------------------------------------------------------------ |
# | **Tool wear \[min]**    | **+0.11**              | Quanto mais desgastada a ferramenta, **maior a chance de falha** (forte indicador).        |
# | **Torque \[Nm]**        | +0.03                  | Torque alto está **levemente associado** a tipos de falhas.                                |
# | **Rotational speed**    | ≈ 0.00                 | **Praticamente sem correlação linear** com a falha.                                        |
# | **Process temperature** | **−0.01**              | Pequena correlação negativa, praticamente irrelevante.                                     |
# | **Air temperature**     | **−0.02**              | Um leve indício de que temperaturas mais altas do ar podem estar ligadas a falhas menores. |
#
#
# ### *Como interpretar isso?*
#
# * A única variável com **correlação notável é `Tool wear`**: isso faz sentido, pois ferramentas muito desgastadas tendem a quebrar ou falhar.
# * O restante tem **baixa ou nenhuma correlação linear direta**. Isso não significa que são inúteis — apenas que a relação pode ser **não linear** ou **mais complexa**, e por isso é melhor capturada por modelos como árvores.
#
# ### *Resultado*
#
# Esse gráfico mostra que, dentre todas as variáveis, o desgaste da ferramenta é o que mais influencia o tipo de falha. Ou seja, quanto mais usada a ferramenta, mais provável que aconteça uma falha grave. Já a rotação ou a temperatura não têm um efeito direto e simples, mas isso não quer dizer que não importam — o modelo pode estar captando interações mais complexas entre elas.

# %%
corr = df_dataset[variaveis].corr(numeric_only=True).abs()

mask = np.triu(np.ones_like(corr, dtype=bool))
corr_tri = corr.where(~mask)

pairs = (
    corr_tri.stack()
    .reset_index()
    .rename(columns={'level_0':'Var 1', 'level_1':'Var 2', 0:'abs_corr'})
    .sort_values('abs_corr', ascending=False)
)

top_k = 10
top_pairs = pairs.head(top_k).copy()  # <= evita SettingWithCopyWarning
top_pairs.loc[:, 'Par'] = top_pairs['Var 1'] + ' ↔ ' + top_pairs['Var 2']

print("Top pares por |correlação|:")
print(top_pairs[['Par', 'abs_corr']])

plt.figure(figsize=(8, 5))
sns.barplot(
    data=top_pairs,
    x='abs_corr',
    y='Par',
    hue='Par',          # <= adiciona hue
    legend=False,       # <= remove legenda redundante
    orient='h',
    palette='coolwarm'  # <= agora permitido
)
plt.title(f'Top {top_k} pares por |correlação|')
plt.xlabel('|correlação|')
plt.tight_layout()
plt.show()
# Out:
# Top pares por |correlação|:
#                                       Par  abs_corr
# 4  Study Satisfaction ↔ Academic Pressure      0.11
# 0                 Academic Pressure ↔ Age      0.08
# 5               Study Satisfaction ↔ CGPA      0.04
# 7      Sleep Duration ↔ Academic Pressure      0.04
# 2                CGPA ↔ Academic Pressure      0.02
# 9     Sleep Duration ↔ Study Satisfaction      0.01
# 3                Study Satisfaction ↔ Age      0.01
# 1                              CGPA ↔ Age      0.01
# 8                   Sleep Duration ↔ CGPA      0.00
# 6                    Sleep Duration ↔ Age      0.00

# %% [markdown]
# # Etapa 3

# %%
#Remove lines with invalid variable value
indices_to_drop = df_dataset[df_dataset['Financial Stress'] == '?'].index
#indices_to_drop.append(df_dataset[df_dataset['Sleep Duration'] == 'Others'].index)

indices_to_drop

# Drop the identified rows
df_dropped = df_dataset.drop(indices_to_drop)

diet_map = {
    'Healthy': 3,
    'Moderate': 2,
    'Unhealthy': 1,
    'Others': 0
}

if 'Dietary Habits' in df_dropped.columns:
    df_dropped['Dietary Habits'] = df_dropped['Dietary Habits'].map(diet_map)

binary_map = {
    'Yes': 1,
    'No': 0,
}

gender_map = {
    'Male': 1,
    'Female': 0,
}

if 'Have you ever had suicidal thoughts ?' in df_dropped.columns:
    df_dropped['Have you ever had suicidal thoughts ?'] = df_dropped['Have you ever had suicidal thoughts ?'].map(binary_map)

if 'Family History of Mental Illness' in df_dropped.columns:
    df_dropped['Family History of Mental Illness'] = df_dropped['Family History of Mental Illness'].map(binary_map)

if 'Gender' in df_dropped.columns:
    df_dropped['Gender'] = df_dropped['Gender'].map(gender_map)

    ##Dropar 'Job Satisfaction' , 'Work Pressure'

# %%
features = df_dropped[['Age', 'Academic Pressure','Study Satisfaction', 'Sleep Duration', 'Dietary Habits','Have you ever had suicidal thoughts ?','Work/Study Hours','Financial Stress','Family History of Mental Illness']]
target = df_dropped[['Depression']]
print(target)
# Out:
#        Depression
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0
# ...           ...
# 27896           0
# 27897           0
# 27898           0
# 27899           1
# 27900           1
#
# [27898 rows x 1 columns]

# %%
features.head()
# Out:
#     Age  Academic Pressure  Study Satisfaction  Sleep Duration  \
# 0 33.00               5.00                2.00            5.50
# 1 24.00               2.00                5.00            5.50
# 2 31.00               3.00                5.00            4.00
# 3 28.00               3.00                2.00            7.50
# 4 25.00               4.00                3.00            5.50
#
#    Dietary Habits  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0               3                                      1              3.00
# 1               2                                      0              3.00
# 2               3                                      0              9.00
# 3               2                                      1              4.00
# 4               2                                      1              1.00
#
#   Financial Stress  Family History of Mental Illness
# 0              1.0                                 0
# 1              2.0                                 1
# 2              1.0                                 1
# 3              5.0                                 1
# 4              1.0                                 0

# %%
# Calcular mutual information entre cada feature e a classe
mi = mutual_info_classif(features, target.values.ravel(), random_state=42)

mi_series = pd.Series(mi, index=features.columns).sort_values(ascending=False)

# Visualizar
print(mi_series)

# Gráfico de barras
mi_series.plot(kind="bar", figsize=(8,4), title="Relevância das variáveis (Mutual Information)")
plt.ylabel("Score")
plt.show()
# Out:
# Have you ever had suicidal thoughts ?   0.16
# Academic Pressure                       0.12
# Financial Stress                        0.07
# Age                                     0.03
# Dietary Habits                          0.02
# Work/Study Hours                        0.02
# Study Satisfaction                      0.01
# Sleep Duration                          0.00
# Family History of Mental Illness        0.00
# dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target.values.ravel(), test_size=0.2, random_state=42, stratify=target)

X_tr, X_va, y_tr, y_va = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=42)

# Contagem simples
print("Distribuição em y_train:")
print(pd.Series(y_train).value_counts())

print("\nDistribuição em y_test:")
print(pd.Series(y_test).value_counts())

# Se quiser formatar mais bonito:
print("\nDistribuição em y_train (percentual):")
print(pd.Series(y_train).value_counts(normalize=True))

print("\nDistribuição em y_test (percentual):")
print(pd.Series(y_test).value_counts(normalize=True))
# Out:
# Distribuição em y_train:
# 1    13068
# 0     9250
# Name: count, dtype: int64
#
# Distribuição em y_test:
# 1    3267
# 0    2313
# Name: count, dtype: int64
#
# Distribuição em y_train (percentual):
# 1   0.59
# 0   0.41
# Name: proportion, dtype: float64
#
# Distribuição em y_test (percentual):
# 1   0.59
# 0   0.41
# Name: proportion, dtype: float64

# %% [markdown]
# #Cria a POOL do CatBoost

# %%
cat_cols = features.select_dtypes(include=["object"]).columns.tolist()
cat_idx = [features.columns.get_loc(c) for c in cat_cols]


train_pool = Pool(X_train, y_train, cat_features=cat_idx)
test_pool  = Pool(X_test, y_test, cat_features=cat_idx)
va_pool = Pool(X_va, y_va, cat_features=cat_idx)

print(train_pool)
# Out:
# <catboost.core.Pool object at 0x7a92bbd81130>

# %% [markdown]
# #Iterar com grid custom para achar as melhores métricas

# %%
''' depths = [5, 7, 9]
learning_rates = [0.03, 0.05, 0.087]
iterations_list = [200, 500, 700]
loss_functions = ["Logloss", "MultiClass"]
custom_metric = ["AUC", "Accuracy", "F1", "Recall"]

results = []

for depth in depths:
    for lr in learning_rates:
        for iters in iterations_list:
            for loss_fn in loss_functions:

                print(
                    f"\n============================="
                    f"\nTestando: depth={depth}, lr={lr}, iters={iters}, loss={loss_fn}"
                    f"\n============================="
                )
                model = CatBoostClassifier(
                    depth=depth,
                    learning_rate=lr,
                    iterations=iters,
                    loss_function=loss_fn,
                    eval_metric="AUC",
                    custom_metric=custom_metric,
                    auto_class_weights="Balanced",
                    random_seed=42,
                    verbose=0
                )
                model.fit(
                    train_pool,
                    eval_set=test_pool,
                    use_best_model=True
                )
                y_pred = model.predict(X_test)
                y_proba = model.predict_proba(X_test)[:, 1]
                report = classification_report(
                    y_test,
                    y_pred,
                    zero_division=0,
                    digits=5
                )
                auc = roc_auc_score(y_test, y_proba)

                print(f"AUC (teste): {auc:.5f}")
                print("\nRelatório de Classificação:\n", report)
                results.append({
                    "depth": depth,
                    "learning_rate": lr,
                    "iterations": iters,
                    "loss_function": loss_fn,
                    "custom_metric": custom_metric,
                    "auc_test": auc,
                    "report": report
                })
best_run = max(results, key=lambda x: x["auc_test"])

print("\n\n===== MELHOR COMBINAÇÃO ENCONTRADA =====")
print(f"depth        : {best_run['depth']}")
print(f"learning_rate: {best_run['learning_rate']}")
print(f"iterations   : {best_run['iterations']}")
print(f"loss_function: {best_run['loss_function']}")
print(f"custom_metric: {best_run['custom_metric']}")
print(f"AUC (teste)  : {best_run['auc_test']:.5f}")

print("\nRelatório de Classificação da melhor combinação:\n")
print(best_run["report"]) '''
# Out:
# ' depths = [5, 7, 9]\nlearning_rates = [0.03, 0.05, 0.087]\niterations_list = [200, 500, 700]\nloss_functions = ["Logloss", "MultiClass"]\ncustom_metric = ["AUC", "Accuracy", "F1", "Recall"]\n\nresults = []\n\nfor depth in depths:\n    for lr in learning_rates:\n        for iters in iterations_list:\n            for loss_fn in loss_functions:\n\n                print(\n                    f"\n============================="\n                    f"\nTestando: depth={depth}, lr={lr}, iters={iters}, loss={loss_fn}"\n                    f"\n============================="\n                )\n                model = CatBoostClassifier(\n                    depth=depth,\n                    learning_rate=lr,\n                    iterations=iters,\n                    loss_function=loss_fn,\n                    eval_metric="AUC",\n                    custom_metric=custom_metric,\n                    auto_class_weights="Balanced",\n                    random_seed=42,\n                    verbose=0\n                )\n                model.fit(\n                    train_pool,\n                    eval_set=test_pool,\n                    use_best_model=True\n                )\n                y_pred = model.predict(X_test)\n                y_proba = model.predict_proba(X_test)[:, 1]\n                report = classification_report(\n                    y_test,\n                    y_pred,\n                    zero_division=0,\n                    digits=5\n                )\n                auc = roc_auc_score(y_test, y_proba)\n\n                print(f"AUC (teste): {auc:.5f}")\n                print("\nRelatório de Classificação:\n", report)\n                results.append({\n                    "depth": depth,\n                    "learning_rate": lr,\n                    "iterations": iters,\n                    "loss_function": loss_fn,\n                    "custom_metric": custom_metric,\n                    "auc_test": auc,\n                    "report": report\n                })\nbest_run = max(results, key=lambda x: x["auc_test"])\n\nprint("\n\n===== MELHOR COMBINAÇÃO ENCONTRADA =====")\nprint(f"depth        : {best_run[\'depth\']}")\nprint(f"learning_rate: {best_run[\'learning_rate\']}")\nprint(f"iterations   : {best_run[\'iterations\']}")\nprint(f"loss_function: {best_run[\'loss_function\']}")\nprint(f"custom_metric: {best_run[\'custom_metric\']}")\nprint(f"AUC (teste)  : {best_run[\'auc_test\']:.5f}")\n\nprint("\nRelatório de Classificação da melhor combinação:\n")\nprint(best_run["report"]) '

# %% [markdown]
# #Definir melhor modelo

# %%
''' best_model = CatBoostClassifier(
  depth=best_run['depth'],
  learning_rate=best_run['learning_rate'],
  iterations=best_run['iterations'],
  loss_function=best_run['loss_function'],
  eval_metric="AUC",
  custom_metric=custom_metric,
  auto_class_weights="Balanced",
  random_seed=42,
  verbose=0
) '''

model = CatBoostClassifier()

# %%
''' best_model.fit(
  train_pool,
  eval_set=test_pool,
  use_best_model=True
) '''

model.fit(
  train_pool,
  eval_set=test_pool,
  use_best_model=True
)
# Out:
# Learning rate set to 0.068238
# 0:	learn: 0.6428304	test: 0.6434114	best: 0.6434114 (0)	total: 50.7ms	remaining: 50.6s
# 1:	learn: 0.5993222	test: 0.6003925	best: 0.6003925 (1)	total: 88.8ms	remaining: 44.3s
# 2:	learn: 0.5647606	test: 0.5658668	best: 0.5658668 (2)	total: 122ms	remaining: 40.6s
# 3:	learn: 0.5374878	test: 0.5386516	best: 0.5386516 (3)	total: 146ms	remaining: 36.3s
# 4:	learn: 0.5115875	test: 0.5128687	best: 0.5128687 (4)	total: 171ms	remaining: 34s
# 5:	learn: 0.4902067	test: 0.4921872	best: 0.4921872 (5)	total: 195ms	remaining: 32.4s
# 6:	learn: 0.4732059	test: 0.4756936	best: 0.4756936 (6)	total: 216ms	remaining: 30.7s
# 7:	learn: 0.4573796	test: 0.4601197	best: 0.4601197 (7)	total: 239ms	remaining: 29.7s
# 8:	learn: 0.4439307	test: 0.4471791	best: 0.4471791 (8)	total: 260ms	remaining: 28.6s
# 9:	learn: 0.4330425	test: 0.4364701	best: 0.4364701 (9)	total: 283ms	remaining: 28.1s
# 10:	learn: 0.4233920	test: 0.4273641	best: 0.4273641 (10)	total: 306ms	remaining: 27.5s
# 11:	learn: 0.4149193	test: 0.4191207	best: 0.4191207 (11)	total: 331ms	remaining: 27.2s
# 12:	learn: 0.4080141	test: 0.4123192	best: 0.4123192 (12)	total: 356ms	remaining: 27s
# 13:	learn: 0.4019312	test: 0.4063409	best: 0.4063409 (13)	total: 376ms	remaining: 26.5s
# 14:	learn: 0.3963986	test: 0.4010582	best: 0.4010582 (14)	total: 401ms	remaining: 26.3s
# 15:	learn: 0.3917253	test: 0.3967083	best: 0.3967083 (15)	total: 421ms	remaining: 25.9s
# 16:	learn: 0.3875715	test: 0.3930485	best: 0.3930485 (16)	total: 443ms	remaining: 25.6s
# 17:	learn: 0.3836330	test: 0.3890710	best: 0.3890710 (17)	total: 463ms	remaining: 25.3s
# 18:	learn: 0.3801847	test: 0.3858539	best: 0.3858539 (18)	total: 486ms	remaining: 25.1s
# 19:	learn: 0.3772376	test: 0.3830021	best: 0.3830021 (19)	total: 512ms	remaining: 25.1s
# 20:	learn: 0.3745918	test: 0.3808861	best: 0.3808861 (20)	total: 557ms	remaining: 26s
# 21:	learn: 0.3721293	test: 0.3787877	best: 0.3787877 (21)	total: 581ms	remaining: 25.8s
# 22:	learn: 0.3698455	test: 0.3768049	best: 0.3768049 (22)	total: 606ms	remaining: 25.7s
# 23:	learn: 0.3682124	test: 0.3753718	best: 0.3753718 (23)	total: 626ms	remaining: 25.5s
# 24:	learn: 0.3664001	test: 0.3738014	best: 0.3738014 (24)	total: 649ms	remaining: 25.3s
# 25:	learn: 0.3647197	test: 0.3723542	best: 0.3723542 (25)	total: 677ms	remaining: 25.3s
# 26:	learn: 0.3631274	test: 0.3710182	best: 0.3710182 (26)	total: 699ms	remaining: 25.2s
# 27:	learn: 0.3617767	test: 0.3700851	best: 0.3700851 (27)	total: 722ms	remaining: 25.1s
# 28:	learn: 0.3605374	test: 0.3690995	best: 0.3690995 (28)	total: 744ms	remaining: 24.9s
# 29:	learn: 0.3593149	test: 0.3681417	best: 0.3681417 (29)	total: 770ms	remaining: 24.9s
# 30:	learn: 0.3579265	test: 0.3668872	best: 0.3668872 (30)	total: 791ms	remaining: 24.7s
# 31:	learn: 0.3569235	test: 0.3663919	best: 0.3663919 (31)	total: 816ms	remaining: 24.7s
# 32:	learn: 0.3559630	test: 0.3657249	best: 0.3657249 (32)	total: 840ms	remaining: 24.6s
# 33:	learn: 0.3550124	test: 0.3652642	best: 0.3652642 (33)	total: 865ms	remaining: 24.6s
# 34:	learn: 0.3541403	test: 0.3645879	best: 0.3645879 (34)	total: 891ms	remaining: 24.6s
# 35:	learn: 0.3532823	test: 0.3639323	best: 0.3639323 (35)	total: 914ms	remaining: 24.5s
# 36:	learn: 0.3526238	test: 0.3634047	best: 0.3634047 (36)	total: 935ms	remaining: 24.3s
# 37:	learn: 0.3521271	test: 0.3630083	best: 0.3630083 (37)	total: 951ms	remaining: 24.1s
# 38:	learn: 0.3514164	test: 0.3624685	best: 0.3624685 (38)	total: 972ms	remaining: 23.9s
# 39:	learn: 0.3506512	test: 0.3619199	best: 0.3619199 (39)	total: 996ms	remaining: 23.9s
# 40:	learn: 0.3499596	test: 0.3615761	best: 0.3615761 (40)	total: 1.02s	remaining: 23.9s
# 41:	learn: 0.3492644	test: 0.3610673	best: 0.3610673 (41)	total: 1.04s	remaining: 23.8s
# 42:	learn: 0.3487245	test: 0.3607571	best: 0.3607571 (42)	total: 1.06s	remaining: 23.7s
# 43:	learn: 0.3481817	test: 0.3602986	best: 0.3602986 (43)	total: 1.09s	remaining: 23.6s
# 44:	learn: 0.3475122	test: 0.3598735	best: 0.3598735 (44)	total: 1.11s	remaining: 23.5s
# 45:	learn: 0.3470431	test: 0.3596776	best: 0.3596776 (45)	total: 1.13s	remaining: 23.4s
# 46:	learn: 0.3464477	test: 0.3593089	best: 0.3593089 (46)	total: 1.15s	remaining: 23.4s
# 47:	learn: 0.3460701	test: 0.3592285	best: 0.3592285 (47)	total: 1.18s	remaining: 23.4s
# 48:	learn: 0.3456607	test: 0.3591180	best: 0.3591180 (48)	total: 1.2s	remaining: 23.3s
# 49:	learn: 0.3452443	test: 0.3590261	best: 0.3590261 (49)	total: 1.23s	remaining: 23.3s
# 50:	learn: 0.3448116	test: 0.3587163	best: 0.3587163 (50)	total: 1.26s	remaining: 23.4s
# 51:	learn: 0.3443237	test: 0.3583964	best: 0.3583964 (51)	total: 1.3s	remaining: 23.8s
# 52:	learn: 0.3438378	test: 0.3582722	best: 0.3582722 (52)	total: 1.34s	remaining: 24s
# 53:	learn: 0.3435680	test: 0.3582299	best: 0.3582299 (53)	total: 1.4s	remaining: 24.6s
# 54:	learn: 0.3431885	test: 0.3579656	best: 0.3579656 (54)	total: 1.45s	remaining: 24.9s
# 55:	learn: 0.3429735	test: 0.3578776	best: 0.3578776 (55)	total: 1.49s	remaining: 25.1s
# 56:	learn: 0.3427297	test: 0.3578054	best: 0.3578054 (56)	total: 1.54s	remaining: 25.5s
# 57:	learn: 0.3422696	test: 0.3575242	best: 0.3575242 (57)	total: 1.59s	remaining: 25.9s
# 58:	learn: 0.3421183	test: 0.3574695	best: 0.3574695 (58)	total: 1.64s	remaining: 26.2s
# 59:	learn: 0.3418925	test: 0.3573296	best: 0.3573296 (59)	total: 1.69s	remaining: 26.4s
# 60:	learn: 0.3415602	test: 0.3572600	best: 0.3572600 (60)	total: 1.74s	remaining: 26.7s
# 61:	learn: 0.3412866	test: 0.3570885	best: 0.3570885 (61)	total: 1.78s	remaining: 27s
# 62:	learn: 0.3408934	test: 0.3569428	best: 0.3569428 (62)	total: 1.83s	remaining: 27.3s
# 63:	learn: 0.3404987	test: 0.3568499	best: 0.3568499 (63)	total: 1.89s	remaining: 27.6s
# 64:	learn: 0.3402360	test: 0.3566883	best: 0.3566883 (64)	total: 1.94s	remaining: 27.9s
# 65:	learn: 0.3400451	test: 0.3566149	best: 0.3566149 (65)	total: 1.98s	remaining: 28.1s
# 66:	learn: 0.3398841	test: 0.3565069	best: 0.3565069 (66)	total: 2.03s	remaining: 28.3s
# 67:	learn: 0.3396800	test: 0.3565103	best: 0.3565069 (66)	total: 2.08s	remaining: 28.5s
# 68:	learn: 0.3393912	test: 0.3564470	best: 0.3564470 (68)	total: 2.13s	remaining: 28.7s
# 69:	learn: 0.3391493	test: 0.3564034	best: 0.3564034 (69)	total: 2.18s	remaining: 29s
# 70:	learn: 0.3389934	test: 0.3563826	best: 0.3563826 (70)	total: 2.22s	remaining: 29.1s
# 71:	learn: 0.3386910	test: 0.3563220	best: 0.3563220 (71)	total: 2.27s	remaining: 29.3s
# 72:	learn: 0.3384142	test: 0.3561874	best: 0.3561874 (72)	total: 2.33s	remaining: 29.6s
# 73:	learn: 0.3382238	test: 0.3561920	best: 0.3561874 (72)	total: 2.37s	remaining: 29.6s
# 74:	learn: 0.3380856	test: 0.3562049	best: 0.3561874 (72)	total: 2.42s	remaining: 29.9s
# 75:	learn: 0.3379208	test: 0.3561768	best: 0.3561768 (75)	total: 2.46s	remaining: 29.9s
# 76:	learn: 0.3376956	test: 0.3562180	best: 0.3561768 (75)	total: 2.51s	remaining: 30.1s
# 77:	learn: 0.3375362	test: 0.3562493	best: 0.3561768 (75)	total: 2.56s	remaining: 30.3s
# 78:	learn: 0.3374074	test: 0.3562031	best: 0.3561768 (75)	total: 2.6s	remaining: 30.3s
# 79:	learn: 0.3372381	test: 0.3561480	best: 0.3561480 (79)	total: 2.68s	remaining: 30.8s
# 80:	learn: 0.3369881	test: 0.3561074	best: 0.3561074 (80)	total: 2.73s	remaining: 31s
# 81:	learn: 0.3368729	test: 0.3560957	best: 0.3560957 (81)	total: 2.78s	remaining: 31.2s
# 82:	learn: 0.3368336	test: 0.3560991	best: 0.3560957 (81)	total: 2.82s	remaining: 31.2s
# 83:	learn: 0.3367603	test: 0.3561292	best: 0.3560957 (81)	total: 2.88s	remaining: 31.4s
# 84:	learn: 0.3365019	test: 0.3560626	best: 0.3560626 (84)	total: 2.93s	remaining: 31.6s
# 85:	learn: 0.3364371	test: 0.3561122	best: 0.3560626 (84)	total: 2.97s	remaining: 31.6s
# 86:	learn: 0.3364296	test: 0.3561033	best: 0.3560626 (84)	total: 3s	remaining: 31.5s
# 87:	learn: 0.3362745	test: 0.3560430	best: 0.3560430 (87)	total: 3.05s	remaining: 31.6s
# 88:	learn: 0.3360537	test: 0.3560136	best: 0.3560136 (88)	total: 3.09s	remaining: 31.6s
# 89:	learn: 0.3360349	test: 0.3559833	best: 0.3559833 (89)	total: 3.12s	remaining: 31.5s
# 90:	learn: 0.3358159	test: 0.3560101	best: 0.3559833 (89)	total: 3.17s	remaining: 31.7s
# 91:	learn: 0.3356829	test: 0.3560347	best: 0.3559833 (89)	total: 3.21s	remaining: 31.6s
# 92:	learn: 0.3356649	test: 0.3560334	best: 0.3559833 (89)	total: 3.24s	remaining: 31.6s
# 93:	learn: 0.3355310	test: 0.3560107	best: 0.3559833 (89)	total: 3.29s	remaining: 31.7s
# 94:	learn: 0.3354686	test: 0.3559719	best: 0.3559719 (94)	total: 3.34s	remaining: 31.8s
# 95:	learn: 0.3353531	test: 0.3559681	best: 0.3559681 (95)	total: 3.39s	remaining: 31.9s
# 96:	learn: 0.3351606	test: 0.3560328	best: 0.3559681 (95)	total: 3.45s	remaining: 32.1s
# 97:	learn: 0.3349856	test: 0.3560175	best: 0.3559681 (95)	total: 3.5s	remaining: 32.2s
# 98:	learn: 0.3349615	test: 0.3560160	best: 0.3559681 (95)	total: 3.53s	remaining: 32.2s
# 99:	learn: 0.3349067	test: 0.3559920	best: 0.3559681 (95)	total: 3.56s	remaining: 32s
# 100:	learn: 0.3348568	test: 0.3560194	best: 0.3559681 (95)	total: 3.61s	remaining: 32.1s
# 101:	learn: 0.3348066	test: 0.3560054	best: 0.3559681 (95)	total: 3.65s	remaining: 32.2s
# 102:	learn: 0.3347812	test: 0.3559985	best: 0.3559681 (95)	total: 3.69s	remaining: 32.1s
# 103:	learn: 0.3346142	test: 0.3559888	best: 0.3559681 (95)	total: 3.73s	remaining: 32.1s
# 104:	learn: 0.3345489	test: 0.3560225	best: 0.3559681 (95)	total: 3.78s	remaining: 32.2s
# 105:	learn: 0.3343967	test: 0.3560024	best: 0.3559681 (95)	total: 3.83s	remaining: 32.3s
# 106:	learn: 0.3341906	test: 0.3560482	best: 0.3559681 (95)	total: 3.87s	remaining: 32.3s
# 107:	learn: 0.3340989	test: 0.3560426	best: 0.3559681 (95)	total: 3.91s	remaining: 32.3s
# 108:	learn: 0.3340731	test: 0.3560375	best: 0.3559681 (95)	total: 3.95s	remaining: 32.3s
# 109:	learn: 0.3340609	test: 0.3560504	best: 0.3559681 (95)	total: 3.98s	remaining: 32.2s
# 110:	learn: 0.3340335	test: 0.3560573	best: 0.3559681 (95)	total: 4.02s	remaining: 32.2s
# 111:	learn: 0.3338653	test: 0.3561097	best: 0.3559681 (95)	total: 4.08s	remaining: 32.4s
# 112:	learn: 0.3338278	test: 0.3561042	best: 0.3559681 (95)	total: 4.14s	remaining: 32.5s
# 113:	learn: 0.3338140	test: 0.3560786	best: 0.3559681 (95)	total: 4.17s	remaining: 32.4s
# 114:	learn: 0.3337753	test: 0.3560960	best: 0.3559681 (95)	total: 4.21s	remaining: 32.4s
# 115:	learn: 0.3336324	test: 0.3560864	best: 0.3559681 (95)	total: 4.24s	remaining: 32.3s
# 116:	learn: 0.3334840	test: 0.3560765	best: 0.3559681 (95)	total: 4.26s	remaining: 32.1s
# 117:	learn: 0.3332822	test: 0.3560720	best: 0.3559681 (95)	total: 4.28s	remaining: 32s
# 118:	learn: 0.3332557	test: 0.3560703	best: 0.3559681 (95)	total: 4.3s	remaining: 31.9s
# 119:	learn: 0.3330964	test: 0.3561446	best: 0.3559681 (95)	total: 4.33s	remaining: 31.7s
# 120:	learn: 0.3329292	test: 0.3562064	best: 0.3559681 (95)	total: 4.35s	remaining: 31.6s
# 121:	learn: 0.3327297	test: 0.3562961	best: 0.3559681 (95)	total: 4.37s	remaining: 31.5s
# 122:	learn: 0.3326863	test: 0.3563188	best: 0.3559681 (95)	total: 4.39s	remaining: 31.3s
# 123:	learn: 0.3325079	test: 0.3563165	best: 0.3559681 (95)	total: 4.42s	remaining: 31.2s
# 124:	learn: 0.3323291	test: 0.3563290	best: 0.3559681 (95)	total: 4.44s	remaining: 31.1s
# 125:	learn: 0.3323207	test: 0.3563384	best: 0.3559681 (95)	total: 4.45s	remaining: 30.9s
# 126:	learn: 0.3322236	test: 0.3564077	best: 0.3559681 (95)	total: 4.47s	remaining: 30.8s
# 127:	learn: 0.3321773	test: 0.3564241	best: 0.3559681 (95)	total: 4.5s	remaining: 30.6s
# 128:	learn: 0.3321362	test: 0.3564539	best: 0.3559681 (95)	total: 4.52s	remaining: 30.5s
# 129:	learn: 0.3320382	test: 0.3564874	best: 0.3559681 (95)	total: 4.54s	remaining: 30.4s
# 130:	learn: 0.3319699	test: 0.3565511	best: 0.3559681 (95)	total: 4.56s	remaining: 30.3s
# 131:	learn: 0.3319359	test: 0.3565557	best: 0.3559681 (95)	total: 4.59s	remaining: 30.2s
# 132:	learn: 0.3318604	test: 0.3565717	best: 0.3559681 (95)	total: 4.61s	remaining: 30s
# 133:	learn: 0.3316541	test: 0.3566218	best: 0.3559681 (95)	total: 4.63s	remaining: 29.9s
# 134:	learn: 0.3315663	test: 0.3566228	best: 0.3559681 (95)	total: 4.65s	remaining: 29.8s
# 135:	learn: 0.3315121	test: 0.3566384	best: 0.3559681 (95)	total: 4.68s	remaining: 29.7s
# 136:	learn: 0.3314736	test: 0.3566362	best: 0.3559681 (95)	total: 4.7s	remaining: 29.6s
# 137:	learn: 0.3313977	test: 0.3566628	best: 0.3559681 (95)	total: 4.72s	remaining: 29.5s
# 138:	learn: 0.3312363	test: 0.3567822	best: 0.3559681 (95)	total: 4.75s	remaining: 29.4s
# 139:	learn: 0.3311052	test: 0.3567891	best: 0.3559681 (95)	total: 4.77s	remaining: 29.3s
# 140:	learn: 0.3311052	test: 0.3567891	best: 0.3559681 (95)	total: 4.79s	remaining: 29.2s
# 141:	learn: 0.3310748	test: 0.3568023	best: 0.3559681 (95)	total: 4.82s	remaining: 29.1s
# 142:	learn: 0.3309694	test: 0.3568107	best: 0.3559681 (95)	total: 4.84s	remaining: 29s
# 143:	learn: 0.3308093	test: 0.3567087	best: 0.3559681 (95)	total: 4.87s	remaining: 28.9s
# 144:	learn: 0.3307774	test: 0.3567232	best: 0.3559681 (95)	total: 4.89s	remaining: 28.8s
# 145:	learn: 0.3307381	test: 0.3567212	best: 0.3559681 (95)	total: 4.91s	remaining: 28.7s
# 146:	learn: 0.3306325	test: 0.3567269	best: 0.3559681 (95)	total: 4.93s	remaining: 28.6s
# 147:	learn: 0.3305180	test: 0.3566961	best: 0.3559681 (95)	total: 4.95s	remaining: 28.5s
# 148:	learn: 0.3305006	test: 0.3567037	best: 0.3559681 (95)	total: 4.97s	remaining: 28.4s
# 149:	learn: 0.3303287	test: 0.3567082	best: 0.3559681 (95)	total: 4.99s	remaining: 28.3s
# 150:	learn: 0.3303014	test: 0.3567145	best: 0.3559681 (95)	total: 5.01s	remaining: 28.2s
# 151:	learn: 0.3302189	test: 0.3567034	best: 0.3559681 (95)	total: 5.03s	remaining: 28.1s
# 152:	learn: 0.3301866	test: 0.3566812	best: 0.3559681 (95)	total: 5.06s	remaining: 28s
# 153:	learn: 0.3300318	test: 0.3567518	best: 0.3559681 (95)	total: 5.08s	remaining: 27.9s
# 154:	learn: 0.3298549	test: 0.3567083	best: 0.3559681 (95)	total: 5.11s	remaining: 27.9s
# 155:	learn: 0.3297811	test: 0.3567164	best: 0.3559681 (95)	total: 5.13s	remaining: 27.8s
# 156:	learn: 0.3296296	test: 0.3567290	best: 0.3559681 (95)	total: 5.16s	remaining: 27.7s
# 157:	learn: 0.3294768	test: 0.3567311	best: 0.3559681 (95)	total: 5.18s	remaining: 27.6s
# 158:	learn: 0.3294537	test: 0.3567337	best: 0.3559681 (95)	total: 5.2s	remaining: 27.5s
# 159:	learn: 0.3294153	test: 0.3567486	best: 0.3559681 (95)	total: 5.22s	remaining: 27.4s
# 160:	learn: 0.3293822	test: 0.3567455	best: 0.3559681 (95)	total: 5.24s	remaining: 27.3s
# 161:	learn: 0.3293225	test: 0.3567515	best: 0.3559681 (95)	total: 5.26s	remaining: 27.2s
# 162:	learn: 0.3291384	test: 0.3567960	best: 0.3559681 (95)	total: 5.28s	remaining: 27.1s
# 163:	learn: 0.3290588	test: 0.3568574	best: 0.3559681 (95)	total: 5.31s	remaining: 27.1s
# 164:	learn: 0.3290268	test: 0.3568639	best: 0.3559681 (95)	total: 5.33s	remaining: 27s
# 165:	learn: 0.3289999	test: 0.3568758	best: 0.3559681 (95)	total: 5.35s	remaining: 26.9s
# 166:	learn: 0.3289979	test: 0.3568764	best: 0.3559681 (95)	total: 5.37s	remaining: 26.8s
# 167:	learn: 0.3288517	test: 0.3568678	best: 0.3559681 (95)	total: 5.39s	remaining: 26.7s
# 168:	learn: 0.3288266	test: 0.3568522	best: 0.3559681 (95)	total: 5.41s	remaining: 26.6s
# 169:	learn: 0.3288124	test: 0.3568671	best: 0.3559681 (95)	total: 5.43s	remaining: 26.5s
# 170:	learn: 0.3287368	test: 0.3569068	best: 0.3559681 (95)	total: 5.45s	remaining: 26.4s
# 171:	learn: 0.3285610	test: 0.3569154	best: 0.3559681 (95)	total: 5.47s	remaining: 26.4s
# 172:	learn: 0.3285476	test: 0.3569109	best: 0.3559681 (95)	total: 5.5s	remaining: 26.3s
# 173:	learn: 0.3284832	test: 0.3569151	best: 0.3559681 (95)	total: 5.52s	remaining: 26.2s
# 174:	learn: 0.3283500	test: 0.3569381	best: 0.3559681 (95)	total: 5.54s	remaining: 26.1s
# 175:	learn: 0.3282837	test: 0.3569066	best: 0.3559681 (95)	total: 5.56s	remaining: 26s
# 176:	learn: 0.3282685	test: 0.3569062	best: 0.3559681 (95)	total: 5.58s	remaining: 25.9s
# 177:	learn: 0.3282480	test: 0.3569074	best: 0.3559681 (95)	total: 5.6s	remaining: 25.8s
# 178:	learn: 0.3282479	test: 0.3569074	best: 0.3559681 (95)	total: 5.61s	remaining: 25.7s
# 179:	learn: 0.3282030	test: 0.3568839	best: 0.3559681 (95)	total: 5.63s	remaining: 25.6s
# 180:	learn: 0.3281223	test: 0.3569118	best: 0.3559681 (95)	total: 5.65s	remaining: 25.6s
# 181:	learn: 0.3280402	test: 0.3569453	best: 0.3559681 (95)	total: 5.67s	remaining: 25.5s
# 182:	learn: 0.3280187	test: 0.3569644	best: 0.3559681 (95)	total: 5.69s	remaining: 25.4s
# 183:	learn: 0.3279866	test: 0.3569761	best: 0.3559681 (95)	total: 5.71s	remaining: 25.3s
# 184:	learn: 0.3278214	test: 0.3571107	best: 0.3559681 (95)	total: 5.73s	remaining: 25.3s
# 185:	learn: 0.3277342	test: 0.3570975	best: 0.3559681 (95)	total: 5.75s	remaining: 25.2s
# 186:	learn: 0.3276968	test: 0.3571041	best: 0.3559681 (95)	total: 5.78s	remaining: 25.1s
# 187:	learn: 0.3276120	test: 0.3571486	best: 0.3559681 (95)	total: 5.8s	remaining: 25.1s
# 188:	learn: 0.3275974	test: 0.3571528	best: 0.3559681 (95)	total: 5.83s	remaining: 25s
# 189:	learn: 0.3275730	test: 0.3571461	best: 0.3559681 (95)	total: 5.86s	remaining: 25s
# 190:	learn: 0.3275497	test: 0.3571427	best: 0.3559681 (95)	total: 5.88s	remaining: 24.9s
# 191:	learn: 0.3274033	test: 0.3571756	best: 0.3559681 (95)	total: 5.91s	remaining: 24.9s
# 192:	learn: 0.3273772	test: 0.3571878	best: 0.3559681 (95)	total: 5.93s	remaining: 24.8s
# 193:	learn: 0.3272526	test: 0.3571879	best: 0.3559681 (95)	total: 5.95s	remaining: 24.7s
# 194:	learn: 0.3271991	test: 0.3571967	best: 0.3559681 (95)	total: 5.97s	remaining: 24.6s
# 195:	learn: 0.3271666	test: 0.3571797	best: 0.3559681 (95)	total: 5.99s	remaining: 24.6s
# 196:	learn: 0.3271387	test: 0.3571916	best: 0.3559681 (95)	total: 6.01s	remaining: 24.5s
# 197:	learn: 0.3270086	test: 0.3572224	best: 0.3559681 (95)	total: 6.03s	remaining: 24.4s
# 198:	learn: 0.3268133	test: 0.3572094	best: 0.3559681 (95)	total: 6.06s	remaining: 24.4s
# 199:	learn: 0.3267028	test: 0.3572216	best: 0.3559681 (95)	total: 6.08s	remaining: 24.3s
# 200:	learn: 0.3266564	test: 0.3572216	best: 0.3559681 (95)	total: 6.1s	remaining: 24.3s
# 201:	learn: 0.3266362	test: 0.3572169	best: 0.3559681 (95)	total: 6.12s	remaining: 24.2s
# 202:	learn: 0.3266113	test: 0.3572022	best: 0.3559681 (95)	total: 6.14s	remaining: 24.1s
# 203:	learn: 0.3264982	test: 0.3572380	best: 0.3559681 (95)	total: 6.16s	remaining: 24s
# 204:	learn: 0.3264125	test: 0.3572412	best: 0.3559681 (95)	total: 6.18s	remaining: 24s
# 205:	learn: 0.3263370	test: 0.3572081	best: 0.3559681 (95)	total: 6.2s	remaining: 23.9s
# 206:	learn: 0.3262911	test: 0.3572006	best: 0.3559681 (95)	total: 6.22s	remaining: 23.8s
# 207:	learn: 0.3262804	test: 0.3571973	best: 0.3559681 (95)	total: 6.24s	remaining: 23.8s
# 208:	learn: 0.3261485	test: 0.3572169	best: 0.3559681 (95)	total: 6.26s	remaining: 23.7s
# 209:	learn: 0.3261348	test: 0.3572141	best: 0.3559681 (95)	total: 6.28s	remaining: 23.6s
# 210:	learn: 0.3261071	test: 0.3572003	best: 0.3559681 (95)	total: 6.3s	remaining: 23.6s
# 211:	learn: 0.3260900	test: 0.3572048	best: 0.3559681 (95)	total: 6.32s	remaining: 23.5s
# 212:	learn: 0.3260853	test: 0.3572112	best: 0.3559681 (95)	total: 6.34s	remaining: 23.4s
# 213:	learn: 0.3260530	test: 0.3572160	best: 0.3559681 (95)	total: 6.36s	remaining: 23.4s
# 214:	learn: 0.3260229	test: 0.3572440	best: 0.3559681 (95)	total: 6.38s	remaining: 23.3s
# 215:	learn: 0.3259123	test: 0.3572338	best: 0.3559681 (95)	total: 6.41s	remaining: 23.3s
# 216:	learn: 0.3258346	test: 0.3572387	best: 0.3559681 (95)	total: 6.43s	remaining: 23.2s
# 217:	learn: 0.3257199	test: 0.3572839	best: 0.3559681 (95)	total: 6.45s	remaining: 23.1s
# 218:	learn: 0.3255613	test: 0.3573580	best: 0.3559681 (95)	total: 6.47s	remaining: 23.1s
# 219:	learn: 0.3254388	test: 0.3574454	best: 0.3559681 (95)	total: 6.5s	remaining: 23s
# 220:	learn: 0.3254342	test: 0.3574406	best: 0.3559681 (95)	total: 6.52s	remaining: 23s
# 221:	learn: 0.3252792	test: 0.3574065	best: 0.3559681 (95)	total: 6.54s	remaining: 22.9s
# 222:	learn: 0.3252575	test: 0.3574217	best: 0.3559681 (95)	total: 6.56s	remaining: 22.9s
# 223:	learn: 0.3251704	test: 0.3574576	best: 0.3559681 (95)	total: 6.58s	remaining: 22.8s
# 224:	learn: 0.3251534	test: 0.3574521	best: 0.3559681 (95)	total: 6.6s	remaining: 22.7s
# 225:	learn: 0.3251452	test: 0.3574492	best: 0.3559681 (95)	total: 6.63s	remaining: 22.7s
# 226:	learn: 0.3249946	test: 0.3574780	best: 0.3559681 (95)	total: 6.65s	remaining: 22.6s
# 227:	learn: 0.3249585	test: 0.3574890	best: 0.3559681 (95)	total: 6.67s	remaining: 22.6s
# 228:	learn: 0.3248821	test: 0.3574916	best: 0.3559681 (95)	total: 6.69s	remaining: 22.5s
# 229:	learn: 0.3248179	test: 0.3575041	best: 0.3559681 (95)	total: 6.71s	remaining: 22.5s
# 230:	learn: 0.3247139	test: 0.3575602	best: 0.3559681 (95)	total: 6.73s	remaining: 22.4s
# 231:	learn: 0.3246842	test: 0.3575882	best: 0.3559681 (95)	total: 6.75s	remaining: 22.3s
# 232:	learn: 0.3245957	test: 0.3576347	best: 0.3559681 (95)	total: 6.77s	remaining: 22.3s
# 233:	learn: 0.3245680	test: 0.3576366	best: 0.3559681 (95)	total: 6.79s	remaining: 22.2s
# 234:	learn: 0.3245362	test: 0.3576577	best: 0.3559681 (95)	total: 6.81s	remaining: 22.2s
# 235:	learn: 0.3244592	test: 0.3576768	best: 0.3559681 (95)	total: 6.84s	remaining: 22.1s
# 236:	learn: 0.3244421	test: 0.3576716	best: 0.3559681 (95)	total: 6.86s	remaining: 22.1s
# 237:	learn: 0.3243536	test: 0.3576753	best: 0.3559681 (95)	total: 6.89s	remaining: 22.1s
# 238:	learn: 0.3242813	test: 0.3577165	best: 0.3559681 (95)	total: 6.92s	remaining: 22s
# 239:	learn: 0.3242605	test: 0.3577191	best: 0.3559681 (95)	total: 6.94s	remaining: 22s
# 240:	learn: 0.3242458	test: 0.3577139	best: 0.3559681 (95)	total: 6.96s	remaining: 21.9s
# 241:	learn: 0.3241458	test: 0.3577336	best: 0.3559681 (95)	total: 6.98s	remaining: 21.9s
# 242:	learn: 0.3240255	test: 0.3577050	best: 0.3559681 (95)	total: 7s	remaining: 21.8s
# 243:	learn: 0.3239361	test: 0.3576901	best: 0.3559681 (95)	total: 7.02s	remaining: 21.8s
# 244:	learn: 0.3239186	test: 0.3577081	best: 0.3559681 (95)	total: 7.04s	remaining: 21.7s
# 245:	learn: 0.3238734	test: 0.3577231	best: 0.3559681 (95)	total: 7.07s	remaining: 21.7s
# 246:	learn: 0.3238224	test: 0.3577321	best: 0.3559681 (95)	total: 7.09s	remaining: 21.6s
# 247:	learn: 0.3237262	test: 0.3577379	best: 0.3559681 (95)	total: 7.11s	remaining: 21.6s
# 248:	learn: 0.3236934	test: 0.3577430	best: 0.3559681 (95)	total: 7.13s	remaining: 21.5s
# 249:	learn: 0.3236040	test: 0.3577627	best: 0.3559681 (95)	total: 7.15s	remaining: 21.5s
# 250:	learn: 0.3235853	test: 0.3577609	best: 0.3559681 (95)	total: 7.17s	remaining: 21.4s
# 251:	learn: 0.3235354	test: 0.3577444	best: 0.3559681 (95)	total: 7.2s	remaining: 21.4s
# 252:	learn: 0.3234915	test: 0.3577543	best: 0.3559681 (95)	total: 7.22s	remaining: 21.3s
# 253:	learn: 0.3234124	test: 0.3577323	best: 0.3559681 (95)	total: 7.24s	remaining: 21.3s
# 254:	learn: 0.3232853	test: 0.3578224	best: 0.3559681 (95)	total: 7.26s	remaining: 21.2s
# 255:	learn: 0.3232695	test: 0.3578188	best: 0.3559681 (95)	total: 7.28s	remaining: 21.2s
# 256:	learn: 0.3231661	test: 0.3577994	best: 0.3559681 (95)	total: 7.31s	remaining: 21.1s
# 257:	learn: 0.3230862	test: 0.3578417	best: 0.3559681 (95)	total: 7.33s	remaining: 21.1s
# 258:	learn: 0.3230192	test: 0.3578912	best: 0.3559681 (95)	total: 7.35s	remaining: 21s
# 259:	learn: 0.3229701	test: 0.3578886	best: 0.3559681 (95)	total: 7.37s	remaining: 21s
# 260:	learn: 0.3229266	test: 0.3578822	best: 0.3559681 (95)	total: 7.39s	remaining: 20.9s
# 261:	learn: 0.3228513	test: 0.3579415	best: 0.3559681 (95)	total: 7.42s	remaining: 20.9s
# 262:	learn: 0.3228046	test: 0.3579021	best: 0.3559681 (95)	total: 7.44s	remaining: 20.8s
# 263:	learn: 0.3226891	test: 0.3579030	best: 0.3559681 (95)	total: 7.46s	remaining: 20.8s
# 264:	learn: 0.3225683	test: 0.3580017	best: 0.3559681 (95)	total: 7.49s	remaining: 20.8s
# 265:	learn: 0.3225120	test: 0.3580630	best: 0.3559681 (95)	total: 7.51s	remaining: 20.7s
# 266:	learn: 0.3224226	test: 0.3581001	best: 0.3559681 (95)	total: 7.53s	remaining: 20.7s
# 267:	learn: 0.3224011	test: 0.3581023	best: 0.3559681 (95)	total: 7.55s	remaining: 20.6s
# 268:	learn: 0.3223354	test: 0.3580926	best: 0.3559681 (95)	total: 7.57s	remaining: 20.6s
# 269:	learn: 0.3222138	test: 0.3581883	best: 0.3559681 (95)	total: 7.59s	remaining: 20.5s
# 270:	learn: 0.3220969	test: 0.3582152	best: 0.3559681 (95)	total: 7.62s	remaining: 20.5s
# 271:	learn: 0.3219954	test: 0.3582773	best: 0.3559681 (95)	total: 7.64s	remaining: 20.4s
# 272:	learn: 0.3219326	test: 0.3583077	best: 0.3559681 (95)	total: 7.66s	remaining: 20.4s
# 273:	learn: 0.3218169	test: 0.3584043	best: 0.3559681 (95)	total: 7.68s	remaining: 20.3s
# 274:	learn: 0.3218005	test: 0.3584031	best: 0.3559681 (95)	total: 7.7s	remaining: 20.3s
# 275:	learn: 0.3217654	test: 0.3583919	best: 0.3559681 (95)	total: 7.72s	remaining: 20.3s
# 276:	learn: 0.3217461	test: 0.3583674	best: 0.3559681 (95)	total: 7.74s	remaining: 20.2s
# 277:	learn: 0.3216905	test: 0.3583617	best: 0.3559681 (95)	total: 7.76s	remaining: 20.2s
# 278:	learn: 0.3216157	test: 0.3584257	best: 0.3559681 (95)	total: 7.79s	remaining: 20.1s
# 279:	learn: 0.3215607	test: 0.3584500	best: 0.3559681 (95)	total: 7.81s	remaining: 20.1s
# 280:	learn: 0.3214763	test: 0.3585239	best: 0.3559681 (95)	total: 7.83s	remaining: 20s
# 281:	learn: 0.3213602	test: 0.3585707	best: 0.3559681 (95)	total: 7.85s	remaining: 20s
# 282:	learn: 0.3213238	test: 0.3585489	best: 0.3559681 (95)	total: 7.87s	remaining: 19.9s
# 283:	learn: 0.3212396	test: 0.3586014	best: 0.3559681 (95)	total: 7.89s	remaining: 19.9s
# 284:	learn: 0.3211615	test: 0.3586099	best: 0.3559681 (95)	total: 7.92s	remaining: 19.9s
# 285:	learn: 0.3209943	test: 0.3586824	best: 0.3559681 (95)	total: 7.95s	remaining: 19.8s
# 286:	learn: 0.3209397	test: 0.3587268	best: 0.3559681 (95)	total: 7.97s	remaining: 19.8s
# 287:	learn: 0.3209103	test: 0.3587075	best: 0.3559681 (95)	total: 7.99s	remaining: 19.8s
# 288:	learn: 0.3208766	test: 0.3586878	best: 0.3559681 (95)	total: 8.01s	remaining: 19.7s
# 289:	learn: 0.3208034	test: 0.3587138	best: 0.3559681 (95)	total: 8.03s	remaining: 19.7s
# 290:	learn: 0.3207118	test: 0.3587893	best: 0.3559681 (95)	total: 8.05s	remaining: 19.6s
# 291:	learn: 0.3206320	test: 0.3588161	best: 0.3559681 (95)	total: 8.07s	remaining: 19.6s
# 292:	learn: 0.3205905	test: 0.3588300	best: 0.3559681 (95)	total: 8.09s	remaining: 19.5s
# 293:	learn: 0.3205230	test: 0.3588578	best: 0.3559681 (95)	total: 8.12s	remaining: 19.5s
# 294:	learn: 0.3204401	test: 0.3589053	best: 0.3559681 (95)	total: 8.14s	remaining: 19.5s
# 295:	learn: 0.3203128	test: 0.3589206	best: 0.3559681 (95)	total: 8.16s	remaining: 19.4s
# 296:	learn: 0.3202176	test: 0.3589413	best: 0.3559681 (95)	total: 8.18s	remaining: 19.4s
# 297:	learn: 0.3201630	test: 0.3589231	best: 0.3559681 (95)	total: 8.21s	remaining: 19.3s
# 298:	learn: 0.3201434	test: 0.3589373	best: 0.3559681 (95)	total: 8.23s	remaining: 19.3s
# 299:	learn: 0.3200601	test: 0.3589570	best: 0.3559681 (95)	total: 8.25s	remaining: 19.2s
# 300:	learn: 0.3200501	test: 0.3589460	best: 0.3559681 (95)	total: 8.27s	remaining: 19.2s
# 301:	learn: 0.3199836	test: 0.3589515	best: 0.3559681 (95)	total: 8.29s	remaining: 19.2s
# 302:	learn: 0.3199475	test: 0.3589853	best: 0.3559681 (95)	total: 8.31s	remaining: 19.1s
# 303:	learn: 0.3198679	test: 0.3589970	best: 0.3559681 (95)	total: 8.33s	remaining: 19.1s
# 304:	learn: 0.3198140	test: 0.3590235	best: 0.3559681 (95)	total: 8.36s	remaining: 19s
# 305:	learn: 0.3197770	test: 0.3590613	best: 0.3559681 (95)	total: 8.38s	remaining: 19s
# 306:	learn: 0.3197136	test: 0.3590388	best: 0.3559681 (95)	total: 8.42s	remaining: 19s
# 307:	learn: 0.3196484	test: 0.3590600	best: 0.3559681 (95)	total: 8.44s	remaining: 19s
# 308:	learn: 0.3195229	test: 0.3590731	best: 0.3559681 (95)	total: 8.46s	remaining: 18.9s
# 309:	learn: 0.3194548	test: 0.3590753	best: 0.3559681 (95)	total: 8.48s	remaining: 18.9s
# 310:	learn: 0.3194271	test: 0.3590645	best: 0.3559681 (95)	total: 8.5s	remaining: 18.8s
# 311:	learn: 0.3193596	test: 0.3590570	best: 0.3559681 (95)	total: 8.52s	remaining: 18.8s
# 312:	learn: 0.3192680	test: 0.3590883	best: 0.3559681 (95)	total: 8.55s	remaining: 18.8s
# 313:	learn: 0.3191396	test: 0.3593159	best: 0.3559681 (95)	total: 8.57s	remaining: 18.7s
# 314:	learn: 0.3190609	test: 0.3593361	best: 0.3559681 (95)	total: 8.59s	remaining: 18.7s
# 315:	learn: 0.3189976	test: 0.3593674	best: 0.3559681 (95)	total: 8.61s	remaining: 18.6s
# 316:	learn: 0.3188565	test: 0.3594433	best: 0.3559681 (95)	total: 8.63s	remaining: 18.6s
# 317:	learn: 0.3188227	test: 0.3594808	best: 0.3559681 (95)	total: 8.65s	remaining: 18.6s
# 318:	learn: 0.3187853	test: 0.3594872	best: 0.3559681 (95)	total: 8.68s	remaining: 18.5s
# 319:	learn: 0.3187533	test: 0.3595023	best: 0.3559681 (95)	total: 8.7s	remaining: 18.5s
# 320:	learn: 0.3186931	test: 0.3594710	best: 0.3559681 (95)	total: 8.72s	remaining: 18.4s
# 321:	learn: 0.3186098	test: 0.3595577	best: 0.3559681 (95)	total: 8.74s	remaining: 18.4s
# 322:	learn: 0.3184729	test: 0.3596111	best: 0.3559681 (95)	total: 8.76s	remaining: 18.4s
# 323:	learn: 0.3184008	test: 0.3596091	best: 0.3559681 (95)	total: 8.79s	remaining: 18.3s
# 324:	learn: 0.3182923	test: 0.3596496	best: 0.3559681 (95)	total: 8.81s	remaining: 18.3s
# 325:	learn: 0.3182366	test: 0.3596995	best: 0.3559681 (95)	total: 8.83s	remaining: 18.3s
# 326:	learn: 0.3181701	test: 0.3596918	best: 0.3559681 (95)	total: 8.85s	remaining: 18.2s
# 327:	learn: 0.3181669	test: 0.3596940	best: 0.3559681 (95)	total: 8.87s	remaining: 18.2s
# 328:	learn: 0.3181306	test: 0.3597504	best: 0.3559681 (95)	total: 8.89s	remaining: 18.1s
# 329:	learn: 0.3180760	test: 0.3597050	best: 0.3559681 (95)	total: 8.91s	remaining: 18.1s
# 330:	learn: 0.3180488	test: 0.3597143	best: 0.3559681 (95)	total: 8.93s	remaining: 18s
# 331:	learn: 0.3179954	test: 0.3597209	best: 0.3559681 (95)	total: 8.94s	remaining: 18s
# 332:	learn: 0.3179061	test: 0.3597453	best: 0.3559681 (95)	total: 8.99s	remaining: 18s
# 333:	learn: 0.3178986	test: 0.3597415	best: 0.3559681 (95)	total: 9.01s	remaining: 18s
# 334:	learn: 0.3178269	test: 0.3597054	best: 0.3559681 (95)	total: 9.03s	remaining: 17.9s
# 335:	learn: 0.3177796	test: 0.3597476	best: 0.3559681 (95)	total: 9.05s	remaining: 17.9s
# 336:	learn: 0.3177655	test: 0.3597421	best: 0.3559681 (95)	total: 9.07s	remaining: 17.9s
# 337:	learn: 0.3177127	test: 0.3597766	best: 0.3559681 (95)	total: 9.1s	remaining: 17.8s
# 338:	learn: 0.3176998	test: 0.3597847	best: 0.3559681 (95)	total: 9.12s	remaining: 17.8s
# 339:	learn: 0.3176758	test: 0.3597796	best: 0.3559681 (95)	total: 9.14s	remaining: 17.7s
# 340:	learn: 0.3175497	test: 0.3597817	best: 0.3559681 (95)	total: 9.16s	remaining: 17.7s
# 341:	learn: 0.3175081	test: 0.3598352	best: 0.3559681 (95)	total: 9.18s	remaining: 17.7s
# 342:	learn: 0.3174325	test: 0.3598537	best: 0.3559681 (95)	total: 9.21s	remaining: 17.6s
# 343:	learn: 0.3173374	test: 0.3598463	best: 0.3559681 (95)	total: 9.22s	remaining: 17.6s
# 344:	learn: 0.3172291	test: 0.3598705	best: 0.3559681 (95)	total: 9.25s	remaining: 17.6s
# 345:	learn: 0.3171934	test: 0.3598870	best: 0.3559681 (95)	total: 9.27s	remaining: 17.5s
# 346:	learn: 0.3170530	test: 0.3599217	best: 0.3559681 (95)	total: 9.29s	remaining: 17.5s
# 347:	learn: 0.3169981	test: 0.3599356	best: 0.3559681 (95)	total: 9.31s	remaining: 17.4s
# 348:	learn: 0.3168867	test: 0.3599330	best: 0.3559681 (95)	total: 9.33s	remaining: 17.4s
# 349:	learn: 0.3167326	test: 0.3599384	best: 0.3559681 (95)	total: 9.36s	remaining: 17.4s
# 350:	learn: 0.3166401	test: 0.3599374	best: 0.3559681 (95)	total: 9.38s	remaining: 17.3s
# 351:	learn: 0.3165511	test: 0.3599664	best: 0.3559681 (95)	total: 9.4s	remaining: 17.3s
# 352:	learn: 0.3165237	test: 0.3599623	best: 0.3559681 (95)	total: 9.42s	remaining: 17.3s
# 353:	learn: 0.3164615	test: 0.3599780	best: 0.3559681 (95)	total: 9.45s	remaining: 17.2s
# 354:	learn: 0.3164272	test: 0.3599874	best: 0.3559681 (95)	total: 9.46s	remaining: 17.2s
# 355:	learn: 0.3164179	test: 0.3599935	best: 0.3559681 (95)	total: 9.48s	remaining: 17.2s
# 356:	learn: 0.3164132	test: 0.3600002	best: 0.3559681 (95)	total: 9.5s	remaining: 17.1s
# 357:	learn: 0.3163388	test: 0.3599860	best: 0.3559681 (95)	total: 9.53s	remaining: 17.1s
# 358:	learn: 0.3163232	test: 0.3599830	best: 0.3559681 (95)	total: 9.54s	remaining: 17s
# 359:	learn: 0.3163007	test: 0.3599503	best: 0.3559681 (95)	total: 9.57s	remaining: 17s
# 360:	learn: 0.3162359	test: 0.3599546	best: 0.3559681 (95)	total: 9.59s	remaining: 17s
# 361:	learn: 0.3161867	test: 0.3599581	best: 0.3559681 (95)	total: 9.61s	remaining: 16.9s
# 362:	learn: 0.3161317	test: 0.3599889	best: 0.3559681 (95)	total: 9.63s	remaining: 16.9s
# 363:	learn: 0.3161066	test: 0.3599779	best: 0.3559681 (95)	total: 9.65s	remaining: 16.9s
# 364:	learn: 0.3160339	test: 0.3599886	best: 0.3559681 (95)	total: 9.68s	remaining: 16.8s
# 365:	learn: 0.3159291	test: 0.3600078	best: 0.3559681 (95)	total: 9.7s	remaining: 16.8s
# 366:	learn: 0.3158568	test: 0.3600961	best: 0.3559681 (95)	total: 9.72s	remaining: 16.8s
# 367:	learn: 0.3158290	test: 0.3601262	best: 0.3559681 (95)	total: 9.74s	remaining: 16.7s
# 368:	learn: 0.3158199	test: 0.3601219	best: 0.3559681 (95)	total: 9.77s	remaining: 16.7s
# 369:	learn: 0.3158002	test: 0.3601236	best: 0.3559681 (95)	total: 9.79s	remaining: 16.7s
# 370:	learn: 0.3157342	test: 0.3601551	best: 0.3559681 (95)	total: 9.81s	remaining: 16.6s
# 371:	learn: 0.3157288	test: 0.3601541	best: 0.3559681 (95)	total: 9.83s	remaining: 16.6s
# 372:	learn: 0.3156543	test: 0.3601988	best: 0.3559681 (95)	total: 9.85s	remaining: 16.6s
# 373:	learn: 0.3156160	test: 0.3602058	best: 0.3559681 (95)	total: 9.88s	remaining: 16.5s
# 374:	learn: 0.3155172	test: 0.3602162	best: 0.3559681 (95)	total: 9.9s	remaining: 16.5s
# 375:	learn: 0.3155057	test: 0.3602084	best: 0.3559681 (95)	total: 9.92s	remaining: 16.5s
# 376:	learn: 0.3154299	test: 0.3602226	best: 0.3559681 (95)	total: 9.94s	remaining: 16.4s
# 377:	learn: 0.3154012	test: 0.3602257	best: 0.3559681 (95)	total: 9.97s	remaining: 16.4s
# 378:	learn: 0.3153592	test: 0.3602420	best: 0.3559681 (95)	total: 9.99s	remaining: 16.4s
# 379:	learn: 0.3152404	test: 0.3602753	best: 0.3559681 (95)	total: 10s	remaining: 16.4s
# 380:	learn: 0.3151401	test: 0.3603648	best: 0.3559681 (95)	total: 10.1s	remaining: 16.3s
# 381:	learn: 0.3150752	test: 0.3603419	best: 0.3559681 (95)	total: 10.1s	remaining: 16.3s
# 382:	learn: 0.3150517	test: 0.3603422	best: 0.3559681 (95)	total: 10.1s	remaining: 16.3s
# 383:	learn: 0.3149368	test: 0.3604056	best: 0.3559681 (95)	total: 10.1s	remaining: 16.2s
# 384:	learn: 0.3148856	test: 0.3604278	best: 0.3559681 (95)	total: 10.1s	remaining: 16.2s
# 385:	learn: 0.3148576	test: 0.3604369	best: 0.3559681 (95)	total: 10.2s	remaining: 16.2s
# 386:	learn: 0.3147881	test: 0.3604405	best: 0.3559681 (95)	total: 10.2s	remaining: 16.1s
# 387:	learn: 0.3146899	test: 0.3604093	best: 0.3559681 (95)	total: 10.2s	remaining: 16.1s
# 388:	learn: 0.3146520	test: 0.3604331	best: 0.3559681 (95)	total: 10.2s	remaining: 16.1s
# 389:	learn: 0.3146123	test: 0.3604322	best: 0.3559681 (95)	total: 10.2s	remaining: 16s
# 390:	learn: 0.3145491	test: 0.3604928	best: 0.3559681 (95)	total: 10.3s	remaining: 16s
# 391:	learn: 0.3144524	test: 0.3605774	best: 0.3559681 (95)	total: 10.3s	remaining: 16s
# 392:	learn: 0.3144376	test: 0.3605767	best: 0.3559681 (95)	total: 10.3s	remaining: 15.9s
# 393:	learn: 0.3144062	test: 0.3605978	best: 0.3559681 (95)	total: 10.3s	remaining: 15.9s
# 394:	learn: 0.3143782	test: 0.3605920	best: 0.3559681 (95)	total: 10.4s	remaining: 15.9s
# 395:	learn: 0.3143072	test: 0.3606811	best: 0.3559681 (95)	total: 10.4s	remaining: 15.8s
# 396:	learn: 0.3142794	test: 0.3606544	best: 0.3559681 (95)	total: 10.4s	remaining: 15.8s
# 397:	learn: 0.3142450	test: 0.3607057	best: 0.3559681 (95)	total: 10.4s	remaining: 15.8s
# 398:	learn: 0.3142166	test: 0.3607244	best: 0.3559681 (95)	total: 10.4s	remaining: 15.7s
# 399:	learn: 0.3141493	test: 0.3606967	best: 0.3559681 (95)	total: 10.5s	remaining: 15.7s
# 400:	learn: 0.3140413	test: 0.3607084	best: 0.3559681 (95)	total: 10.5s	remaining: 15.7s
# 401:	learn: 0.3139961	test: 0.3606926	best: 0.3559681 (95)	total: 10.5s	remaining: 15.6s
# 402:	learn: 0.3139273	test: 0.3607152	best: 0.3559681 (95)	total: 10.5s	remaining: 15.6s
# 403:	learn: 0.3139110	test: 0.3607183	best: 0.3559681 (95)	total: 10.6s	remaining: 15.6s
# 404:	learn: 0.3138640	test: 0.3607283	best: 0.3559681 (95)	total: 10.6s	remaining: 15.5s
# 405:	learn: 0.3138304	test: 0.3607290	best: 0.3559681 (95)	total: 10.6s	remaining: 15.5s
# 406:	learn: 0.3137440	test: 0.3607675	best: 0.3559681 (95)	total: 10.6s	remaining: 15.5s
# 407:	learn: 0.3137192	test: 0.3607941	best: 0.3559681 (95)	total: 10.6s	remaining: 15.4s
# 408:	learn: 0.3135949	test: 0.3607767	best: 0.3559681 (95)	total: 10.7s	remaining: 15.4s
# 409:	learn: 0.3135604	test: 0.3607608	best: 0.3559681 (95)	total: 10.7s	remaining: 15.4s
# 410:	learn: 0.3134815	test: 0.3607860	best: 0.3559681 (95)	total: 10.7s	remaining: 15.4s
# 411:	learn: 0.3134040	test: 0.3607875	best: 0.3559681 (95)	total: 10.7s	remaining: 15.3s
# 412:	learn: 0.3133819	test: 0.3607760	best: 0.3559681 (95)	total: 10.8s	remaining: 15.3s
# 413:	learn: 0.3133318	test: 0.3607909	best: 0.3559681 (95)	total: 10.8s	remaining: 15.3s
# 414:	learn: 0.3133031	test: 0.3608059	best: 0.3559681 (95)	total: 10.8s	remaining: 15.2s
# 415:	learn: 0.3131821	test: 0.3608190	best: 0.3559681 (95)	total: 10.8s	remaining: 15.2s
# 416:	learn: 0.3131251	test: 0.3607898	best: 0.3559681 (95)	total: 10.8s	remaining: 15.2s
# 417:	learn: 0.3131095	test: 0.3608068	best: 0.3559681 (95)	total: 10.9s	remaining: 15.1s
# 418:	learn: 0.3130674	test: 0.3607989	best: 0.3559681 (95)	total: 10.9s	remaining: 15.1s
# 419:	learn: 0.3129673	test: 0.3608232	best: 0.3559681 (95)	total: 10.9s	remaining: 15.1s
# 420:	learn: 0.3129522	test: 0.3608258	best: 0.3559681 (95)	total: 10.9s	remaining: 15s
# 421:	learn: 0.3128839	test: 0.3608273	best: 0.3559681 (95)	total: 10.9s	remaining: 15s
# 422:	learn: 0.3128092	test: 0.3608471	best: 0.3559681 (95)	total: 11s	remaining: 15s
# 423:	learn: 0.3127253	test: 0.3608394	best: 0.3559681 (95)	total: 11s	remaining: 14.9s
# 424:	learn: 0.3126995	test: 0.3608613	best: 0.3559681 (95)	total: 11s	remaining: 14.9s
# 425:	learn: 0.3126860	test: 0.3608588	best: 0.3559681 (95)	total: 11.1s	remaining: 14.9s
# 426:	learn: 0.3126812	test: 0.3608522	best: 0.3559681 (95)	total: 11.1s	remaining: 14.9s
# 427:	learn: 0.3125972	test: 0.3608783	best: 0.3559681 (95)	total: 11.1s	remaining: 14.8s
# 428:	learn: 0.3125466	test: 0.3609123	best: 0.3559681 (95)	total: 11.1s	remaining: 14.8s
# 429:	learn: 0.3125320	test: 0.3609134	best: 0.3559681 (95)	total: 11.1s	remaining: 14.8s
# 430:	learn: 0.3124235	test: 0.3609529	best: 0.3559681 (95)	total: 11.2s	remaining: 14.7s
# 431:	learn: 0.3123532	test: 0.3609861	best: 0.3559681 (95)	total: 11.2s	remaining: 14.7s
# 432:	learn: 0.3122961	test: 0.3610123	best: 0.3559681 (95)	total: 11.2s	remaining: 14.7s
# 433:	learn: 0.3122211	test: 0.3610160	best: 0.3559681 (95)	total: 11.2s	remaining: 14.7s
# 434:	learn: 0.3121534	test: 0.3610455	best: 0.3559681 (95)	total: 11.3s	remaining: 14.6s
# 435:	learn: 0.3121154	test: 0.3610823	best: 0.3559681 (95)	total: 11.3s	remaining: 14.6s
# 436:	learn: 0.3120900	test: 0.3610913	best: 0.3559681 (95)	total: 11.3s	remaining: 14.6s
# 437:	learn: 0.3120162	test: 0.3610985	best: 0.3559681 (95)	total: 11.3s	remaining: 14.5s
# 438:	learn: 0.3119532	test: 0.3611665	best: 0.3559681 (95)	total: 11.3s	remaining: 14.5s
# 439:	learn: 0.3119011	test: 0.3611820	best: 0.3559681 (95)	total: 11.4s	remaining: 14.5s
# 440:	learn: 0.3118352	test: 0.3612192	best: 0.3559681 (95)	total: 11.4s	remaining: 14.4s
# 441:	learn: 0.3118094	test: 0.3612341	best: 0.3559681 (95)	total: 11.4s	remaining: 14.4s
# 442:	learn: 0.3117762	test: 0.3612444	best: 0.3559681 (95)	total: 11.4s	remaining: 14.4s
# 443:	learn: 0.3117150	test: 0.3612586	best: 0.3559681 (95)	total: 11.4s	remaining: 14.3s
# 444:	learn: 0.3116543	test: 0.3613305	best: 0.3559681 (95)	total: 11.5s	remaining: 14.3s
# 445:	learn: 0.3116238	test: 0.3613170	best: 0.3559681 (95)	total: 11.5s	remaining: 14.3s
# 446:	learn: 0.3115905	test: 0.3613200	best: 0.3559681 (95)	total: 11.5s	remaining: 14.3s
# 447:	learn: 0.3115343	test: 0.3613399	best: 0.3559681 (95)	total: 11.5s	remaining: 14.2s
# 448:	learn: 0.3115243	test: 0.3613382	best: 0.3559681 (95)	total: 11.6s	remaining: 14.2s
# 449:	learn: 0.3114264	test: 0.3613686	best: 0.3559681 (95)	total: 11.6s	remaining: 14.2s
# 450:	learn: 0.3113678	test: 0.3613260	best: 0.3559681 (95)	total: 11.6s	remaining: 14.1s
# 451:	learn: 0.3112490	test: 0.3613647	best: 0.3559681 (95)	total: 11.6s	remaining: 14.1s
# 452:	learn: 0.3111690	test: 0.3614202	best: 0.3559681 (95)	total: 11.7s	remaining: 14.1s
# 453:	learn: 0.3111156	test: 0.3614015	best: 0.3559681 (95)	total: 11.7s	remaining: 14s
# 454:	learn: 0.3110584	test: 0.3614186	best: 0.3559681 (95)	total: 11.7s	remaining: 14s
# 455:	learn: 0.3110087	test: 0.3614203	best: 0.3559681 (95)	total: 11.7s	remaining: 14s
# 456:	learn: 0.3108868	test: 0.3613456	best: 0.3559681 (95)	total: 11.7s	remaining: 14s
# 457:	learn: 0.3108704	test: 0.3613437	best: 0.3559681 (95)	total: 11.8s	remaining: 14s
# 458:	learn: 0.3108482	test: 0.3613428	best: 0.3559681 (95)	total: 11.9s	remaining: 14.1s
# 459:	learn: 0.3107611	test: 0.3614183	best: 0.3559681 (95)	total: 12s	remaining: 14.1s
# 460:	learn: 0.3107414	test: 0.3614181	best: 0.3559681 (95)	total: 12.1s	remaining: 14.2s
# 461:	learn: 0.3107185	test: 0.3614256	best: 0.3559681 (95)	total: 12.2s	remaining: 14.2s
# 462:	learn: 0.3106842	test: 0.3614521	best: 0.3559681 (95)	total: 12.3s	remaining: 14.3s
# 463:	learn: 0.3105876	test: 0.3614831	best: 0.3559681 (95)	total: 12.4s	remaining: 14.3s
# 464:	learn: 0.3105414	test: 0.3615277	best: 0.3559681 (95)	total: 12.5s	remaining: 14.4s
# 465:	learn: 0.3104702	test: 0.3615092	best: 0.3559681 (95)	total: 12.6s	remaining: 14.4s
# 466:	learn: 0.3104427	test: 0.3615441	best: 0.3559681 (95)	total: 12.6s	remaining: 14.4s
# 467:	learn: 0.3103508	test: 0.3615403	best: 0.3559681 (95)	total: 12.8s	remaining: 14.5s
# 468:	learn: 0.3103190	test: 0.3615437	best: 0.3559681 (95)	total: 12.8s	remaining: 14.5s
# 469:	learn: 0.3102957	test: 0.3615506	best: 0.3559681 (95)	total: 12.8s	remaining: 14.5s
# 470:	learn: 0.3101882	test: 0.3616324	best: 0.3559681 (95)	total: 12.9s	remaining: 14.4s
# 471:	learn: 0.3101668	test: 0.3616354	best: 0.3559681 (95)	total: 12.9s	remaining: 14.4s
# 472:	learn: 0.3100717	test: 0.3616306	best: 0.3559681 (95)	total: 12.9s	remaining: 14.4s
# 473:	learn: 0.3100376	test: 0.3616482	best: 0.3559681 (95)	total: 12.9s	remaining: 14.3s
# 474:	learn: 0.3100206	test: 0.3616365	best: 0.3559681 (95)	total: 12.9s	remaining: 14.3s
# 475:	learn: 0.3099609	test: 0.3616452	best: 0.3559681 (95)	total: 13s	remaining: 14.3s
# 476:	learn: 0.3099070	test: 0.3616454	best: 0.3559681 (95)	total: 13s	remaining: 14.2s
# 477:	learn: 0.3097938	test: 0.3617061	best: 0.3559681 (95)	total: 13s	remaining: 14.2s
# 478:	learn: 0.3097686	test: 0.3617390	best: 0.3559681 (95)	total: 13s	remaining: 14.2s
# 479:	learn: 0.3096650	test: 0.3617590	best: 0.3559681 (95)	total: 13.1s	remaining: 14.1s
# 480:	learn: 0.3096333	test: 0.3617478	best: 0.3559681 (95)	total: 13.1s	remaining: 14.1s
# 481:	learn: 0.3095694	test: 0.3617735	best: 0.3559681 (95)	total: 13.1s	remaining: 14.1s
# 482:	learn: 0.3095490	test: 0.3617845	best: 0.3559681 (95)	total: 13.1s	remaining: 14s
# 483:	learn: 0.3094067	test: 0.3618869	best: 0.3559681 (95)	total: 13.2s	remaining: 14s
# 484:	learn: 0.3093565	test: 0.3619352	best: 0.3559681 (95)	total: 13.2s	remaining: 14s
# 485:	learn: 0.3093014	test: 0.3619449	best: 0.3559681 (95)	total: 13.2s	remaining: 14s
# 486:	learn: 0.3092848	test: 0.3619529	best: 0.3559681 (95)	total: 13.2s	remaining: 13.9s
# 487:	learn: 0.3092667	test: 0.3619599	best: 0.3559681 (95)	total: 13.3s	remaining: 13.9s
# 488:	learn: 0.3092364	test: 0.3619801	best: 0.3559681 (95)	total: 13.3s	remaining: 13.9s
# 489:	learn: 0.3091338	test: 0.3620067	best: 0.3559681 (95)	total: 13.3s	remaining: 13.8s
# 490:	learn: 0.3091179	test: 0.3620004	best: 0.3559681 (95)	total: 13.3s	remaining: 13.8s
# 491:	learn: 0.3090565	test: 0.3619946	best: 0.3559681 (95)	total: 13.3s	remaining: 13.8s
# 492:	learn: 0.3090267	test: 0.3619803	best: 0.3559681 (95)	total: 13.4s	remaining: 13.7s
# 493:	learn: 0.3089838	test: 0.3619943	best: 0.3559681 (95)	total: 13.4s	remaining: 13.7s
# 494:	learn: 0.3089429	test: 0.3619628	best: 0.3559681 (95)	total: 13.4s	remaining: 13.7s
# 495:	learn: 0.3089300	test: 0.3619522	best: 0.3559681 (95)	total: 13.4s	remaining: 13.6s
# 496:	learn: 0.3088758	test: 0.3619462	best: 0.3559681 (95)	total: 13.5s	remaining: 13.6s
# 497:	learn: 0.3088173	test: 0.3619724	best: 0.3559681 (95)	total: 13.5s	remaining: 13.6s
# 498:	learn: 0.3087592	test: 0.3619545	best: 0.3559681 (95)	total: 13.5s	remaining: 13.6s
# 499:	learn: 0.3087389	test: 0.3619483	best: 0.3559681 (95)	total: 13.5s	remaining: 13.5s
# 500:	learn: 0.3086573	test: 0.3620301	best: 0.3559681 (95)	total: 13.5s	remaining: 13.5s
# 501:	learn: 0.3085954	test: 0.3620924	best: 0.3559681 (95)	total: 13.6s	remaining: 13.5s
# 502:	learn: 0.3085788	test: 0.3621016	best: 0.3559681 (95)	total: 13.6s	remaining: 13.4s
# 503:	learn: 0.3084886	test: 0.3621122	best: 0.3559681 (95)	total: 13.6s	remaining: 13.4s
# 504:	learn: 0.3084128	test: 0.3621183	best: 0.3559681 (95)	total: 13.6s	remaining: 13.4s
# 505:	learn: 0.3083648	test: 0.3621234	best: 0.3559681 (95)	total: 13.7s	remaining: 13.3s
# 506:	learn: 0.3082499	test: 0.3621504	best: 0.3559681 (95)	total: 13.7s	remaining: 13.3s
# 507:	learn: 0.3082406	test: 0.3621615	best: 0.3559681 (95)	total: 13.7s	remaining: 13.3s
# 508:	learn: 0.3081698	test: 0.3621699	best: 0.3559681 (95)	total: 13.7s	remaining: 13.2s
# 509:	learn: 0.3080958	test: 0.3621251	best: 0.3559681 (95)	total: 13.7s	remaining: 13.2s
# 510:	learn: 0.3080417	test: 0.3621581	best: 0.3559681 (95)	total: 13.8s	remaining: 13.2s
# 511:	learn: 0.3079976	test: 0.3621960	best: 0.3559681 (95)	total: 13.8s	remaining: 13.1s
# 512:	learn: 0.3079476	test: 0.3622217	best: 0.3559681 (95)	total: 13.8s	remaining: 13.1s
# 513:	learn: 0.3079446	test: 0.3622208	best: 0.3559681 (95)	total: 13.8s	remaining: 13.1s
# 514:	learn: 0.3079015	test: 0.3622308	best: 0.3559681 (95)	total: 13.9s	remaining: 13s
# 515:	learn: 0.3078680	test: 0.3622265	best: 0.3559681 (95)	total: 13.9s	remaining: 13s
# 516:	learn: 0.3078382	test: 0.3622222	best: 0.3559681 (95)	total: 13.9s	remaining: 13s
# 517:	learn: 0.3077181	test: 0.3622898	best: 0.3559681 (95)	total: 13.9s	remaining: 13s
# 518:	learn: 0.3076996	test: 0.3622842	best: 0.3559681 (95)	total: 13.9s	remaining: 12.9s
# 519:	learn: 0.3076567	test: 0.3622861	best: 0.3559681 (95)	total: 14s	remaining: 12.9s
# 520:	learn: 0.3076219	test: 0.3622834	best: 0.3559681 (95)	total: 14s	remaining: 12.9s
# 521:	learn: 0.3075831	test: 0.3623190	best: 0.3559681 (95)	total: 14s	remaining: 12.8s
# 522:	learn: 0.3075346	test: 0.3622857	best: 0.3559681 (95)	total: 14s	remaining: 12.8s
# 523:	learn: 0.3075150	test: 0.3622989	best: 0.3559681 (95)	total: 14s	remaining: 12.8s
# 524:	learn: 0.3074905	test: 0.3623225	best: 0.3559681 (95)	total: 14.1s	remaining: 12.7s
# 525:	learn: 0.3074648	test: 0.3623405	best: 0.3559681 (95)	total: 14.1s	remaining: 12.7s
# 526:	learn: 0.3073826	test: 0.3622865	best: 0.3559681 (95)	total: 14.1s	remaining: 12.7s
# 527:	learn: 0.3073320	test: 0.3622873	best: 0.3559681 (95)	total: 14.1s	remaining: 12.6s
# 528:	learn: 0.3073064	test: 0.3622643	best: 0.3559681 (95)	total: 14.2s	remaining: 12.6s
# 529:	learn: 0.3072775	test: 0.3622756	best: 0.3559681 (95)	total: 14.2s	remaining: 12.6s
# 530:	learn: 0.3072479	test: 0.3622573	best: 0.3559681 (95)	total: 14.3s	remaining: 12.6s
# 531:	learn: 0.3071027	test: 0.3622692	best: 0.3559681 (95)	total: 14.3s	remaining: 12.6s
# 532:	learn: 0.3070449	test: 0.3622724	best: 0.3559681 (95)	total: 14.4s	remaining: 12.6s
# 533:	learn: 0.3070076	test: 0.3622835	best: 0.3559681 (95)	total: 14.4s	remaining: 12.6s
# 534:	learn: 0.3069653	test: 0.3622960	best: 0.3559681 (95)	total: 14.4s	remaining: 12.6s
# 535:	learn: 0.3069504	test: 0.3623024	best: 0.3559681 (95)	total: 14.5s	remaining: 12.5s
# 536:	learn: 0.3069331	test: 0.3622935	best: 0.3559681 (95)	total: 14.5s	remaining: 12.5s
# 537:	learn: 0.3069125	test: 0.3623211	best: 0.3559681 (95)	total: 14.6s	remaining: 12.5s
# 538:	learn: 0.3068697	test: 0.3623127	best: 0.3559681 (95)	total: 14.6s	remaining: 12.5s
# 539:	learn: 0.3067829	test: 0.3623083	best: 0.3559681 (95)	total: 14.7s	remaining: 12.5s
# 540:	learn: 0.3067337	test: 0.3623261	best: 0.3559681 (95)	total: 14.7s	remaining: 12.5s
# 541:	learn: 0.3067151	test: 0.3623257	best: 0.3559681 (95)	total: 14.7s	remaining: 12.4s
# ...
# 821:	learn: 0.2941006	test: 0.3649679	best: 0.3559681 (95)	total: 22.3s	remaining: 4.82s
# 822:	learn: 0.2940936	test: 0.3649663	best: 0.3559681 (95)	total: 22.3s	remaining: 4.79s
# 823:	learn: 0.2940747	test: 0.3649616	best: 0.3559681 (95)	total: 22.3s	remaining: 4.76s
# 824:	learn: 0.2940698	test: 0.3649613	best: 0.3559681 (95)	total: 22.3s	remaining: 4.74s
# 825:	learn: 0.2940258	test: 0.3649639	best: 0.3559681 (95)	total: 22.3s	remaining: 4.71s
# 826:	learn: 0.2939421	test: 0.3648993	best: 0.3559681 (95)	total: 22.4s	remaining: 4.68s
# 827:	learn: 0.2938895	test: 0.3649070	best: 0.3559681 (95)	total: 22.4s	remaining: 4.65s
# 828:	learn: 0.2938421	test: 0.3649200	best: 0.3559681 (95)	total: 22.4s	remaining: 4.62s
# 829:	learn: 0.2937999	test: 0.3649212	best: 0.3559681 (95)	total: 22.4s	remaining: 4.59s
# 830:	learn: 0.2937681	test: 0.3649429	best: 0.3559681 (95)	total: 22.5s	remaining: 4.57s
# 831:	learn: 0.2937396	test: 0.3649520	best: 0.3559681 (95)	total: 22.5s	remaining: 4.54s
# 832:	learn: 0.2937266	test: 0.3649543	best: 0.3559681 (95)	total: 22.5s	remaining: 4.51s
# 833:	learn: 0.2936973	test: 0.3649579	best: 0.3559681 (95)	total: 22.5s	remaining: 4.48s
# 834:	learn: 0.2936444	test: 0.3649634	best: 0.3559681 (95)	total: 22.5s	remaining: 4.46s
# 835:	learn: 0.2935908	test: 0.3649409	best: 0.3559681 (95)	total: 22.6s	remaining: 4.43s
# 836:	learn: 0.2935601	test: 0.3649489	best: 0.3559681 (95)	total: 22.6s	remaining: 4.4s
# 837:	learn: 0.2935311	test: 0.3649527	best: 0.3559681 (95)	total: 22.6s	remaining: 4.37s
# 838:	learn: 0.2935202	test: 0.3649851	best: 0.3559681 (95)	total: 22.7s	remaining: 4.35s
# 839:	learn: 0.2933802	test: 0.3650926	best: 0.3559681 (95)	total: 22.7s	remaining: 4.32s
# 840:	learn: 0.2933553	test: 0.3650870	best: 0.3559681 (95)	total: 22.7s	remaining: 4.29s
# 841:	learn: 0.2933457	test: 0.3651054	best: 0.3559681 (95)	total: 22.7s	remaining: 4.26s
# 842:	learn: 0.2933259	test: 0.3651245	best: 0.3559681 (95)	total: 22.8s	remaining: 4.24s
# 843:	learn: 0.2933220	test: 0.3651090	best: 0.3559681 (95)	total: 22.8s	remaining: 4.21s
# 844:	learn: 0.2932850	test: 0.3651451	best: 0.3559681 (95)	total: 22.8s	remaining: 4.18s
# 845:	learn: 0.2932187	test: 0.3651932	best: 0.3559681 (95)	total: 22.8s	remaining: 4.15s
# 846:	learn: 0.2931772	test: 0.3652342	best: 0.3559681 (95)	total: 22.8s	remaining: 4.12s
# 847:	learn: 0.2931744	test: 0.3652315	best: 0.3559681 (95)	total: 22.9s	remaining: 4.1s
# 848:	learn: 0.2931126	test: 0.3652905	best: 0.3559681 (95)	total: 22.9s	remaining: 4.07s
# 849:	learn: 0.2930974	test: 0.3653008	best: 0.3559681 (95)	total: 22.9s	remaining: 4.04s
# 850:	learn: 0.2930786	test: 0.3653178	best: 0.3559681 (95)	total: 22.9s	remaining: 4.01s
# 851:	learn: 0.2930474	test: 0.3653664	best: 0.3559681 (95)	total: 22.9s	remaining: 3.98s
# 852:	learn: 0.2929933	test: 0.3654016	best: 0.3559681 (95)	total: 23s	remaining: 3.96s
# 853:	learn: 0.2929767	test: 0.3654266	best: 0.3559681 (95)	total: 23s	remaining: 3.93s
# 854:	learn: 0.2929699	test: 0.3654236	best: 0.3559681 (95)	total: 23s	remaining: 3.9s
# 855:	learn: 0.2929547	test: 0.3654131	best: 0.3559681 (95)	total: 23s	remaining: 3.87s
# 856:	learn: 0.2929110	test: 0.3653731	best: 0.3559681 (95)	total: 23.1s	remaining: 3.85s
# 857:	learn: 0.2928922	test: 0.3653736	best: 0.3559681 (95)	total: 23.1s	remaining: 3.82s
# 858:	learn: 0.2928490	test: 0.3653855	best: 0.3559681 (95)	total: 23.1s	remaining: 3.79s
# 859:	learn: 0.2927509	test: 0.3654109	best: 0.3559681 (95)	total: 23.1s	remaining: 3.76s
# 860:	learn: 0.2927202	test: 0.3654536	best: 0.3559681 (95)	total: 23.1s	remaining: 3.74s
# 861:	learn: 0.2927014	test: 0.3654835	best: 0.3559681 (95)	total: 23.2s	remaining: 3.71s
# 862:	learn: 0.2926707	test: 0.3654887	best: 0.3559681 (95)	total: 23.2s	remaining: 3.68s
# 863:	learn: 0.2926563	test: 0.3654767	best: 0.3559681 (95)	total: 23.2s	remaining: 3.65s
# 864:	learn: 0.2926369	test: 0.3654595	best: 0.3559681 (95)	total: 23.2s	remaining: 3.63s
# 865:	learn: 0.2925942	test: 0.3654926	best: 0.3559681 (95)	total: 23.3s	remaining: 3.6s
# 866:	learn: 0.2925884	test: 0.3654997	best: 0.3559681 (95)	total: 23.3s	remaining: 3.57s
# 867:	learn: 0.2925766	test: 0.3655075	best: 0.3559681 (95)	total: 23.3s	remaining: 3.54s
# 868:	learn: 0.2925577	test: 0.3655115	best: 0.3559681 (95)	total: 23.3s	remaining: 3.52s
# 869:	learn: 0.2925524	test: 0.3655077	best: 0.3559681 (95)	total: 23.3s	remaining: 3.49s
# 870:	learn: 0.2925464	test: 0.3654901	best: 0.3559681 (95)	total: 23.4s	remaining: 3.46s
# 871:	learn: 0.2925032	test: 0.3654629	best: 0.3559681 (95)	total: 23.4s	remaining: 3.43s
# 872:	learn: 0.2924374	test: 0.3654819	best: 0.3559681 (95)	total: 23.4s	remaining: 3.41s
# 873:	learn: 0.2923968	test: 0.3654942	best: 0.3559681 (95)	total: 23.4s	remaining: 3.38s
# 874:	learn: 0.2923599	test: 0.3654952	best: 0.3559681 (95)	total: 23.5s	remaining: 3.35s
# 875:	learn: 0.2923431	test: 0.3655135	best: 0.3559681 (95)	total: 23.5s	remaining: 3.32s
# 876:	learn: 0.2923279	test: 0.3655067	best: 0.3559681 (95)	total: 23.5s	remaining: 3.3s
# 877:	learn: 0.2923070	test: 0.3654995	best: 0.3559681 (95)	total: 23.5s	remaining: 3.27s
# 878:	learn: 0.2922877	test: 0.3654900	best: 0.3559681 (95)	total: 23.5s	remaining: 3.24s
# 879:	learn: 0.2922671	test: 0.3655232	best: 0.3559681 (95)	total: 23.6s	remaining: 3.21s
# 880:	learn: 0.2922512	test: 0.3655192	best: 0.3559681 (95)	total: 23.6s	remaining: 3.19s
# 881:	learn: 0.2922495	test: 0.3655228	best: 0.3559681 (95)	total: 23.6s	remaining: 3.16s
# 882:	learn: 0.2921420	test: 0.3655442	best: 0.3559681 (95)	total: 23.6s	remaining: 3.13s
# 883:	learn: 0.2921276	test: 0.3655468	best: 0.3559681 (95)	total: 23.7s	remaining: 3.1s
# 884:	learn: 0.2921152	test: 0.3655508	best: 0.3559681 (95)	total: 23.7s	remaining: 3.08s
# 885:	learn: 0.2921008	test: 0.3655459	best: 0.3559681 (95)	total: 23.7s	remaining: 3.05s
# 886:	learn: 0.2920632	test: 0.3655469	best: 0.3559681 (95)	total: 23.7s	remaining: 3.02s
# 887:	learn: 0.2919739	test: 0.3656075	best: 0.3559681 (95)	total: 23.8s	remaining: 3s
# 888:	learn: 0.2919498	test: 0.3656205	best: 0.3559681 (95)	total: 23.8s	remaining: 2.97s
# 889:	learn: 0.2919038	test: 0.3656264	best: 0.3559681 (95)	total: 23.8s	remaining: 2.94s
# 890:	learn: 0.2918779	test: 0.3656409	best: 0.3559681 (95)	total: 23.8s	remaining: 2.92s
# 891:	learn: 0.2918588	test: 0.3656379	best: 0.3559681 (95)	total: 23.9s	remaining: 2.89s
# 892:	learn: 0.2917987	test: 0.3656341	best: 0.3559681 (95)	total: 23.9s	remaining: 2.86s
# 893:	learn: 0.2917325	test: 0.3656413	best: 0.3559681 (95)	total: 23.9s	remaining: 2.83s
# 894:	learn: 0.2916608	test: 0.3656626	best: 0.3559681 (95)	total: 23.9s	remaining: 2.81s
# 895:	learn: 0.2916399	test: 0.3656872	best: 0.3559681 (95)	total: 23.9s	remaining: 2.78s
# 896:	learn: 0.2915918	test: 0.3657143	best: 0.3559681 (95)	total: 24s	remaining: 2.75s
# 897:	learn: 0.2915685	test: 0.3656944	best: 0.3559681 (95)	total: 24s	remaining: 2.73s
# 898:	learn: 0.2915320	test: 0.3657351	best: 0.3559681 (95)	total: 24s	remaining: 2.7s
# 899:	learn: 0.2915170	test: 0.3657491	best: 0.3559681 (95)	total: 24s	remaining: 2.67s
# 900:	learn: 0.2914961	test: 0.3657860	best: 0.3559681 (95)	total: 24.1s	remaining: 2.64s
# 901:	learn: 0.2914499	test: 0.3657909	best: 0.3559681 (95)	total: 24.1s	remaining: 2.62s
# 902:	learn: 0.2913740	test: 0.3657721	best: 0.3559681 (95)	total: 24.1s	remaining: 2.59s
# 903:	learn: 0.2913138	test: 0.3657846	best: 0.3559681 (95)	total: 24.1s	remaining: 2.56s
# 904:	learn: 0.2912569	test: 0.3657801	best: 0.3559681 (95)	total: 24.1s	remaining: 2.53s
# 905:	learn: 0.2912067	test: 0.3657976	best: 0.3559681 (95)	total: 24.2s	remaining: 2.51s
# 906:	learn: 0.2911831	test: 0.3658044	best: 0.3559681 (95)	total: 24.2s	remaining: 2.48s
# 907:	learn: 0.2911708	test: 0.3658108	best: 0.3559681 (95)	total: 24.2s	remaining: 2.45s
# 908:	learn: 0.2911251	test: 0.3658481	best: 0.3559681 (95)	total: 24.2s	remaining: 2.43s
# 909:	learn: 0.2910895	test: 0.3658437	best: 0.3559681 (95)	total: 24.3s	remaining: 2.4s
# 910:	learn: 0.2910296	test: 0.3658551	best: 0.3559681 (95)	total: 24.3s	remaining: 2.37s
# 911:	learn: 0.2909892	test: 0.3658543	best: 0.3559681 (95)	total: 24.3s	remaining: 2.34s
# 912:	learn: 0.2909622	test: 0.3658852	best: 0.3559681 (95)	total: 24.3s	remaining: 2.32s
# 913:	learn: 0.2909551	test: 0.3658862	best: 0.3559681 (95)	total: 24.3s	remaining: 2.29s
# 914:	learn: 0.2908891	test: 0.3658689	best: 0.3559681 (95)	total: 24.4s	remaining: 2.26s
# 915:	learn: 0.2908631	test: 0.3658886	best: 0.3559681 (95)	total: 24.4s	remaining: 2.24s
# 916:	learn: 0.2907596	test: 0.3659215	best: 0.3559681 (95)	total: 24.4s	remaining: 2.21s
# 917:	learn: 0.2907338	test: 0.3659330	best: 0.3559681 (95)	total: 24.4s	remaining: 2.18s
# 918:	learn: 0.2907223	test: 0.3659332	best: 0.3559681 (95)	total: 24.5s	remaining: 2.16s
# 919:	learn: 0.2906728	test: 0.3659207	best: 0.3559681 (95)	total: 24.5s	remaining: 2.13s
# 920:	learn: 0.2906247	test: 0.3659455	best: 0.3559681 (95)	total: 24.5s	remaining: 2.1s
# 921:	learn: 0.2905892	test: 0.3659415	best: 0.3559681 (95)	total: 24.5s	remaining: 2.08s
# 922:	learn: 0.2905724	test: 0.3659688	best: 0.3559681 (95)	total: 24.6s	remaining: 2.05s
# 923:	learn: 0.2905685	test: 0.3659655	best: 0.3559681 (95)	total: 24.6s	remaining: 2.02s
# 924:	learn: 0.2905324	test: 0.3659315	best: 0.3559681 (95)	total: 24.6s	remaining: 1.99s
# 925:	learn: 0.2904335	test: 0.3659597	best: 0.3559681 (95)	total: 24.6s	remaining: 1.97s
# 926:	learn: 0.2903906	test: 0.3659548	best: 0.3559681 (95)	total: 24.6s	remaining: 1.94s
# 927:	learn: 0.2903739	test: 0.3659695	best: 0.3559681 (95)	total: 24.7s	remaining: 1.91s
# 928:	learn: 0.2903267	test: 0.3659877	best: 0.3559681 (95)	total: 24.7s	remaining: 1.89s
# 929:	learn: 0.2902788	test: 0.3659717	best: 0.3559681 (95)	total: 24.7s	remaining: 1.86s
# 930:	learn: 0.2902267	test: 0.3660200	best: 0.3559681 (95)	total: 24.7s	remaining: 1.83s
# 931:	learn: 0.2902234	test: 0.3660287	best: 0.3559681 (95)	total: 24.8s	remaining: 1.81s
# 932:	learn: 0.2901597	test: 0.3661955	best: 0.3559681 (95)	total: 24.8s	remaining: 1.78s
# 933:	learn: 0.2901505	test: 0.3661954	best: 0.3559681 (95)	total: 24.8s	remaining: 1.75s
# 934:	learn: 0.2901016	test: 0.3662061	best: 0.3559681 (95)	total: 24.8s	remaining: 1.73s
# 935:	learn: 0.2899959	test: 0.3662233	best: 0.3559681 (95)	total: 24.9s	remaining: 1.7s
# 936:	learn: 0.2899508	test: 0.3662581	best: 0.3559681 (95)	total: 24.9s	remaining: 1.67s
# 937:	learn: 0.2899492	test: 0.3662604	best: 0.3559681 (95)	total: 24.9s	remaining: 1.65s
# 938:	learn: 0.2899435	test: 0.3662679	best: 0.3559681 (95)	total: 24.9s	remaining: 1.62s
# 939:	learn: 0.2899137	test: 0.3662925	best: 0.3559681 (95)	total: 24.9s	remaining: 1.59s
# 940:	learn: 0.2898525	test: 0.3663402	best: 0.3559681 (95)	total: 25s	remaining: 1.56s
# 941:	learn: 0.2898512	test: 0.3663369	best: 0.3559681 (95)	total: 25s	remaining: 1.54s
# 942:	learn: 0.2898389	test: 0.3663372	best: 0.3559681 (95)	total: 25s	remaining: 1.51s
# 943:	learn: 0.2898244	test: 0.3663328	best: 0.3559681 (95)	total: 25s	remaining: 1.48s
# 944:	learn: 0.2898144	test: 0.3663277	best: 0.3559681 (95)	total: 25s	remaining: 1.46s
# 945:	learn: 0.2897271	test: 0.3663174	best: 0.3559681 (95)	total: 25.1s	remaining: 1.43s
# 946:	learn: 0.2897139	test: 0.3663280	best: 0.3559681 (95)	total: 25.1s	remaining: 1.4s
# 947:	learn: 0.2896533	test: 0.3663260	best: 0.3559681 (95)	total: 25.1s	remaining: 1.38s
# 948:	learn: 0.2896346	test: 0.3663181	best: 0.3559681 (95)	total: 25.1s	remaining: 1.35s
# 949:	learn: 0.2896287	test: 0.3663283	best: 0.3559681 (95)	total: 25.1s	remaining: 1.32s
# 950:	learn: 0.2896232	test: 0.3663289	best: 0.3559681 (95)	total: 25.2s	remaining: 1.3s
# 951:	learn: 0.2895904	test: 0.3663120	best: 0.3559681 (95)	total: 25.2s	remaining: 1.27s
# 952:	learn: 0.2895467	test: 0.3663412	best: 0.3559681 (95)	total: 25.2s	remaining: 1.24s
# 953:	learn: 0.2895467	test: 0.3663412	best: 0.3559681 (95)	total: 25.2s	remaining: 1.22s
# 954:	learn: 0.2895368	test: 0.3663620	best: 0.3559681 (95)	total: 25.2s	remaining: 1.19s
# 955:	learn: 0.2894990	test: 0.3664012	best: 0.3559681 (95)	total: 25.3s	remaining: 1.16s
# 956:	learn: 0.2894239	test: 0.3664112	best: 0.3559681 (95)	total: 25.3s	remaining: 1.14s
# 957:	learn: 0.2893468	test: 0.3664621	best: 0.3559681 (95)	total: 25.3s	remaining: 1.11s
# 958:	learn: 0.2893142	test: 0.3664555	best: 0.3559681 (95)	total: 25.3s	remaining: 1.08s
# 959:	learn: 0.2892690	test: 0.3664788	best: 0.3559681 (95)	total: 25.4s	remaining: 1.06s
# 960:	learn: 0.2892339	test: 0.3664889	best: 0.3559681 (95)	total: 25.4s	remaining: 1.03s
# 961:	learn: 0.2892273	test: 0.3664890	best: 0.3559681 (95)	total: 25.4s	remaining: 1s
# 962:	learn: 0.2892189	test: 0.3664944	best: 0.3559681 (95)	total: 25.4s	remaining: 977ms
# 963:	learn: 0.2891317	test: 0.3665407	best: 0.3559681 (95)	total: 25.4s	remaining: 950ms
# 964:	learn: 0.2890935	test: 0.3665395	best: 0.3559681 (95)	total: 25.5s	remaining: 924ms
# 965:	learn: 0.2890509	test: 0.3665582	best: 0.3559681 (95)	total: 25.5s	remaining: 898ms
# 966:	learn: 0.2889772	test: 0.3665214	best: 0.3559681 (95)	total: 25.5s	remaining: 871ms
# 967:	learn: 0.2889744	test: 0.3665206	best: 0.3559681 (95)	total: 25.5s	remaining: 844ms
# 968:	learn: 0.2889695	test: 0.3665138	best: 0.3559681 (95)	total: 25.6s	remaining: 818ms
# 969:	learn: 0.2889362	test: 0.3665563	best: 0.3559681 (95)	total: 25.6s	remaining: 791ms
# 970:	learn: 0.2888913	test: 0.3665782	best: 0.3559681 (95)	total: 25.6s	remaining: 765ms
# 971:	learn: 0.2888700	test: 0.3665941	best: 0.3559681 (95)	total: 25.6s	remaining: 738ms
# 972:	learn: 0.2888170	test: 0.3665937	best: 0.3559681 (95)	total: 25.6s	remaining: 712ms
# 973:	learn: 0.2887114	test: 0.3665796	best: 0.3559681 (95)	total: 25.7s	remaining: 685ms
# 974:	learn: 0.2886595	test: 0.3665521	best: 0.3559681 (95)	total: 25.7s	remaining: 659ms
# 975:	learn: 0.2886430	test: 0.3665474	best: 0.3559681 (95)	total: 25.7s	remaining: 632ms
# 976:	learn: 0.2885937	test: 0.3665322	best: 0.3559681 (95)	total: 25.7s	remaining: 606ms
# 977:	learn: 0.2885804	test: 0.3665325	best: 0.3559681 (95)	total: 25.8s	remaining: 580ms
# 978:	learn: 0.2885644	test: 0.3665459	best: 0.3559681 (95)	total: 25.8s	remaining: 553ms
# 979:	learn: 0.2885556	test: 0.3665490	best: 0.3559681 (95)	total: 25.8s	remaining: 527ms
# 980:	learn: 0.2885338	test: 0.3665317	best: 0.3559681 (95)	total: 25.8s	remaining: 501ms
# 981:	learn: 0.2885125	test: 0.3665365	best: 0.3559681 (95)	total: 25.9s	remaining: 474ms
# 982:	learn: 0.2884968	test: 0.3665458	best: 0.3559681 (95)	total: 25.9s	remaining: 448ms
# 983:	learn: 0.2884706	test: 0.3665356	best: 0.3559681 (95)	total: 25.9s	remaining: 421ms
# 984:	learn: 0.2884422	test: 0.3665210	best: 0.3559681 (95)	total: 25.9s	remaining: 395ms
# 985:	learn: 0.2884132	test: 0.3665225	best: 0.3559681 (95)	total: 26s	remaining: 369ms
# 986:	learn: 0.2883476	test: 0.3665002	best: 0.3559681 (95)	total: 26s	remaining: 342ms
# 987:	learn: 0.2883462	test: 0.3664965	best: 0.3559681 (95)	total: 26s	remaining: 316ms
# 988:	learn: 0.2883015	test: 0.3665105	best: 0.3559681 (95)	total: 26s	remaining: 290ms
# 989:	learn: 0.2882156	test: 0.3664939	best: 0.3559681 (95)	total: 26.1s	remaining: 263ms
# 990:	learn: 0.2881704	test: 0.3665167	best: 0.3559681 (95)	total: 26.1s	remaining: 237ms
# 991:	learn: 0.2880447	test: 0.3665193	best: 0.3559681 (95)	total: 26.1s	remaining: 210ms
# 992:	learn: 0.2880366	test: 0.3665332	best: 0.3559681 (95)	total: 26.1s	remaining: 184ms
# 993:	learn: 0.2879850	test: 0.3665694	best: 0.3559681 (95)	total: 26.1s	remaining: 158ms
# 994:	learn: 0.2878934	test: 0.3666626	best: 0.3559681 (95)	total: 26.2s	remaining: 132ms
# 995:	learn: 0.2878557	test: 0.3666573	best: 0.3559681 (95)	total: 26.2s	remaining: 105ms
# 996:	learn: 0.2878398	test: 0.3666580	best: 0.3559681 (95)	total: 26.2s	remaining: 78.9ms
# 997:	learn: 0.2878079	test: 0.3666604	best: 0.3559681 (95)	total: 26.2s	remaining: 52.6ms
# 998:	learn: 0.2877908	test: 0.3666522	best: 0.3559681 (95)	total: 26.3s	remaining: 26.3ms
# 999:	learn: 0.2877740	test: 0.3666738	best: 0.3559681 (95)	total: 26.3s	remaining: 0us
#
# bestTest = 0.3559681217
# bestIteration = 95
#
# Shrink model to first 96 iterations.

# %%
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

# %%
print("\nRelatório de Classificação:\n", classification_report(y_test, y_pred, zero_division=0, digits=5))
# Out:
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0    0.83333   0.78902   0.81057      2313
#            1    0.85605   0.88828   0.87186      3267
#
#     accuracy                        0.84713      5580
#    macro avg    0.84469   0.83865   0.84122      5580
# weighted avg    0.84663   0.84713   0.84646      5580

# %% [markdown]
# # Treinamento

# %%
# Retorna o rótulo previsto para cada amostra (ex.: 0, 1, 2, 3, 4, 5).
proba = model.predict_proba(test_pool)[:, 1]
print(proba)
# Out:
# [0.93868664 0.94102196 0.00457511 ... 0.05231496 0.9582228  0.60466044]

# %%
# Retorna as probabilidades por classe para cada amostra.
pred = model.predict(test_pool)
print(pred)
# Out:
# [1 1 0 ... 0 1 1]

# %% [markdown]
# #Comparação SMOTE X BASE

# %%
sm = SMOTE(random_state=42)
X_tr_sm, y_tr_sm = sm.fit_resample(X_train, y_train)
model_sm = CatBoostClassifier()
model_sm.fit(X_tr_sm, y_tr_sm)
y_pred_sm = model_sm.predict(X_test)
print(classification_report(y_test, y_pred_sm, digits=3))
# Out:
# Learning rate set to 0.041504
# 0:	learn: 0.6587476	total: 9.88ms	remaining: 9.87s
# 1:	learn: 0.6306335	total: 22.1ms	remaining: 11s
# 2:	learn: 0.6049947	total: 33.5ms	remaining: 11.1s
# 3:	learn: 0.5811380	total: 44.8ms	remaining: 11.2s
# 4:	learn: 0.5594381	total: 56.9ms	remaining: 11.3s
# 5:	learn: 0.5405316	total: 78.7ms	remaining: 13s
# 6:	learn: 0.5230875	total: 88.3ms	remaining: 12.5s
# 7:	learn: 0.5069662	total: 96.9ms	remaining: 12s
# 8:	learn: 0.4928610	total: 106ms	remaining: 11.7s
# 9:	learn: 0.4806421	total: 115ms	remaining: 11.4s
# 10:	learn: 0.4688239	total: 124ms	remaining: 11.1s
# 11:	learn: 0.4583723	total: 133ms	remaining: 11s
# 12:	learn: 0.4488958	total: 143ms	remaining: 10.8s
# 13:	learn: 0.4396117	total: 152ms	remaining: 10.7s
# 14:	learn: 0.4316482	total: 162ms	remaining: 10.6s
# 15:	learn: 0.4256990	total: 171ms	remaining: 10.5s
# 16:	learn: 0.4186454	total: 180ms	remaining: 10.4s
# 17:	learn: 0.4126523	total: 190ms	remaining: 10.3s
# 18:	learn: 0.4070763	total: 203ms	remaining: 10.5s
# 19:	learn: 0.4020008	total: 211ms	remaining: 10.4s
# 20:	learn: 0.3978392	total: 220ms	remaining: 10.3s
# 21:	learn: 0.3935550	total: 229ms	remaining: 10.2s
# 22:	learn: 0.3896274	total: 239ms	remaining: 10.1s
# 23:	learn: 0.3863954	total: 247ms	remaining: 10.1s
# 24:	learn: 0.3832014	total: 256ms	remaining: 9.99s
# 25:	learn: 0.3802474	total: 265ms	remaining: 9.94s
# 26:	learn: 0.3774538	total: 274ms	remaining: 9.89s
# 27:	learn: 0.3747593	total: 290ms	remaining: 10.1s
# 28:	learn: 0.3724252	total: 319ms	remaining: 10.7s
# 29:	learn: 0.3699124	total: 340ms	remaining: 11s
# 30:	learn: 0.3679010	total: 368ms	remaining: 11.5s
# 31:	learn: 0.3659443	total: 390ms	remaining: 11.8s
# 32:	learn: 0.3639993	total: 412ms	remaining: 12.1s
# 33:	learn: 0.3621718	total: 423ms	remaining: 12s
# 34:	learn: 0.3604262	total: 448ms	remaining: 12.3s
# 35:	learn: 0.3589061	total: 476ms	remaining: 12.7s
# 36:	learn: 0.3571209	total: 501ms	remaining: 13s
# 37:	learn: 0.3559058	total: 529ms	remaining: 13.4s
# 38:	learn: 0.3545555	total: 542ms	remaining: 13.4s
# 39:	learn: 0.3532564	total: 554ms	remaining: 13.3s
# 40:	learn: 0.3519964	total: 566ms	remaining: 13.2s
# 41:	learn: 0.3508574	total: 580ms	remaining: 13.2s
# 42:	learn: 0.3497520	total: 593ms	remaining: 13.2s
# 43:	learn: 0.3486151	total: 622ms	remaining: 13.5s
# 44:	learn: 0.3474804	total: 649ms	remaining: 13.8s
# 45:	learn: 0.3464618	total: 672ms	remaining: 13.9s
# 46:	learn: 0.3453870	total: 696ms	remaining: 14.1s
# 47:	learn: 0.3443852	total: 721ms	remaining: 14.3s
# 48:	learn: 0.3435836	total: 740ms	remaining: 14.4s
# 49:	learn: 0.3426336	total: 767ms	remaining: 14.6s
# 50:	learn: 0.3417106	total: 795ms	remaining: 14.8s
# 51:	learn: 0.3410059	total: 818ms	remaining: 14.9s
# 52:	learn: 0.3402419	total: 850ms	remaining: 15.2s
# 53:	learn: 0.3393676	total: 875ms	remaining: 15.3s
# 54:	learn: 0.3385473	total: 902ms	remaining: 15.5s
# 55:	learn: 0.3378323	total: 925ms	remaining: 15.6s
# 56:	learn: 0.3371057	total: 948ms	remaining: 15.7s
# 57:	learn: 0.3365611	total: 969ms	remaining: 15.7s
# 58:	learn: 0.3359216	total: 990ms	remaining: 15.8s
# 59:	learn: 0.3352698	total: 1s	remaining: 15.7s
# 60:	learn: 0.3345723	total: 1.03s	remaining: 15.8s
# 61:	learn: 0.3337386	total: 1.06s	remaining: 16.1s
# 62:	learn: 0.3331699	total: 1.09s	remaining: 16.3s
# 63:	learn: 0.3326412	total: 1.12s	remaining: 16.4s
# 64:	learn: 0.3320359	total: 1.14s	remaining: 16.5s
# 65:	learn: 0.3314378	total: 1.17s	remaining: 16.5s
# 66:	learn: 0.3309832	total: 1.18s	remaining: 16.5s
# 67:	learn: 0.3304615	total: 1.2s	remaining: 16.4s
# 68:	learn: 0.3296713	total: 1.21s	remaining: 16.4s
# 69:	learn: 0.3291141	total: 1.23s	remaining: 16.3s
# 70:	learn: 0.3286907	total: 1.24s	remaining: 16.2s
# 71:	learn: 0.3282657	total: 1.26s	remaining: 16.2s
# 72:	learn: 0.3277134	total: 1.29s	remaining: 16.3s
# 73:	learn: 0.3272842	total: 1.31s	remaining: 16.4s
# 74:	learn: 0.3269270	total: 1.33s	remaining: 16.5s
# 75:	learn: 0.3265741	total: 1.35s	remaining: 16.4s
# 76:	learn: 0.3261728	total: 1.37s	remaining: 16.5s
# 77:	learn: 0.3256787	total: 1.4s	remaining: 16.5s
# 78:	learn: 0.3252200	total: 1.41s	remaining: 16.4s
# 79:	learn: 0.3249014	total: 1.43s	remaining: 16.5s
# 80:	learn: 0.3245153	total: 1.46s	remaining: 16.5s
# 81:	learn: 0.3241299	total: 1.48s	remaining: 16.5s
# 82:	learn: 0.3236980	total: 1.51s	remaining: 16.7s
# 83:	learn: 0.3232116	total: 1.53s	remaining: 16.7s
# 84:	learn: 0.3228875	total: 1.56s	remaining: 16.8s
# 85:	learn: 0.3223951	total: 1.59s	remaining: 16.9s
# 86:	learn: 0.3220824	total: 1.61s	remaining: 16.9s
# 87:	learn: 0.3218244	total: 1.64s	remaining: 17s
# 88:	learn: 0.3211770	total: 1.66s	remaining: 17s
# 89:	learn: 0.3208012	total: 1.69s	remaining: 17.1s
# 90:	learn: 0.3204718	total: 1.72s	remaining: 17.1s
# 91:	learn: 0.3201927	total: 1.74s	remaining: 17.2s
# 92:	learn: 0.3198756	total: 1.77s	remaining: 17.2s
# 93:	learn: 0.3196137	total: 1.79s	remaining: 17.3s
# 94:	learn: 0.3193528	total: 1.82s	remaining: 17.3s
# 95:	learn: 0.3190124	total: 1.83s	remaining: 17.3s
# 96:	learn: 0.3186306	total: 1.85s	remaining: 17.2s
# 97:	learn: 0.3184334	total: 1.86s	remaining: 17.1s
# 98:	learn: 0.3182101	total: 1.88s	remaining: 17.1s
# 99:	learn: 0.3179805	total: 1.9s	remaining: 17.1s
# 100:	learn: 0.3177534	total: 1.93s	remaining: 17.2s
# 101:	learn: 0.3175294	total: 1.96s	remaining: 17.3s
# 102:	learn: 0.3172567	total: 1.98s	remaining: 17.3s
# 103:	learn: 0.3169953	total: 2.01s	remaining: 17.3s
# 104:	learn: 0.3167314	total: 2.04s	remaining: 17.4s
# 105:	learn: 0.3164476	total: 2.06s	remaining: 17.4s
# 106:	learn: 0.3161425	total: 2.08s	remaining: 17.3s
# 107:	learn: 0.3158634	total: 2.09s	remaining: 17.2s
# 108:	learn: 0.3156269	total: 2.1s	remaining: 17.2s
# 109:	learn: 0.3153175	total: 2.12s	remaining: 17.1s
# 110:	learn: 0.3149467	total: 2.14s	remaining: 17.1s
# 111:	learn: 0.3146970	total: 2.16s	remaining: 17.1s
# 112:	learn: 0.3144908	total: 2.18s	remaining: 17.1s
# 113:	learn: 0.3142815	total: 2.2s	remaining: 17.1s
# 114:	learn: 0.3140543	total: 2.21s	remaining: 17s
# 115:	learn: 0.3136554	total: 2.23s	remaining: 17s
# 116:	learn: 0.3135110	total: 2.25s	remaining: 17s
# 117:	learn: 0.3133630	total: 2.27s	remaining: 17s
# 118:	learn: 0.3131447	total: 2.3s	remaining: 17s
# 119:	learn: 0.3130014	total: 2.32s	remaining: 17s
# 120:	learn: 0.3128516	total: 2.35s	remaining: 17.1s
# 121:	learn: 0.3127134	total: 2.38s	remaining: 17.2s
# 122:	learn: 0.3125102	total: 2.4s	remaining: 17.1s
# 123:	learn: 0.3122803	total: 2.43s	remaining: 17.2s
# 124:	learn: 0.3121417	total: 2.46s	remaining: 17.2s
# 125:	learn: 0.3119657	total: 2.48s	remaining: 17.2s
# 126:	learn: 0.3118172	total: 2.51s	remaining: 17.2s
# 127:	learn: 0.3116228	total: 2.53s	remaining: 17.2s
# 128:	learn: 0.3114336	total: 2.56s	remaining: 17.3s
# 129:	learn: 0.3112077	total: 2.59s	remaining: 17.3s
# 130:	learn: 0.3110670	total: 2.62s	remaining: 17.3s
# 131:	learn: 0.3108533	total: 2.64s	remaining: 17.4s
# 132:	learn: 0.3105959	total: 2.67s	remaining: 17.4s
# 133:	learn: 0.3104056	total: 2.69s	remaining: 17.4s
# 134:	learn: 0.3102755	total: 2.71s	remaining: 17.4s
# 135:	learn: 0.3100866	total: 2.74s	remaining: 17.4s
# 136:	learn: 0.3099128	total: 2.76s	remaining: 17.4s
# 137:	learn: 0.3097650	total: 2.79s	remaining: 17.4s
# 138:	learn: 0.3095043	total: 2.81s	remaining: 17.4s
# 139:	learn: 0.3093574	total: 2.84s	remaining: 17.4s
# 140:	learn: 0.3089854	total: 2.87s	remaining: 17.5s
# 141:	learn: 0.3088709	total: 2.88s	remaining: 17.4s
# 142:	learn: 0.3087440	total: 2.9s	remaining: 17.4s
# 143:	learn: 0.3086213	total: 2.93s	remaining: 17.4s
# 144:	learn: 0.3084465	total: 2.96s	remaining: 17.4s
# 145:	learn: 0.3083002	total: 2.99s	remaining: 17.5s
# 146:	learn: 0.3081746	total: 3.01s	remaining: 17.5s
# 147:	learn: 0.3080375	total: 3.04s	remaining: 17.5s
# 148:	learn: 0.3079463	total: 3.07s	remaining: 17.5s
# 149:	learn: 0.3077962	total: 3.1s	remaining: 17.5s
# 150:	learn: 0.3076881	total: 3.11s	remaining: 17.5s
# 151:	learn: 0.3075578	total: 3.14s	remaining: 17.5s
# 152:	learn: 0.3074027	total: 3.17s	remaining: 17.5s
# 153:	learn: 0.3072288	total: 3.18s	remaining: 17.5s
# 154:	learn: 0.3069894	total: 3.2s	remaining: 17.4s
# 155:	learn: 0.3066698	total: 3.21s	remaining: 17.4s
# 156:	learn: 0.3065714	total: 3.22s	remaining: 17.3s
# 157:	learn: 0.3064494	total: 3.24s	remaining: 17.2s
# 158:	learn: 0.3062940	total: 3.25s	remaining: 17.2s
# 159:	learn: 0.3062404	total: 3.26s	remaining: 17.1s
# 160:	learn: 0.3061197	total: 3.27s	remaining: 17s
# 161:	learn: 0.3057952	total: 3.29s	remaining: 17s
# 162:	learn: 0.3056450	total: 3.3s	remaining: 17s
# 163:	learn: 0.3055583	total: 3.31s	remaining: 16.9s
# 164:	learn: 0.3053940	total: 3.32s	remaining: 16.8s
# 165:	learn: 0.3053262	total: 3.33s	remaining: 16.7s
# 166:	learn: 0.3051753	total: 3.34s	remaining: 16.6s
# 167:	learn: 0.3050268	total: 3.35s	remaining: 16.6s
# 168:	learn: 0.3049279	total: 3.35s	remaining: 16.5s
# 169:	learn: 0.3048448	total: 3.36s	remaining: 16.4s
# 170:	learn: 0.3046826	total: 3.37s	remaining: 16.3s
# 171:	learn: 0.3046181	total: 3.38s	remaining: 16.3s
# 172:	learn: 0.3044820	total: 3.39s	remaining: 16.2s
# 173:	learn: 0.3044227	total: 3.4s	remaining: 16.1s
# 174:	learn: 0.3043181	total: 3.41s	remaining: 16.1s
# 175:	learn: 0.3041946	total: 3.42s	remaining: 16s
# 176:	learn: 0.3041024	total: 3.43s	remaining: 15.9s
# 177:	learn: 0.3040055	total: 3.44s	remaining: 15.9s
# 178:	learn: 0.3039191	total: 3.45s	remaining: 15.8s
# 179:	learn: 0.3038102	total: 3.46s	remaining: 15.7s
# 180:	learn: 0.3037301	total: 3.46s	remaining: 15.7s
# 181:	learn: 0.3036384	total: 3.47s	remaining: 15.6s
# 182:	learn: 0.3035468	total: 3.48s	remaining: 15.6s
# 183:	learn: 0.3034756	total: 3.49s	remaining: 15.5s
# 184:	learn: 0.3033725	total: 3.5s	remaining: 15.4s
# 185:	learn: 0.3032673	total: 3.51s	remaining: 15.4s
# 186:	learn: 0.3031407	total: 3.52s	remaining: 15.3s
# 187:	learn: 0.3030650	total: 3.53s	remaining: 15.2s
# 188:	learn: 0.3029556	total: 3.54s	remaining: 15.2s
# 189:	learn: 0.3027910	total: 3.54s	remaining: 15.1s
# 190:	learn: 0.3026197	total: 3.55s	remaining: 15.1s
# 191:	learn: 0.3024697	total: 3.56s	remaining: 15s
# 192:	learn: 0.3023869	total: 3.57s	remaining: 14.9s
# 193:	learn: 0.3022936	total: 3.58s	remaining: 14.9s
# 194:	learn: 0.3022538	total: 3.59s	remaining: 14.8s
# 195:	learn: 0.3020772	total: 3.6s	remaining: 14.8s
# 196:	learn: 0.3020119	total: 3.61s	remaining: 14.7s
# 197:	learn: 0.3018152	total: 3.62s	remaining: 14.7s
# 198:	learn: 0.3017415	total: 3.63s	remaining: 14.6s
# 199:	learn: 0.3016476	total: 3.64s	remaining: 14.5s
# 200:	learn: 0.3015453	total: 3.65s	remaining: 14.5s
# 201:	learn: 0.3014163	total: 3.65s	remaining: 14.4s
# 202:	learn: 0.3012733	total: 3.66s	remaining: 14.4s
# 203:	learn: 0.3012040	total: 3.67s	remaining: 14.3s
# 204:	learn: 0.3010577	total: 3.68s	remaining: 14.3s
# 205:	learn: 0.3010411	total: 3.69s	remaining: 14.2s
# 206:	learn: 0.3010100	total: 3.69s	remaining: 14.2s
# 207:	learn: 0.3009094	total: 3.7s	remaining: 14.1s
# 208:	learn: 0.3007733	total: 3.71s	remaining: 14s
# 209:	learn: 0.3006392	total: 3.72s	remaining: 14s
# 210:	learn: 0.3005527	total: 3.73s	remaining: 14s
# 211:	learn: 0.3004507	total: 3.74s	remaining: 13.9s
# 212:	learn: 0.3003935	total: 3.75s	remaining: 13.9s
# 213:	learn: 0.3002580	total: 3.76s	remaining: 13.8s
# 214:	learn: 0.3001583	total: 3.77s	remaining: 13.8s
# 215:	learn: 0.3000795	total: 3.78s	remaining: 13.7s
# 216:	learn: 0.2999697	total: 3.79s	remaining: 13.7s
# 217:	learn: 0.2998856	total: 3.8s	remaining: 13.6s
# 218:	learn: 0.2997644	total: 3.81s	remaining: 13.6s
# 219:	learn: 0.2997338	total: 3.82s	remaining: 13.5s
# 220:	learn: 0.2996870	total: 3.83s	remaining: 13.5s
# 221:	learn: 0.2996172	total: 3.84s	remaining: 13.4s
# 222:	learn: 0.2994999	total: 3.85s	remaining: 13.4s
# 223:	learn: 0.2993756	total: 3.86s	remaining: 13.4s
# 224:	learn: 0.2993098	total: 3.87s	remaining: 13.3s
# 225:	learn: 0.2992502	total: 3.88s	remaining: 13.3s
# 226:	learn: 0.2991436	total: 3.89s	remaining: 13.2s
# 227:	learn: 0.2990924	total: 3.9s	remaining: 13.2s
# 228:	learn: 0.2989943	total: 3.9s	remaining: 13.1s
# 229:	learn: 0.2989511	total: 3.91s	remaining: 13.1s
# 230:	learn: 0.2989078	total: 3.92s	remaining: 13.1s
# 231:	learn: 0.2988675	total: 3.93s	remaining: 13s
# 232:	learn: 0.2987553	total: 3.94s	remaining: 13s
# 233:	learn: 0.2987087	total: 3.95s	remaining: 12.9s
# 234:	learn: 0.2986195	total: 3.96s	remaining: 12.9s
# 235:	learn: 0.2985112	total: 3.97s	remaining: 12.8s
# 236:	learn: 0.2984212	total: 3.98s	remaining: 12.8s
# 237:	learn: 0.2983452	total: 3.98s	remaining: 12.8s
# 238:	learn: 0.2982435	total: 3.99s	remaining: 12.7s
# 239:	learn: 0.2981563	total: 4.01s	remaining: 12.7s
# 240:	learn: 0.2980745	total: 4.01s	remaining: 12.6s
# 241:	learn: 0.2979759	total: 4.02s	remaining: 12.6s
# 242:	learn: 0.2978958	total: 4.03s	remaining: 12.6s
# 243:	learn: 0.2978123	total: 4.04s	remaining: 12.5s
# 244:	learn: 0.2977400	total: 4.05s	remaining: 12.5s
# 245:	learn: 0.2976967	total: 4.06s	remaining: 12.4s
# 246:	learn: 0.2976164	total: 4.07s	remaining: 12.4s
# 247:	learn: 0.2974929	total: 4.08s	remaining: 12.4s
# 248:	learn: 0.2974369	total: 4.09s	remaining: 12.3s
# 249:	learn: 0.2973676	total: 4.1s	remaining: 12.3s
# 250:	learn: 0.2973008	total: 4.11s	remaining: 12.3s
# 251:	learn: 0.2972332	total: 4.12s	remaining: 12.2s
# 252:	learn: 0.2971272	total: 4.13s	remaining: 12.2s
# 253:	learn: 0.2970591	total: 4.14s	remaining: 12.2s
# 254:	learn: 0.2969133	total: 4.15s	remaining: 12.1s
# 255:	learn: 0.2968743	total: 4.16s	remaining: 12.1s
# 256:	learn: 0.2968270	total: 4.16s	remaining: 12s
# 257:	learn: 0.2967509	total: 4.17s	remaining: 12s
# 258:	learn: 0.2966547	total: 4.18s	remaining: 12s
# 259:	learn: 0.2965426	total: 4.19s	remaining: 11.9s
# 260:	learn: 0.2964126	total: 4.2s	remaining: 11.9s
# 261:	learn: 0.2963339	total: 4.21s	remaining: 11.9s
# 262:	learn: 0.2962872	total: 4.22s	remaining: 11.8s
# 263:	learn: 0.2961457	total: 4.23s	remaining: 11.8s
# 264:	learn: 0.2960488	total: 4.24s	remaining: 11.8s
# 265:	learn: 0.2959791	total: 4.25s	remaining: 11.7s
# 266:	learn: 0.2959044	total: 4.26s	remaining: 11.7s
# 267:	learn: 0.2957940	total: 4.27s	remaining: 11.7s
# 268:	learn: 0.2957813	total: 4.28s	remaining: 11.6s
# 269:	learn: 0.2957460	total: 4.3s	remaining: 11.6s
# 270:	learn: 0.2957010	total: 4.32s	remaining: 11.6s
# 271:	learn: 0.2956369	total: 4.33s	remaining: 11.6s
# 272:	learn: 0.2955687	total: 4.33s	remaining: 11.5s
# 273:	learn: 0.2955391	total: 4.34s	remaining: 11.5s
# 274:	learn: 0.2954782	total: 4.35s	remaining: 11.5s
# 275:	learn: 0.2954120	total: 4.36s	remaining: 11.4s
# 276:	learn: 0.2953700	total: 4.37s	remaining: 11.4s
# 277:	learn: 0.2952989	total: 4.38s	remaining: 11.4s
# 278:	learn: 0.2951696	total: 4.39s	remaining: 11.3s
# 279:	learn: 0.2951138	total: 4.39s	remaining: 11.3s
# 280:	learn: 0.2950098	total: 4.4s	remaining: 11.3s
# 281:	learn: 0.2948564	total: 4.41s	remaining: 11.2s
# 282:	learn: 0.2948418	total: 4.42s	remaining: 11.2s
# 283:	learn: 0.2947979	total: 4.43s	remaining: 11.2s
# 284:	learn: 0.2947283	total: 4.44s	remaining: 11.1s
# 285:	learn: 0.2946767	total: 4.45s	remaining: 11.1s
# 286:	learn: 0.2946326	total: 4.46s	remaining: 11.1s
# 287:	learn: 0.2945319	total: 4.47s	remaining: 11.1s
# 288:	learn: 0.2944376	total: 4.48s	remaining: 11s
# 289:	learn: 0.2943728	total: 4.49s	remaining: 11s
# 290:	learn: 0.2942916	total: 4.5s	remaining: 11s
# 291:	learn: 0.2942347	total: 4.51s	remaining: 10.9s
# 292:	learn: 0.2942248	total: 4.52s	remaining: 10.9s
# 293:	learn: 0.2941314	total: 4.53s	remaining: 10.9s
# 294:	learn: 0.2941058	total: 4.54s	remaining: 10.8s
# 295:	learn: 0.2940355	total: 4.54s	remaining: 10.8s
# 296:	learn: 0.2939592	total: 4.55s	remaining: 10.8s
# 297:	learn: 0.2939441	total: 4.56s	remaining: 10.7s
# 298:	learn: 0.2938916	total: 4.57s	remaining: 10.7s
# 299:	learn: 0.2938354	total: 4.58s	remaining: 10.7s
# 300:	learn: 0.2937837	total: 4.59s	remaining: 10.7s
# 301:	learn: 0.2936642	total: 4.59s	remaining: 10.6s
# 302:	learn: 0.2935844	total: 4.6s	remaining: 10.6s
# 303:	learn: 0.2935103	total: 4.61s	remaining: 10.6s
# 304:	learn: 0.2934444	total: 4.62s	remaining: 10.5s
# 305:	learn: 0.2933456	total: 4.63s	remaining: 10.5s
# 306:	learn: 0.2932844	total: 4.64s	remaining: 10.5s
# 307:	learn: 0.2932289	total: 4.66s	remaining: 10.5s
# 308:	learn: 0.2932147	total: 4.66s	remaining: 10.4s
# 309:	learn: 0.2931567	total: 4.67s	remaining: 10.4s
# 310:	learn: 0.2930837	total: 4.68s	remaining: 10.4s
# 311:	learn: 0.2930431	total: 4.69s	remaining: 10.3s
# 312:	learn: 0.2929851	total: 4.7s	remaining: 10.3s
# 313:	learn: 0.2929529	total: 4.71s	remaining: 10.3s
# 314:	learn: 0.2929161	total: 4.71s	remaining: 10.3s
# 315:	learn: 0.2928290	total: 4.72s	remaining: 10.2s
# 316:	learn: 0.2927069	total: 4.73s	remaining: 10.2s
# 317:	learn: 0.2926146	total: 4.74s	remaining: 10.2s
# 318:	learn: 0.2925078	total: 4.75s	remaining: 10.1s
# 319:	learn: 0.2924251	total: 4.76s	remaining: 10.1s
# 320:	learn: 0.2924026	total: 4.77s	remaining: 10.1s
# 321:	learn: 0.2923321	total: 4.78s	remaining: 10.1s
# 322:	learn: 0.2922906	total: 4.79s	remaining: 10s
# 323:	learn: 0.2922331	total: 4.79s	remaining: 10s
# 324:	learn: 0.2922060	total: 4.8s	remaining: 9.98s
# 325:	learn: 0.2921528	total: 4.81s	remaining: 9.95s
# 326:	learn: 0.2921082	total: 4.82s	remaining: 9.92s
# 327:	learn: 0.2920407	total: 4.83s	remaining: 9.89s
# 328:	learn: 0.2919845	total: 4.84s	remaining: 9.88s
# 329:	learn: 0.2919148	total: 4.85s	remaining: 9.85s
# 330:	learn: 0.2918804	total: 4.86s	remaining: 9.82s
# 331:	learn: 0.2917967	total: 4.87s	remaining: 9.8s
# 332:	learn: 0.2917253	total: 4.88s	remaining: 9.77s
# 333:	learn: 0.2916648	total: 4.89s	remaining: 9.74s
# 334:	learn: 0.2915391	total: 4.89s	remaining: 9.72s
# 335:	learn: 0.2914792	total: 4.9s	remaining: 9.69s
# 336:	learn: 0.2914037	total: 4.91s	remaining: 9.67s
# 337:	learn: 0.2913387	total: 4.92s	remaining: 9.64s
# 338:	learn: 0.2912568	total: 4.93s	remaining: 9.62s
# 339:	learn: 0.2912010	total: 4.94s	remaining: 9.59s
# 340:	learn: 0.2911264	total: 4.95s	remaining: 9.56s
# 341:	learn: 0.2911007	total: 4.96s	remaining: 9.54s
# 342:	learn: 0.2910766	total: 4.97s	remaining: 9.51s
# 343:	learn: 0.2910045	total: 4.97s	remaining: 9.49s
# 344:	learn: 0.2909735	total: 4.98s	remaining: 9.46s
# 345:	learn: 0.2909342	total: 4.99s	remaining: 9.44s
# 346:	learn: 0.2908693	total: 5s	remaining: 9.42s
# 347:	learn: 0.2907848	total: 5.01s	remaining: 9.39s
# 348:	learn: 0.2906952	total: 5.02s	remaining: 9.37s
# 349:	learn: 0.2906406	total: 5.04s	remaining: 9.36s
# 350:	learn: 0.2906035	total: 5.05s	remaining: 9.34s
# 351:	learn: 0.2905455	total: 5.06s	remaining: 9.31s
# 352:	learn: 0.2904885	total: 5.07s	remaining: 9.29s
# 353:	learn: 0.2904491	total: 5.08s	remaining: 9.27s
# 354:	learn: 0.2903716	total: 5.09s	remaining: 9.25s
# 355:	learn: 0.2902474	total: 5.1s	remaining: 9.23s
# 356:	learn: 0.2902009	total: 5.11s	remaining: 9.2s
# 357:	learn: 0.2901219	total: 5.12s	remaining: 9.18s
# 358:	learn: 0.2900675	total: 5.13s	remaining: 9.15s
# 359:	learn: 0.2900531	total: 5.13s	remaining: 9.13s
# 360:	learn: 0.2900132	total: 5.14s	remaining: 9.11s
# 361:	learn: 0.2899632	total: 5.15s	remaining: 9.08s
# 362:	learn: 0.2898503	total: 5.17s	remaining: 9.07s
# 363:	learn: 0.2897847	total: 5.18s	remaining: 9.04s
# 364:	learn: 0.2897567	total: 5.18s	remaining: 9.02s
# 365:	learn: 0.2897007	total: 5.2s	remaining: 9s
# 366:	learn: 0.2896508	total: 5.2s	remaining: 8.98s
# 367:	learn: 0.2895802	total: 5.21s	remaining: 8.96s
# 368:	learn: 0.2894798	total: 5.23s	remaining: 8.94s
# 369:	learn: 0.2893951	total: 5.24s	remaining: 8.92s
# 370:	learn: 0.2893069	total: 5.25s	remaining: 8.9s
# 371:	learn: 0.2892213	total: 5.26s	remaining: 8.88s
# 372:	learn: 0.2891476	total: 5.27s	remaining: 8.86s
# 373:	learn: 0.2891238	total: 5.28s	remaining: 8.84s
# 374:	learn: 0.2890577	total: 5.29s	remaining: 8.82s
# 375:	learn: 0.2889953	total: 5.31s	remaining: 8.81s
# 376:	learn: 0.2889744	total: 5.33s	remaining: 8.81s
# 377:	learn: 0.2888815	total: 5.34s	remaining: 8.8s
# 378:	learn: 0.2888567	total: 5.35s	remaining: 8.77s
# 379:	learn: 0.2888379	total: 5.36s	remaining: 8.75s
# 380:	learn: 0.2887882	total: 5.37s	remaining: 8.73s
# 381:	learn: 0.2887421	total: 5.38s	remaining: 8.7s
# 382:	learn: 0.2887041	total: 5.39s	remaining: 8.68s
# 383:	learn: 0.2886414	total: 5.4s	remaining: 8.66s
# 384:	learn: 0.2885707	total: 5.41s	remaining: 8.64s
# 385:	learn: 0.2885006	total: 5.42s	remaining: 8.62s
# 386:	learn: 0.2884133	total: 5.43s	remaining: 8.6s
# 387:	learn: 0.2883539	total: 5.44s	remaining: 8.58s
# 388:	learn: 0.2882699	total: 5.45s	remaining: 8.56s
# 389:	learn: 0.2882260	total: 5.46s	remaining: 8.54s
# 390:	learn: 0.2882004	total: 5.47s	remaining: 8.52s
# 391:	learn: 0.2881366	total: 5.48s	remaining: 8.5s
# 392:	learn: 0.2880855	total: 5.49s	remaining: 8.48s
# 393:	learn: 0.2880278	total: 5.5s	remaining: 8.46s
# 394:	learn: 0.2879841	total: 5.51s	remaining: 8.44s
# 395:	learn: 0.2879544	total: 5.51s	remaining: 8.41s
# 396:	learn: 0.2879358	total: 5.52s	remaining: 8.39s
# 397:	learn: 0.2878547	total: 5.53s	remaining: 8.37s
# 398:	learn: 0.2878211	total: 5.54s	remaining: 8.35s
# 399:	learn: 0.2877636	total: 5.55s	remaining: 8.33s
# 400:	learn: 0.2876875	total: 5.56s	remaining: 8.31s
# 401:	learn: 0.2876376	total: 5.57s	remaining: 8.29s
# 402:	learn: 0.2875616	total: 5.58s	remaining: 8.27s
# 403:	learn: 0.2875118	total: 5.59s	remaining: 8.24s
# 404:	learn: 0.2874682	total: 5.6s	remaining: 8.22s
# 405:	learn: 0.2874565	total: 5.6s	remaining: 8.2s
# 406:	learn: 0.2873802	total: 5.61s	remaining: 8.18s
# 407:	learn: 0.2872853	total: 5.62s	remaining: 8.16s
# 408:	learn: 0.2872098	total: 5.63s	remaining: 8.13s
# 409:	learn: 0.2871195	total: 5.64s	remaining: 8.11s
# 410:	learn: 0.2870720	total: 5.65s	remaining: 8.1s
# 411:	learn: 0.2870099	total: 5.66s	remaining: 8.07s
# 412:	learn: 0.2869638	total: 5.67s	remaining: 8.06s
# 413:	learn: 0.2868731	total: 5.68s	remaining: 8.04s
# 414:	learn: 0.2868172	total: 5.69s	remaining: 8.02s
# 415:	learn: 0.2867877	total: 5.7s	remaining: 8s
# 416:	learn: 0.2867410	total: 5.71s	remaining: 7.98s
# 417:	learn: 0.2866950	total: 5.71s	remaining: 7.96s
# 418:	learn: 0.2866603	total: 5.72s	remaining: 7.93s
# 419:	learn: 0.2866277	total: 5.73s	remaining: 7.92s
# 420:	learn: 0.2866198	total: 5.74s	remaining: 7.89s
# 421:	learn: 0.2865722	total: 5.75s	remaining: 7.88s
# 422:	learn: 0.2865231	total: 5.76s	remaining: 7.86s
# 423:	learn: 0.2864276	total: 5.77s	remaining: 7.83s
# 424:	learn: 0.2863809	total: 5.78s	remaining: 7.82s
# 425:	learn: 0.2863096	total: 5.79s	remaining: 7.8s
# 426:	learn: 0.2862395	total: 5.8s	remaining: 7.78s
# 427:	learn: 0.2861870	total: 5.81s	remaining: 7.76s
# 428:	learn: 0.2861243	total: 5.82s	remaining: 7.74s
# 429:	learn: 0.2860388	total: 5.83s	remaining: 7.72s
# 430:	learn: 0.2859811	total: 5.84s	remaining: 7.71s
# 431:	learn: 0.2859365	total: 5.84s	remaining: 7.68s
# 432:	learn: 0.2858495	total: 5.85s	remaining: 7.67s
# 433:	learn: 0.2857785	total: 5.86s	remaining: 7.65s
# 434:	learn: 0.2857526	total: 5.88s	remaining: 7.63s
# 435:	learn: 0.2857396	total: 5.88s	remaining: 7.61s
# 436:	learn: 0.2856911	total: 5.89s	remaining: 7.59s
# 437:	learn: 0.2856705	total: 5.9s	remaining: 7.57s
# 438:	learn: 0.2856240	total: 5.91s	remaining: 7.55s
# 439:	learn: 0.2855877	total: 5.92s	remaining: 7.53s
# 440:	learn: 0.2855210	total: 5.93s	remaining: 7.51s
# 441:	learn: 0.2854955	total: 5.93s	remaining: 7.49s
# 442:	learn: 0.2854260	total: 5.94s	remaining: 7.47s
# 443:	learn: 0.2853761	total: 5.95s	remaining: 7.45s
# 444:	learn: 0.2853283	total: 5.96s	remaining: 7.43s
# 445:	learn: 0.2852757	total: 5.97s	remaining: 7.41s
# 446:	learn: 0.2852073	total: 5.98s	remaining: 7.4s
# 447:	learn: 0.2851106	total: 5.99s	remaining: 7.38s
# 448:	learn: 0.2850422	total: 6s	remaining: 7.36s
# 449:	learn: 0.2849790	total: 6.01s	remaining: 7.34s
# 450:	learn: 0.2849167	total: 6.01s	remaining: 7.32s
# 451:	learn: 0.2848756	total: 6.02s	remaining: 7.3s
# 452:	learn: 0.2848479	total: 6.03s	remaining: 7.29s
# 453:	learn: 0.2848296	total: 6.04s	remaining: 7.27s
# 454:	learn: 0.2848055	total: 6.05s	remaining: 7.25s
# 455:	learn: 0.2847165	total: 6.06s	remaining: 7.23s
# 456:	learn: 0.2846515	total: 6.07s	remaining: 7.21s
# 457:	learn: 0.2846085	total: 6.08s	remaining: 7.2s
# 458:	learn: 0.2845534	total: 6.09s	remaining: 7.18s
# 459:	learn: 0.2844865	total: 6.1s	remaining: 7.16s
# 460:	learn: 0.2844396	total: 6.11s	remaining: 7.14s
# 461:	learn: 0.2843602	total: 6.12s	remaining: 7.13s
# 462:	learn: 0.2843072	total: 6.13s	remaining: 7.11s
# 463:	learn: 0.2842557	total: 6.14s	remaining: 7.09s
# 464:	learn: 0.2841904	total: 6.14s	remaining: 7.07s
# 465:	learn: 0.2841263	total: 6.15s	remaining: 7.05s
# 466:	learn: 0.2840802	total: 6.16s	remaining: 7.03s
# 467:	learn: 0.2840666	total: 6.17s	remaining: 7.01s
# 468:	learn: 0.2840089	total: 6.18s	remaining: 7s
# 469:	learn: 0.2839442	total: 6.19s	remaining: 6.98s
# 470:	learn: 0.2838995	total: 6.2s	remaining: 6.96s
# 471:	learn: 0.2838867	total: 6.21s	remaining: 6.94s
# 472:	learn: 0.2838206	total: 6.22s	remaining: 6.93s
# 473:	learn: 0.2837984	total: 6.23s	remaining: 6.91s
# 474:	learn: 0.2837743	total: 6.24s	remaining: 6.89s
# 475:	learn: 0.2837455	total: 6.25s	remaining: 6.88s
# 476:	learn: 0.2837379	total: 6.25s	remaining: 6.86s
# 477:	learn: 0.2837225	total: 6.26s	remaining: 6.84s
# 478:	learn: 0.2836556	total: 6.27s	remaining: 6.82s
# 479:	learn: 0.2836173	total: 6.29s	remaining: 6.81s
# 480:	learn: 0.2835905	total: 6.3s	remaining: 6.8s
# 481:	learn: 0.2835527	total: 6.33s	remaining: 6.81s
# 482:	learn: 0.2835039	total: 6.36s	remaining: 6.81s
# 483:	learn: 0.2834492	total: 6.37s	remaining: 6.79s
# 484:	learn: 0.2834148	total: 6.38s	remaining: 6.78s
# 485:	learn: 0.2833440	total: 6.39s	remaining: 6.76s
# 486:	learn: 0.2832854	total: 6.4s	remaining: 6.74s
# 487:	learn: 0.2832292	total: 6.41s	remaining: 6.72s
# 488:	learn: 0.2831884	total: 6.42s	remaining: 6.71s
# 489:	learn: 0.2831699	total: 6.43s	remaining: 6.69s
# 490:	learn: 0.2831054	total: 6.44s	remaining: 6.67s
# 491:	learn: 0.2830474	total: 6.45s	remaining: 6.65s
# 492:	learn: 0.2829965	total: 6.45s	remaining: 6.64s
# 493:	learn: 0.2829378	total: 6.46s	remaining: 6.62s
# 494:	learn: 0.2829326	total: 6.47s	remaining: 6.6s
# 495:	learn: 0.2828617	total: 6.48s	remaining: 6.58s
# 496:	learn: 0.2828292	total: 6.49s	remaining: 6.57s
# 497:	learn: 0.2827684	total: 6.5s	remaining: 6.55s
# 498:	learn: 0.2827516	total: 6.51s	remaining: 6.53s
# 499:	learn: 0.2826863	total: 6.51s	remaining: 6.51s
# 500:	learn: 0.2826453	total: 6.52s	remaining: 6.5s
# 501:	learn: 0.2826243	total: 6.53s	remaining: 6.48s
# 502:	learn: 0.2825893	total: 6.54s	remaining: 6.46s
# 503:	learn: 0.2825198	total: 6.55s	remaining: 6.45s
# 504:	learn: 0.2825039	total: 6.56s	remaining: 6.43s
# 505:	learn: 0.2824718	total: 6.57s	remaining: 6.41s
# 506:	learn: 0.2824481	total: 6.58s	remaining: 6.39s
# 507:	learn: 0.2824068	total: 6.58s	remaining: 6.38s
# 508:	learn: 0.2823636	total: 6.59s	remaining: 6.36s
# 509:	learn: 0.2822993	total: 6.6s	remaining: 6.34s
# 510:	learn: 0.2822621	total: 6.61s	remaining: 6.32s
# 511:	learn: 0.2821914	total: 6.62s	remaining: 6.31s
# 512:	learn: 0.2821241	total: 6.63s	remaining: 6.29s
# 513:	learn: 0.2820754	total: 6.64s	remaining: 6.27s
# 514:	learn: 0.2820091	total: 6.64s	remaining: 6.26s
# 515:	learn: 0.2819207	total: 6.65s	remaining: 6.24s
# 516:	learn: 0.2818602	total: 6.66s	remaining: 6.22s
# 517:	learn: 0.2818135	total: 6.67s	remaining: 6.21s
# 518:	learn: 0.2817977	total: 6.68s	remaining: 6.19s
# 519:	learn: 0.2817769	total: 6.69s	remaining: 6.17s
# 520:	learn: 0.2817427	total: 6.7s	remaining: 6.16s
# 521:	learn: 0.2817160	total: 6.71s	remaining: 6.14s
# 522:	learn: 0.2816912	total: 6.72s	remaining: 6.13s
# 523:	learn: 0.2816201	total: 6.73s	remaining: 6.11s
# 524:	learn: 0.2815792	total: 6.74s	remaining: 6.09s
# 525:	learn: 0.2815317	total: 6.74s	remaining: 6.08s
# 526:	learn: 0.2814924	total: 6.75s	remaining: 6.06s
# 527:	learn: 0.2814784	total: 6.76s	remaining: 6.05s
# 528:	learn: 0.2814378	total: 6.77s	remaining: 6.03s
# 529:	learn: 0.2813779	total: 6.78s	remaining: 6.01s
# 530:	learn: 0.2813219	total: 6.79s	remaining: 6s
# 531:	learn: 0.2812783	total: 6.8s	remaining: 5.98s
# 532:	learn: 0.2812307	total: 6.81s	remaining: 5.96s
# 533:	learn: 0.2812098	total: 6.82s	remaining: 5.95s
# 534:	learn: 0.2811579	total: 6.83s	remaining: 5.93s
# 535:	learn: 0.2811444	total: 6.83s	remaining: 5.92s
# 536:	learn: 0.2810990	total: 6.84s	remaining: 5.9s
# 537:	learn: 0.2810453	total: 6.85s	remaining: 5.88s
# 538:	learn: 0.2809855	total: 6.86s	remaining: 5.87s
# 539:	learn: 0.2809608	total: 6.87s	remaining: 5.85s
# 540:	learn: 0.2809287	total: 6.88s	remaining: 5.84s
# 541:	learn: 0.2808447	total: 6.89s	remaining: 5.82s
# 542:	learn: 0.2807956	total: 6.9s	remaining: 5.81s
# 543:	learn: 0.2807488	total: 6.91s	remaining: 5.79s
# 544:	learn: 0.2807058	total: 6.92s	remaining: 5.78s
# 545:	learn: 0.2806624	total: 6.93s	remaining: 5.76s
# 546:	learn: 0.2806451	total: 6.94s	remaining: 5.74s
# 547:	learn: 0.2805464	total: 6.95s	remaining: 5.73s
# 548:	learn: 0.2805309	total: 6.95s	remaining: 5.71s
# 549:	learn: 0.2804706	total: 6.96s	remaining: 5.7s
# 550:	learn: 0.2804093	total: 6.97s	remaining: 5.68s
# 551:	learn: 0.2803910	total: 6.98s	remaining: 5.67s
# 552:	learn: 0.2803630	total: 6.99s	remaining: 5.65s
# 553:	learn: 0.2802760	total: 7s	remaining: 5.64s
# 554:	learn: 0.2802114	total: 7.01s	remaining: 5.62s
# 555:	learn: 0.2801378	total: 7.02s	remaining: 5.61s
# 556:	learn: 0.2800908	total: 7.03s	remaining: 5.59s
# 557:	learn: 0.2800475	total: 7.04s	remaining: 5.57s
# 558:	learn: 0.2800306	total: 7.04s	remaining: 5.56s
# 559:	learn: 0.2799674	total: 7.05s	remaining: 5.54s
# 560:	learn: 0.2799115	total: 7.06s	remaining: 5.53s
# 561:	learn: 0.2798555	total: 7.07s	remaining: 5.51s
# 562:	learn: 0.2797830	total: 7.08s	remaining: 5.5s
# 563:	learn: 0.2797551	total: 7.09s	remaining: 5.48s
# 564:	learn: 0.2797196	total: 7.1s	remaining: 5.46s
# 565:	learn: 0.2796811	total: 7.11s	remaining: 5.45s
# 566:	learn: 0.2796704	total: 7.12s	remaining: 5.43s
# 567:	learn: 0.2796286	total: 7.13s	remaining: 5.42s
# 568:	learn: 0.2795648	total: 7.13s	remaining: 5.4s
# 569:	learn: 0.2795060	total: 7.14s	remaining: 5.39s
# 570:	learn: 0.2794518	total: 7.15s	remaining: 5.37s
# 571:	learn: 0.2793956	total: 7.16s	remaining: 5.36s
# 572:	learn: 0.2793705	total: 7.17s	remaining: 5.34s
# 573:	learn: 0.2793338	total: 7.18s	remaining: 5.33s
# 574:	learn: 0.2792990	total: 7.19s	remaining: 5.31s
# 575:	learn: 0.2792809	total: 7.19s	remaining: 5.3s
# 576:	learn: 0.2792572	total: 7.21s	remaining: 5.28s
# 577:	learn: 0.2792187	total: 7.21s	remaining: 5.27s
# 578:	learn: 0.2792004	total: 7.22s	remaining: 5.25s
# 579:	learn: 0.2791531	total: 7.23s	remaining: 5.24s
# 580:	learn: 0.2790783	total: 7.24s	remaining: 5.22s
# 581:	learn: 0.2790533	total: 7.25s	remaining: 5.21s
# 582:	learn: 0.2790034	total: 7.26s	remaining: 5.19s
# 583:	learn: 0.2789357	total: 7.27s	remaining: 5.18s
# 584:	learn: 0.2788955	total: 7.28s	remaining: 5.16s
# 585:	learn: 0.2788343	total: 7.29s	remaining: 5.15s
# 586:	learn: 0.2787945	total: 7.3s	remaining: 5.13s
# 587:	learn: 0.2787449	total: 7.3s	remaining: 5.12s
# 588:	learn: 0.2786998	total: 7.32s	remaining: 5.11s
# 589:	learn: 0.2786733	total: 7.33s	remaining: 5.09s
# 590:	learn: 0.2786316	total: 7.33s	remaining: 5.08s
# 591:	learn: 0.2785477	total: 7.34s	remaining: 5.06s
# 592:	learn: 0.2785070	total: 7.36s	remaining: 5.05s
# 593:	learn: 0.2784310	total: 7.38s	remaining: 5.05s
# 594:	learn: 0.2783994	total: 7.39s	remaining: 5.03s
# 595:	learn: 0.2783431	total: 7.4s	remaining: 5.02s
# 596:	learn: 0.2783213	total: 7.41s	remaining: 5s
# 597:	learn: 0.2782906	total: 7.42s	remaining: 4.99s
# 598:	learn: 0.2782398	total: 7.43s	remaining: 4.97s
# 599:	learn: 0.2781948	total: 7.44s	remaining: 4.96s
# 600:	learn: 0.2781460	total: 7.45s	remaining: 4.95s
# 601:	learn: 0.2780883	total: 7.46s	remaining: 4.93s
# 602:	learn: 0.2780732	total: 7.47s	remaining: 4.92s
# 603:	learn: 0.2780361	total: 7.47s	remaining: 4.9s
# 604:	learn: 0.2780095	total: 7.48s	remaining: 4.89s
# 605:	learn: 0.2779584	total: 7.49s	remaining: 4.87s
# 606:	learn: 0.2779120	total: 7.5s	remaining: 4.86s
# 607:	learn: 0.2778438	total: 7.51s	remaining: 4.84s
# 608:	learn: 0.2778078	total: 7.52s	remaining: 4.83s
# 609:	learn: 0.2777971	total: 7.53s	remaining: 4.81s
# 610:	learn: 0.2777764	total: 7.54s	remaining: 4.8s
# 611:	learn: 0.2777299	total: 7.55s	remaining: 4.78s
# 612:	learn: 0.2776658	total: 7.55s	remaining: 4.77s
# 613:	learn: 0.2776068	total: 7.56s	remaining: 4.75s
# 614:	learn: 0.2775448	total: 7.57s	remaining: 4.74s
# 615:	learn: 0.2775102	total: 7.58s	remaining: 4.73s
# 616:	learn: 0.2774550	total: 7.59s	remaining: 4.71s
# 617:	learn: 0.2774077	total: 7.6s	remaining: 4.7s
# 618:	learn: 0.2773691	total: 7.61s	remaining: 4.68s
# 619:	learn: 0.2773234	total: 7.62s	remaining: 4.67s
# 620:	learn: 0.2773103	total: 7.63s	remaining: 4.65s
# 621:	learn: 0.2772664	total: 7.64s	remaining: 4.64s
# 622:	learn: 0.2772182	total: 7.65s	remaining: 4.63s
# 623:	learn: 0.2771774	total: 7.65s	remaining: 4.61s
# 624:	learn: 0.2771354	total: 7.66s	remaining: 4.6s
# 625:	learn: 0.2770724	total: 7.67s	remaining: 4.58s
# 626:	learn: 0.2770161	total: 7.68s	remaining: 4.57s
# 627:	learn: 0.2769468	total: 7.69s	remaining: 4.55s
# 628:	learn: 0.2769365	total: 7.7s	remaining: 4.54s
# 629:	learn: 0.2768779	total: 7.71s	remaining: 4.53s
# 630:	learn: 0.2768360	total: 7.72s	remaining: 4.51s
# 631:	learn: 0.2767847	total: 7.73s	remaining: 4.5s
# 632:	learn: 0.2767225	total: 7.74s	remaining: 4.49s
# 633:	learn: 0.2766599	total: 7.75s	remaining: 4.47s
# 634:	learn: 0.2766232	total: 7.76s	remaining: 4.46s
# 635:	learn: 0.2765875	total: 7.77s	remaining: 4.45s
# 636:	learn: 0.2765723	total: 7.77s	remaining: 4.43s
# 637:	learn: 0.2765201	total: 7.78s	remaining: 4.42s
# 638:	learn: 0.2764515	total: 7.79s	remaining: 4.4s
# 639:	learn: 0.2763953	total: 7.8s	remaining: 4.39s
# 640:	learn: 0.2763907	total: 7.81s	remaining: 4.38s
# 641:	learn: 0.2763335	total: 7.82s	remaining: 4.36s
# 642:	learn: 0.2762763	total: 7.83s	remaining: 4.35s
# 643:	learn: 0.2762698	total: 7.84s	remaining: 4.33s
# 644:	learn: 0.2762256	total: 7.85s	remaining: 4.32s
# 645:	learn: 0.2761790	total: 7.86s	remaining: 4.3s
# 646:	learn: 0.2761066	total: 7.86s	remaining: 4.29s
# 647:	learn: 0.2760919	total: 7.87s	remaining: 4.28s
# 648:	learn: 0.2760167	total: 7.88s	remaining: 4.26s
# 649:	learn: 0.2759763	total: 7.89s	remaining: 4.25s
# 650:	learn: 0.2759100	total: 7.9s	remaining: 4.23s
# 651:	learn: 0.2758742	total: 7.91s	remaining: 4.22s
# 652:	learn: 0.2758001	total: 7.91s	remaining: 4.21s
# 653:	learn: 0.2757304	total: 7.92s	remaining: 4.19s
# 654:	learn: 0.2756879	total: 7.93s	remaining: 4.18s
# 655:	learn: 0.2756269	total: 7.95s	remaining: 4.17s
# 656:	learn: 0.2755751	total: 7.96s	remaining: 4.15s
# 657:	learn: 0.2755588	total: 7.96s	remaining: 4.14s
# 658:	learn: 0.2755244	total: 7.97s	remaining: 4.13s
# 659:	learn: 0.2754856	total: 7.98s	remaining: 4.11s
# 660:	learn: 0.2754057	total: 7.99s	remaining: 4.1s
# 661:	learn: 0.2753688	total: 8s	remaining: 4.08s
# 662:	learn: 0.2753368	total: 8.01s	remaining: 4.07s
# 663:	learn: 0.2752855	total: 8.02s	remaining: 4.06s
# 664:	learn: 0.2752605	total: 8.03s	remaining: 4.04s
# 665:	learn: 0.2751800	total: 8.04s	remaining: 4.03s
# 666:	learn: 0.2751339	total: 8.04s	remaining: 4.01s
# 667:	learn: 0.2751209	total: 8.05s	remaining: 4s
# 668:	learn: 0.2750745	total: 8.06s	remaining: 3.99s
# 669:	learn: 0.2750194	total: 8.07s	remaining: 3.97s
# 670:	learn: 0.2749716	total: 8.08s	remaining: 3.96s
# 671:	learn: 0.2749386	total: 8.09s	remaining: 3.95s
# 672:	learn: 0.2749170	total: 8.09s	remaining: 3.93s
# 673:	learn: 0.2748670	total: 8.1s	remaining: 3.92s
# 674:	learn: 0.2748087	total: 8.11s	remaining: 3.9s
# 675:	learn: 0.2747877	total: 8.12s	remaining: 3.89s
# 676:	learn: 0.2747528	total: 8.13s	remaining: 3.88s
# 677:	learn: 0.2747125	total: 8.14s	remaining: 3.87s
# 678:	learn: 0.2746815	total: 8.15s	remaining: 3.85s
# 679:	learn: 0.2746482	total: 8.16s	remaining: 3.84s
# 680:	learn: 0.2746294	total: 8.17s	remaining: 3.83s
# 681:	learn: 0.2746177	total: 8.18s	remaining: 3.81s
# 682:	learn: 0.2746013	total: 8.19s	remaining: 3.8s
# 683:	learn: 0.2745264	total: 8.19s	remaining: 3.79s
# 684:	learn: 0.2744779	total: 8.2s	remaining: 3.77s
# 685:	learn: 0.2744327	total: 8.21s	remaining: 3.76s
# 686:	learn: 0.2743918	total: 8.22s	remaining: 3.74s
# 687:	learn: 0.2743532	total: 8.23s	remaining: 3.73s
# 688:	learn: 0.2743414	total: 8.24s	remaining: 3.72s
# 689:	learn: 0.2743215	total: 8.24s	remaining: 3.7s
# 690:	learn: 0.2742813	total: 8.25s	remaining: 3.69s
# 691:	learn: 0.2742312	total: 8.26s	remaining: 3.68s
# 692:	learn: 0.2741653	total: 8.27s	remaining: 3.66s
# 693:	learn: 0.2741631	total: 8.28s	remaining: 3.65s
# 694:	learn: 0.2740959	total: 8.29s	remaining: 3.64s
# 695:	learn: 0.2740639	total: 8.3s	remaining: 3.62s
# 696:	learn: 0.2740448	total: 8.3s	remaining: 3.61s
# 697:	learn: 0.2739983	total: 8.31s	remaining: 3.6s
# 698:	learn: 0.2739787	total: 8.32s	remaining: 3.58s
# 699:	learn: 0.2739486	total: 8.33s	remaining: 3.57s
# 700:	learn: 0.2738889	total: 8.34s	remaining: 3.56s
# 701:	learn: 0.2738331	total: 8.35s	remaining: 3.54s
# 702:	learn: 0.2737815	total: 8.36s	remaining: 3.53s
# 703:	learn: 0.2737665	total: 8.37s	remaining: 3.52s
# 704:	learn: 0.2736932	total: 8.38s	remaining: 3.51s
# 705:	learn: 0.2736387	total: 8.39s	remaining: 3.5s
# 706:	learn: 0.2735869	total: 8.41s	remaining: 3.48s
# 707:	learn: 0.2735503	total: 8.42s	remaining: 3.47s
# 708:	learn: 0.2734949	total: 8.43s	remaining: 3.46s
# 709:	learn: 0.2734309	total: 8.44s	remaining: 3.45s
# 710:	learn: 0.2733890	total: 8.45s	remaining: 3.44s
# 711:	learn: 0.2733470	total: 8.46s	remaining: 3.42s
# 712:	learn: 0.2732874	total: 8.47s	remaining: 3.41s
# 713:	learn: 0.2732573	total: 8.48s	remaining: 3.4s
# 714:	learn: 0.2732267	total: 8.48s	remaining: 3.38s
# 715:	learn: 0.2731549	total: 8.49s	remaining: 3.37s
# 716:	learn: 0.2731424	total: 8.5s	remaining: 3.36s
# 717:	learn: 0.2730963	total: 8.51s	remaining: 3.34s
# 718:	learn: 0.2730432	total: 8.52s	remaining: 3.33s
# 719:	learn: 0.2730028	total: 8.53s	remaining: 3.32s
# 720:	learn: 0.2729677	total: 8.54s	remaining: 3.3s
# 721:	learn: 0.2729212	total: 8.55s	remaining: 3.29s
# 722:	learn: 0.2729001	total: 8.56s	remaining: 3.28s
# 723:	learn: 0.2728445	total: 8.56s	remaining: 3.27s
# 724:	learn: 0.2728133	total: 8.57s	remaining: 3.25s
# 725:	learn: 0.2727617	total: 8.58s	remaining: 3.24s
# 726:	learn: 0.2727000	total: 8.59s	remaining: 3.23s
# 727:	learn: 0.2726866	total: 8.6s	remaining: 3.21s
# 728:	learn: 0.2726314	total: 8.61s	remaining: 3.2s
# 729:	learn: 0.2725713	total: 8.62s	remaining: 3.19s
# 730:	learn: 0.2725193	total: 8.63s	remaining: 3.17s
# 731:	learn: 0.2725004	total: 8.63s	remaining: 3.16s
# 732:	learn: 0.2724467	total: 8.64s	remaining: 3.15s
# 733:	learn: 0.2723838	total: 8.65s	remaining: 3.13s
# 734:	learn: 0.2723816	total: 8.66s	remaining: 3.12s
# 735:	learn: 0.2723604	total: 8.67s	remaining: 3.11s
# 736:	learn: 0.2723211	total: 8.68s	remaining: 3.1s
# 737:	learn: 0.2723072	total: 8.69s	remaining: 3.08s
# 738:	learn: 0.2722501	total: 8.7s	remaining: 3.07s
# 739:	learn: 0.2722477	total: 8.71s	remaining: 3.06s
# 740:	learn: 0.2721988	total: 8.72s	remaining: 3.05s
# 741:	learn: 0.2721697	total: 8.72s	remaining: 3.03s
# 742:	learn: 0.2721283	total: 8.73s	remaining: 3.02s
# 743:	learn: 0.2721158	total: 8.74s	remaining: 3.01s
# 744:	learn: 0.2720666	total: 8.75s	remaining: 3s
# 745:	learn: 0.2720121	total: 8.77s	remaining: 2.98s
# 746:	learn: 0.2719962	total: 8.78s	remaining: 2.97s
# 747:	learn: 0.2719485	total: 8.79s	remaining: 2.96s
# 748:	learn: 0.2718935	total: 8.8s	remaining: 2.95s
# 749:	learn: 0.2718272	total: 8.8s	remaining: 2.94s
# 750:	learn: 0.2717776	total: 8.81s	remaining: 2.92s
# 751:	learn: 0.2717368	total: 8.82s	remaining: 2.91s
# 752:	learn: 0.2717040	total: 8.83s	remaining: 2.9s
# 753:	learn: 0.2716458	total: 8.84s	remaining: 2.88s
# 754:	learn: 0.2716116	total: 8.85s	remaining: 2.87s
# 755:	learn: 0.2715783	total: 8.86s	remaining: 2.86s
# 756:	learn: 0.2715760	total: 8.87s	remaining: 2.85s
# 757:	learn: 0.2715609	total: 8.88s	remaining: 2.83s
# 758:	learn: 0.2715468	total: 8.88s	remaining: 2.82s
# 759:	learn: 0.2714912	total: 8.89s	remaining: 2.81s
# 760:	learn: 0.2714663	total: 8.9s	remaining: 2.79s
# 761:	learn: 0.2714172	total: 8.91s	remaining: 2.78s
# 762:	learn: 0.2713536	total: 8.92s	remaining: 2.77s
# 763:	learn: 0.2713439	total: 8.93s	remaining: 2.76s
# 764:	learn: 0.2712977	total: 8.94s	remaining: 2.75s
# 765:	learn: 0.2712623	total: 8.94s	remaining: 2.73s
# 766:	learn: 0.2712228	total: 8.95s	remaining: 2.72s
# 767:	learn: 0.2711738	total: 8.96s	remaining: 2.71s
# 768:	learn: 0.2711721	total: 8.98s	remaining: 2.7s
# 769:	learn: 0.2711371	total: 8.98s	remaining: 2.68s
# 770:	learn: 0.2710999	total: 9s	remaining: 2.67s
# 771:	learn: 0.2710680	total: 9s	remaining: 2.66s
# 772:	learn: 0.2710584	total: 9.01s	remaining: 2.65s
# 773:	learn: 0.2710462	total: 9.02s	remaining: 2.63s
# 774:	learn: 0.2710443	total: 9.03s	remaining: 2.62s
# 775:	learn: 0.2709842	total: 9.04s	remaining: 2.61s
# 776:	learn: 0.2709282	total: 9.05s	remaining: 2.6s
# 777:	learn: 0.2709154	total: 9.05s	remaining: 2.58s
# 778:	learn: 0.2708797	total: 9.06s	remaining: 2.57s
# 779:	learn: 0.2708672	total: 9.07s	remaining: 2.56s
# 780:	learn: 0.2708318	total: 9.08s	remaining: 2.55s
# 781:	learn: 0.2708299	total: 9.09s	remaining: 2.53s
# 782:	learn: 0.2707661	total: 9.1s	remaining: 2.52s
# 783:	learn: 0.2707366	total: 9.11s	remaining: 2.51s
# 784:	learn: 0.2707347	total: 9.12s	remaining: 2.5s
# 785:	learn: 0.2706836	total: 9.13s	remaining: 2.48s
# 786:	learn: 0.2706505	total: 9.14s	remaining: 2.47s
# 787:	learn: 0.2706353	total: 9.14s	remaining: 2.46s
# 788:	learn: 0.2706085	total: 9.15s	remaining: 2.45s
# 789:	learn: 0.2705506	total: 9.16s	remaining: 2.44s
# 790:	learn: 0.2705067	total: 9.17s	remaining: 2.42s
# 791:	learn: 0.2704659	total: 9.18s	remaining: 2.41s
# 792:	learn: 0.2704641	total: 9.19s	remaining: 2.4s
# 793:	learn: 0.2703950	total: 9.2s	remaining: 2.39s
# 794:	learn: 0.2703514	total: 9.21s	remaining: 2.38s
# 795:	learn: 0.2703228	total: 9.22s	remaining: 2.36s
# 796:	learn: 0.2702619	total: 9.23s	remaining: 2.35s
# 797:	learn: 0.2702033	total: 9.24s	remaining: 2.34s
# 798:	learn: 0.2701400	total: 9.25s	remaining: 2.33s
# 799:	learn: 0.2700948	total: 9.26s	remaining: 2.31s
# 800:	learn: 0.2700703	total: 9.27s	remaining: 2.3s
# 801:	learn: 0.2700390	total: 9.28s	remaining: 2.29s
# 802:	learn: 0.2699979	total: 9.29s	remaining: 2.28s
# 803:	learn: 0.2699625	total: 9.3s	remaining: 2.27s
# 804:	learn: 0.2699334	total: 9.3s	remaining: 2.25s
# 805:	learn: 0.2699233	total: 9.31s	remaining: 2.24s
# 806:	learn: 0.2698839	total: 9.32s	remaining: 2.23s
# 807:	learn: 0.2698382	total: 9.33s	remaining: 2.22s
# 808:	learn: 0.2698000	total: 9.34s	remaining: 2.21s
# 809:	learn: 0.2697794	total: 9.35s	remaining: 2.19s
# 810:	learn: 0.2697688	total: 9.36s	remaining: 2.18s
# 811:	learn: 0.2697289	total: 9.37s	remaining: 2.17s
# 812:	learn: 0.2696911	total: 9.38s	remaining: 2.16s
# 813:	learn: 0.2696511	total: 9.39s	remaining: 2.15s
# 814:	learn: 0.2696494	total: 9.4s	remaining: 2.13s
# 815:	learn: 0.2696127	total: 9.41s	remaining: 2.12s
# 816:	learn: 0.2695867	total: 9.42s	remaining: 2.11s
# 817:	learn: 0.2695769	total: 9.43s	remaining: 2.1s
# 818:	learn: 0.2695496	total: 9.46s	remaining: 2.09s
# 819:	learn: 0.2695192	total: 9.46s	remaining: 2.08s
# 820:	learn: 0.2694637	total: 9.47s	remaining: 2.06s
# 821:	learn: 0.2694113	total: 9.48s	remaining: 2.05s
# 822:	learn: 0.2693648	total: 9.49s	remaining: 2.04s
# 823:	learn: 0.2693247	total: 9.5s	remaining: 2.03s
# 824:	learn: 0.2692917	total: 9.51s	remaining: 2.02s
# 825:	learn: 0.2692537	total: 9.52s	remaining: 2s
# 826:	learn: 0.2691891	total: 9.53s	remaining: 1.99s
# 827:	learn: 0.2691338	total: 9.54s	remaining: 1.98s
# 828:	learn: 0.2691103	total: 9.54s	remaining: 1.97s
# 829:	learn: 0.2690662	total: 9.55s	remaining: 1.96s
# 830:	learn: 0.2690316	total: 9.56s	remaining: 1.94s
# 831:	learn: 0.2689839	total: 9.57s	remaining: 1.93s
# 832:	learn: 0.2689252	total: 9.58s	remaining: 1.92s
# 833:	learn: 0.2688838	total: 9.59s	remaining: 1.91s
# 834:	learn: 0.2688396	total: 9.6s	remaining: 1.9s
# 835:	learn: 0.2688143	total: 9.61s	remaining: 1.89s
# 836:	learn: 0.2687774	total: 9.62s	remaining: 1.87s
# 837:	learn: 0.2687698	total: 9.63s	remaining: 1.86s
# 838:	learn: 0.2687358	total: 9.64s	remaining: 1.85s
# 839:	learn: 0.2686536	total: 9.64s	remaining: 1.84s
# 840:	learn: 0.2685774	total: 9.65s	remaining: 1.82s
# 841:	learn: 0.2685221	total: 9.66s	remaining: 1.81s
# 842:	learn: 0.2685143	total: 9.67s	remaining: 1.8s
# 843:	learn: 0.2684983	total: 9.68s	remaining: 1.79s
# 844:	learn: 0.2684506	total: 9.69s	remaining: 1.78s
# 845:	learn: 0.2684049	total: 9.7s	remaining: 1.76s
# 846:	learn: 0.2683793	total: 9.71s	remaining: 1.75s
# 847:	learn: 0.2683382	total: 9.71s	remaining: 1.74s
# 848:	learn: 0.2682769	total: 9.72s	remaining: 1.73s
# 849:	learn: 0.2681959	total: 9.73s	remaining: 1.72s
# 850:	learn: 0.2681944	total: 9.74s	remaining: 1.71s
# 851:	learn: 0.2681580	total: 9.75s	remaining: 1.69s
# 852:	learn: 0.2681420	total: 9.76s	remaining: 1.68s
# 853:	learn: 0.2680883	total: 9.77s	remaining: 1.67s
# 854:	learn: 0.2680586	total: 9.79s	remaining: 1.66s
# 855:	learn: 0.2680035	total: 9.79s	remaining: 1.65s
# 856:	learn: 0.2679670	total: 9.8s	remaining: 1.64s
# 857:	learn: 0.2679479	total: 9.81s	remaining: 1.62s
# 858:	learn: 0.2678918	total: 9.82s	remaining: 1.61s
# 859:	learn: 0.2678397	total: 9.83s	remaining: 1.6s
# 860:	learn: 0.2678140	total: 9.84s	remaining: 1.59s
# 861:	learn: 0.2677831	total: 9.85s	remaining: 1.58s
# 862:	learn: 0.2677730	total: 9.86s	remaining: 1.56s
# 863:	learn: 0.2677567	total: 9.86s	remaining: 1.55s
# 864:	learn: 0.2677208	total: 9.87s	remaining: 1.54s
# 865:	learn: 0.2676955	total: 9.88s	remaining: 1.53s
# 866:	learn: 0.2676300	total: 9.89s	remaining: 1.52s
# 867:	learn: 0.2676123	total: 9.9s	remaining: 1.5s
# 868:	learn: 0.2676037	total: 9.91s	remaining: 1.49s
# 869:	learn: 0.2675735	total: 9.92s	remaining: 1.48s
# 870:	learn: 0.2675619	total: 9.93s	remaining: 1.47s
# 871:	learn: 0.2675608	total: 9.94s	remaining: 1.46s
# 872:	learn: 0.2675089	total: 9.94s	remaining: 1.45s
# 873:	learn: 0.2675078	total: 9.95s	remaining: 1.43s
# 874:	learn: 0.2674633	total: 9.96s	remaining: 1.42s
# 875:	learn: 0.2674042	total: 9.97s	remaining: 1.41s
# 876:	learn: 0.2673701	total: 9.98s	remaining: 1.4s
# 877:	learn: 0.2673291	total: 9.99s	remaining: 1.39s
# 878:	learn: 0.2672744	total: 10s	remaining: 1.38s
# 879:	learn: 0.2672230	total: 10s	remaining: 1.36s
# 880:	learn: 0.2671633	total: 10s	remaining: 1.35s
# 881:	learn: 0.2671586	total: 10s	remaining: 1.34s
# 882:	learn: 0.2671412	total: 10s	remaining: 1.33s
# 883:	learn: 0.2671324	total: 10s	remaining: 1.32s
# 884:	learn: 0.2670934	total: 10.1s	remaining: 1.31s
# 885:	learn: 0.2670640	total: 10.1s	remaining: 1.29s
# 886:	learn: 0.2670411	total: 10.1s	remaining: 1.28s
# 887:	learn: 0.2670311	total: 10.1s	remaining: 1.27s
# 888:	learn: 0.2669717	total: 10.1s	remaining: 1.26s
# 889:	learn: 0.2669407	total: 10.1s	remaining: 1.25s
# 890:	learn: 0.2668933	total: 10.1s	remaining: 1.24s
# 891:	learn: 0.2668613	total: 10.1s	remaining: 1.22s
# 892:	learn: 0.2668315	total: 10.1s	remaining: 1.21s
# 893:	learn: 0.2668024	total: 10.1s	remaining: 1.2s
# 894:	learn: 0.2667747	total: 10.1s	remaining: 1.19s
# 895:	learn: 0.2667366	total: 10.1s	remaining: 1.18s
# 896:	learn: 0.2666912	total: 10.2s	remaining: 1.17s
# 897:	learn: 0.2666814	total: 10.2s	remaining: 1.15s
# 898:	learn: 0.2666512	total: 10.2s	remaining: 1.14s
# 899:	learn: 0.2666502	total: 10.2s	remaining: 1.13s
# 900:	learn: 0.2666340	total: 10.2s	remaining: 1.12s
# 901:	learn: 0.2665993	total: 10.2s	remaining: 1.11s
# 902:	learn: 0.2665756	total: 10.2s	remaining: 1.1s
# 903:	learn: 0.2665672	total: 10.2s	remaining: 1.08s
# 904:	learn: 0.2665389	total: 10.2s	remaining: 1.07s
# 905:	learn: 0.2664908	total: 10.2s	remaining: 1.06s
# 906:	learn: 0.2664713	total: 10.2s	remaining: 1.05s
# 907:	learn: 0.2664401	total: 10.3s	remaining: 1.04s
# 908:	learn: 0.2664309	total: 10.3s	remaining: 1.03s
# 909:	learn: 0.2664073	total: 10.3s	remaining: 1.01s
# 910:	learn: 0.2663833	total: 10.3s	remaining: 1s
# 911:	learn: 0.2663410	total: 10.3s	remaining: 993ms
# 912:	learn: 0.2663128	total: 10.3s	remaining: 981ms
# 913:	learn: 0.2663043	total: 10.3s	remaining: 970ms
# 914:	learn: 0.2663033	total: 10.3s	remaining: 958ms
# 915:	learn: 0.2662883	total: 10.3s	remaining: 947ms
# 916:	learn: 0.2662486	total: 10.3s	remaining: 936ms
# 917:	learn: 0.2661916	total: 10.3s	remaining: 924ms
# 918:	learn: 0.2661526	total: 10.4s	remaining: 913ms
# 919:	learn: 0.2661313	total: 10.4s	remaining: 901ms
# 920:	learn: 0.2660681	total: 10.4s	remaining: 890ms
# 921:	learn: 0.2660409	total: 10.4s	remaining: 878ms
# 922:	learn: 0.2660065	total: 10.4s	remaining: 867ms
# 923:	learn: 0.2659806	total: 10.4s	remaining: 856ms
# 924:	learn: 0.2659608	total: 10.4s	remaining: 844ms
# 925:	learn: 0.2658879	total: 10.4s	remaining: 833ms
# 926:	learn: 0.2658790	total: 10.4s	remaining: 822ms
# 927:	learn: 0.2658543	total: 10.4s	remaining: 811ms
# 928:	learn: 0.2658200	total: 10.5s	remaining: 799ms
# 929:	learn: 0.2657711	total: 10.5s	remaining: 788ms
# 930:	learn: 0.2657637	total: 10.5s	remaining: 777ms
# 931:	learn: 0.2657560	total: 10.5s	remaining: 766ms
# 932:	learn: 0.2657387	total: 10.5s	remaining: 754ms
# 933:	learn: 0.2657323	total: 10.5s	remaining: 743ms
# 934:	learn: 0.2657147	total: 10.5s	remaining: 731ms
# 935:	learn: 0.2656480	total: 10.5s	remaining: 720ms
# 936:	learn: 0.2656281	total: 10.5s	remaining: 709ms
# 937:	learn: 0.2655984	total: 10.6s	remaining: 697ms
# 938:	learn: 0.2655460	total: 10.6s	remaining: 686ms
# 939:	learn: 0.2655053	total: 10.6s	remaining: 675ms
# 940:	learn: 0.2654560	total: 10.6s	remaining: 663ms
# 941:	learn: 0.2654233	total: 10.6s	remaining: 652ms
# 942:	learn: 0.2653717	total: 10.6s	remaining: 641ms
# 943:	learn: 0.2653586	total: 10.6s	remaining: 630ms
# 944:	learn: 0.2652809	total: 10.6s	remaining: 618ms
# 945:	learn: 0.2652417	total: 10.6s	remaining: 607ms
# 946:	learn: 0.2651883	total: 10.6s	remaining: 595ms
# 947:	learn: 0.2651210	total: 10.6s	remaining: 584ms
# 948:	learn: 0.2650718	total: 10.7s	remaining: 573ms
# 949:	learn: 0.2650395	total: 10.7s	remaining: 562ms
# 950:	learn: 0.2650093	total: 10.7s	remaining: 550ms
# 951:	learn: 0.2649426	total: 10.7s	remaining: 539ms
# 952:	learn: 0.2649115	total: 10.7s	remaining: 528ms
# 953:	learn: 0.2648796	total: 10.7s	remaining: 516ms
# 954:	learn: 0.2648311	total: 10.7s	remaining: 505ms
# 955:	learn: 0.2647726	total: 10.7s	remaining: 494ms
# 956:	learn: 0.2647324	total: 10.7s	remaining: 482ms
# 957:	learn: 0.2646997	total: 10.7s	remaining: 471ms
# 958:	learn: 0.2646830	total: 10.8s	remaining: 460ms
# 959:	learn: 0.2646690	total: 10.8s	remaining: 449ms
# 960:	learn: 0.2646371	total: 10.8s	remaining: 437ms
# 961:	learn: 0.2646140	total: 10.8s	remaining: 426ms
# 962:	learn: 0.2645865	total: 10.8s	remaining: 415ms
# 963:	learn: 0.2645621	total: 10.8s	remaining: 404ms
# 964:	learn: 0.2645382	total: 10.8s	remaining: 392ms
# 965:	learn: 0.2644983	total: 10.8s	remaining: 381ms
# 966:	learn: 0.2644780	total: 10.8s	remaining: 370ms
# 967:	learn: 0.2644294	total: 10.8s	remaining: 359ms
# 968:	learn: 0.2644147	total: 10.9s	remaining: 347ms
# 969:	learn: 0.2643651	total: 10.9s	remaining: 336ms
# 970:	learn: 0.2643065	total: 10.9s	remaining: 325ms
# 971:	learn: 0.2642509	total: 10.9s	remaining: 314ms
# 972:	learn: 0.2642080	total: 10.9s	remaining: 302ms
# 973:	learn: 0.2641734	total: 10.9s	remaining: 291ms
# 974:	learn: 0.2641503	total: 10.9s	remaining: 280ms
# 975:	learn: 0.2641378	total: 10.9s	remaining: 269ms
# 976:	learn: 0.2641109	total: 10.9s	remaining: 257ms
# 977:	learn: 0.2640845	total: 10.9s	remaining: 246ms
# 978:	learn: 0.2640152	total: 10.9s	remaining: 235ms
# 979:	learn: 0.2639779	total: 11s	remaining: 224ms
# 980:	learn: 0.2639571	total: 11s	remaining: 212ms
# 981:	learn: 0.2639068	total: 11s	remaining: 201ms
# 982:	learn: 0.2638789	total: 11s	remaining: 190ms
# 983:	learn: 0.2638470	total: 11s	remaining: 179ms
# 984:	learn: 0.2638048	total: 11s	remaining: 168ms
# 985:	learn: 0.2638002	total: 11s	remaining: 156ms
# 986:	learn: 0.2637959	total: 11s	remaining: 145ms
# 987:	learn: 0.2637473	total: 11s	remaining: 134ms
# 988:	learn: 0.2637133	total: 11s	remaining: 123ms
# 989:	learn: 0.2636856	total: 11.1s	remaining: 112ms
# 990:	learn: 0.2636518	total: 11.1s	remaining: 100ms
# 991:	learn: 0.2636409	total: 11.1s	remaining: 89.3ms
# 992:	learn: 0.2636041	total: 11.1s	remaining: 78.1ms
# 993:	learn: 0.2635423	total: 11.1s	remaining: 66.9ms
# 994:	learn: 0.2635284	total: 11.1s	remaining: 55.8ms
# 995:	learn: 0.2635037	total: 11.1s	remaining: 44.6ms
# 996:	learn: 0.2634910	total: 11.1s	remaining: 33.4ms
# 997:	learn: 0.2634613	total: 11.1s	remaining: 22.3ms
# 998:	learn: 0.2634189	total: 11.1s	remaining: 11.1ms
# 999:	learn: 0.2634071	total: 11.1s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0      0.823     0.792     0.807      2313
#            1      0.856     0.879     0.868      3267
#
#     accuracy                          0.843      5580
#    macro avg      0.840     0.836     0.837      5580
# weighted avg      0.842     0.843     0.843      5580

# %%
print("Balanced Acc (Base) :", balanced_accuracy_score(y_test, pred))
print("Balanced Acc (SMOTE):", balanced_accuracy_score(y_test, y_pred_sm))
# Out:
# Balanced Acc (Base) : 0.8386476485167678
# Balanced Acc (SMOTE): 0.8355063427578461

# %% [markdown]
# #Curvas de calibração
# Verifica se as probabilidades podem ser usadas como “grau de confiança” (importante para tomar decisão baseada em risco).

# %%
y_proba = model.predict_proba(X_test)
classes = model.classes_

# Padronização do n_bins = 10
N_BINS = 10

# Uma curva por classe (one-vs-rest)
for k, cls in enumerate(classes):
    y_true_bin = (y_test == cls).astype(int)
    frac_pos, mean_pred = calibration_curve(y_true_bin, y_proba[:, k], n_bins=N_BINS, strategy="quantile")

    plt.figure(figsize=(8,4))
    plt.plot([0,1], [0,1], "--", label="Perfeita (y=x)")
    plt.plot(mean_pred, frac_pos, marker="o", label=f"Classe {cls}")
    plt.xlabel("Probabilidade prevista p(y = classe)")
    plt.ylabel("Fração positiva observada")
    plt.title(f"Curva de Calibração — Classe {cls}")
    plt.legend(loc="best")
    plt.tight_layout()
    plt.show()

    # Métrica quantitativa de calibração (Brier score) para a classe k
    bs = brier_score_loss(y_true_bin, y_proba[:, k])
    print(f"Brier score (classe {cls}): {bs:.4f}")
# Out:
# Brier score (classe 0): 0.1106
# Brier score (classe 1): 0.1106

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Matriz de Confusão - Random Forest")
plt.xlabel("Previsto")
plt.ylabel("Real")
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred, normalize='true')
sns.heatmap(cm, annot=True, fmt='.2f'); plt.show()

# %%
importancias = model.feature_importances_
feature_names = features.columns
importancia_df = pd.DataFrame({'Feature': feature_names, 'Importância': importancias})
importancia_df = importancia_df.sort_values(by='Importância', ascending=False)

plt.figure(figsize=(8, 4))
sns.barplot(data=importancia_df, x='Importância', y='Feature')
plt.title('Importância das Features - CatBoost')
plt.show()

# %%
# No conjunto de teste (para não superestimar)
result = permutation_importance(model, X_test, y_test, scoring="f1_macro",
                                n_repeats=20, random_state=42, n_jobs=-1)

importances = pd.Series(result.importances_mean, index=features.columns)
importances = importances.sort_values(ascending=False)

print(importances)

# Gráfico
importances.plot(kind="bar", figsize=(8,3), title="Permutation Importance")
# Out:
# Have you ever had suicidal thoughts ?    0.11
# Academic Pressure                        0.09
# Financial Stress                         0.04
# Age                                      0.02
# Work/Study Hours                         0.01
# Dietary Habits                           0.01
# Study Satisfaction                       0.01
# Sleep Duration                           0.00
# Family History of Mental Illness        -0.00
# dtype: float64
# <Axes: title={'center': 'Permutation Importance'}>

# %%
classes = model.classes_
classes_interesse = [1, 3, 5]   # ajuste as classes de interesse

def scorer_para_classe_k_factory(k):
    # k é o rótulo inteiro da classe (ex.: 1, 3, 5)
    def _scorer(estimator, X, y_true_bin):
        # Prediz classe argmax e transforma em binário (1 se ==k, 0 caso contrário)
        y_pred_bin = (estimator.predict(X) == k).astype(int)
        return f1_score(y_true_bin, y_pred_bin, zero_division=0)
    return _scorer

for k in classes_interesse:
    print(f"\n=== Permutation Importance focada na classe {k} (F1-binário) ===")
    y_true_bin = (y_test == k).astype(int)

    result_k = permutation_importance(
        model, X_test, y_true_bin,
        scoring=scorer_para_classe_k_factory(k),
        n_repeats=20, random_state=42, n_jobs=-1
    )

    pi_k = pd.Series(result_k.importances_mean, index=features.columns).sort_values(ascending=False)
    display(pi_k)

    plt.figure(figsize=(10,4))
    pi_k.plot(kind="bar")
    plt.title(f"Permutation Importance — Classe {k} (F1 binário classe {k})")
    plt.ylabel("Queda média na métrica ao permutar")
    plt.tight_layout()
    plt.show()
# Out:
# === Permutation Importance focada na classe 1 (F1-binário) ===
# Have you ever had suicidal thoughts ?   0.09
# Academic Pressure                       0.07
# Financial Stress                        0.03
# Age                                     0.01
# Work/Study Hours                        0.01
# Dietary Habits                          0.01
# Study Satisfaction                      0.01
# Sleep Duration                          0.00
# Family History of Mental Illness        0.00
# dtype: float64
# === Permutation Importance focada na classe 3 (F1-binário) ===
# Age                                     0.00
# Academic Pressure                       0.00
# Study Satisfaction                      0.00
# Sleep Duration                          0.00
# Dietary Habits                          0.00
# Have you ever had suicidal thoughts ?   0.00
# Work/Study Hours                        0.00
# Financial Stress                        0.00
# Family History of Mental Illness        0.00
# dtype: float64
# === Permutation Importance focada na classe 5 (F1-binário) ===
# Age                                     0.00
# Academic Pressure                       0.00
# Study Satisfaction                      0.00
# Sleep Duration                          0.00
# Dietary Habits                          0.00
# Have you ever had suicidal thoughts ?   0.00
# Work/Study Hours                        0.00
# Financial Stress                        0.00
# Family History of Mental Illness        0.00
# dtype: float64

# %% [markdown]
# #Classification Report
#
# Resumo das métricas por classes de modelos de classificação

# %%
y_proba = model.predict_proba(X_test)[:, 1]

tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

acc  = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, zero_division=0)
rec  = recall_score(y_test, y_pred)
f1   = f1_score(y_test, y_pred)

tpr = tp / (tp + fn)
tnr = tn / (tn + fp)
fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

bal_acc = balanced_accuracy_score(y_test, y_pred)
mcc     = matthews_corrcoef(y_test, y_pred)
kappa   = cohen_kappa_score(y_test, y_pred)

roc_auc = roc_auc_score(y_test, y_proba)
ap      = average_precision_score(y_test, y_proba)
ll      = log_loss(y_test, y_proba)
brier   = brier_score_loss(y_test, y_proba)

resumo = pd.Series({
    "Accuracy": acc,
    "Precision (classe 1)": prec,
    "Recall/Sensibilidade (classe 1)": rec,
    "Especificidade (classe 0)": tnr,
    "F1 (classe 1)": f1,
    "Balanced Accuracy": bal_acc,
    "MCC": mcc,
    "Cohen’s Kappa": kappa,
    "ROC AUC": roc_auc,
    "PR AUC (Average Precision)": ap,
    "Log Loss": ll,
    "Brier Score": brier,
    "TP": tp, "FP": fp, "TN": tn, "FN": fn,
    "FPR": fpr, "FNR": fnr
})
print(resumo.round(4))

print("\nClassification report:\n")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Accuracy                             0.85
# Precision (classe 1)                 0.86
# Recall/Sensibilidade (classe 1)      0.89
# Especificidade (classe 0)            0.79
# F1 (classe 1)                        0.87
# Balanced Accuracy                    0.84
# MCC                                  0.68
# Cohen’s Kappa                        0.68
# ROC AUC                              0.92
# PR AUC (Average Precision)           0.94
# Log Loss                             0.36
# Brier Score                          0.11
# TP                                2902.00
# FP                                 488.00
# TN                                1825.00
# FN                                 365.00
# FPR                                  0.21
# FNR                                  0.11
# dtype: float64
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0     0.8333    0.7890    0.8106      2313
#            1     0.8560    0.8883    0.8719      3267
#
#     accuracy                         0.8471      5580
#    macro avg     0.8447    0.8386    0.8412      5580
# weighted avg     0.8466    0.8471    0.8465      5580

# %% [markdown]
# #Curva Roc
# Mede o equilíbrio entre não errar falsos positivos e não perder casos reais de depressão.

# %%
fpr_curve, tpr_curve, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(5,4))
plt.plot(fpr_curve, tpr_curve, label=f'ROC AUC = {roc_auc:.3f}')
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('FPR (1 - Especificidade)')
plt.ylabel('TPR (Sensibilidade)')
plt.title('ROC Curve')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #Precision-Recall
# Se você aumenta recall (pega mais pessoas com depressão), a precision cai (mais falsos alarmes).

# %%
prec_curve, rec_curve, _ = precision_recall_curve(y_test, y_proba)
plt.figure(figsize=(5,4))
plt.plot(rec_curve, prec_curve, label=f'AP = {ap:.3f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.tight_layout()
plt.show()
